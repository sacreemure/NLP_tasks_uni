# %%
# !pip install textstat

# %%
import os
import textstat

# %%
ottepel_path = "/content/ottepel.txt"
ottepel_short_path = '/content/ottepel_pereskaz.txt'

nez_path = '/content/neznakomka.txt'
nez_short_path = '/content/neznakomka_pereskaz.txt'

p_path = '/content/peterburg.txt'
p_short_path = '/content/peterburg_perskaz.txt'

# %%
with open(ottepel_path, 'r', encoding='utf-8') as f:
    ottepel = ' '.join([line.strip() for line in f.readlines()])
with open(ottepel_short_path, 'r', encoding='utf-8') as f:
    ottepel_short = ' '.join([line.strip() for line in f.readlines()])

# %%
with open(nez_path, 'r', encoding='utf-8') as f:
    neznakomka = ' '.join([line.strip() for line in f.readlines()])
with open(nez_short_path, 'r', encoding='utf-8') as f:
    neznakomka_short = ' '.join([line.strip() for line in f.readlines()])

# %%
with open(p_path, 'r', encoding='utf-8') as f:
    peterburg = ' '.join([line.strip() for line in f.readlines()])
with open(p_short_path, 'r', encoding='utf-8') as f:
    peterburg_short = ' '.join([line.strip() for line in f.readlines()])

# %% [markdown]
# # TextStat

# %%
textstat.set_lang('ru')

# %% [markdown]
# ---

# %% [markdown]
# ## Оттепель

# %%
print('Readability scores Ottepel Orig')
print('flesch_reading_ease', textstat.flesch_reading_ease(ottepel))
print('flesch_kincaid_grade', textstat.flesch_kincaid_grade(ottepel))
print('smog_index', textstat.smog_index(ottepel))
print('coleman_liau_index', textstat.coleman_liau_index(ottepel))
print('automated_readability_index', textstat.automated_readability_index(ottepel))
print('dale_chall_readability_score', textstat.dale_chall_readability_score(ottepel))
print('difficult_words', textstat.difficult_words(ottepel))
print('linsear_write_formula', textstat.linsear_write_formula(ottepel))
print('gunning_fog', textstat.gunning_fog(ottepel))
print('text_standard', textstat.text_standard(ottepel))
print('fernandez_huerta', textstat.fernandez_huerta(ottepel))
print('szigriszt_pazos', textstat.szigriszt_pazos(ottepel))
print('gutierrez_polini', textstat.gutierrez_polini(ottepel))
print('crawford', textstat.crawford(ottepel))
print('gulpease_index', textstat.gulpease_index(ottepel))
print('osman', textstat.osman(ottepel))
# Out:
# Readability scores Ottepel Orig
# flesch_reading_ease 67.37
# flesch_kincaid_grade 13.2
# smog_index 13.5
# coleman_liau_index 11.17
# automated_readability_index 9.7
# /usr/local/lib/python3.10/dist-packages/textstat/textstat.py:1482: Warning: There is no easy words vocabulary for ru, using english.
#   warnings.warn(
# dale_chall_readability_score 7.18
# difficult_words 13429
# linsear_write_formula 13.714285714285714
# gunning_fog 9.14
# text_standard 13th and 14th grade
# fernandez_huerta 70.44
# szigriszt_pazos 66.78
# gutierrez_polini 41.56
# crawford 4.8
# gulpease_index 63.3
# osman 53.39

# %%
print('Readability scores Ottepel Short')
print('flesch_reading_ease', textstat.flesch_reading_ease(ottepel_short))
print('flesch_kincaid_grade', textstat.flesch_kincaid_grade(ottepel_short))
print('smog_index', textstat.smog_index(ottepel_short))
print('coleman_liau_index', textstat.coleman_liau_index(ottepel_short))
print('automated_readability_index', textstat.automated_readability_index(ottepel_short))
print('dale_chall_readability_score', textstat.dale_chall_readability_score(ottepel_short))
print('difficult_words', textstat.difficult_words(ottepel_short))
print('linsear_write_formula', textstat.linsear_write_formula(ottepel_short))
print('gunning_fog', textstat.gunning_fog(ottepel_short))
print('text_standard', textstat.text_standard(ottepel_short))
print('fernandez_huerta', textstat.fernandez_huerta(ottepel_short))
print('szigriszt_pazos', textstat.szigriszt_pazos(ottepel_short))
print('gutierrez_polini', textstat.gutierrez_polini(ottepel_short))
print('crawford', textstat.crawford(ottepel_short))
print('gulpease_index', textstat.gulpease_index(ottepel_short))
print('osman', textstat.osman(ottepel_short))
# Out:
# Readability scores Ottepel Short
# flesch_reading_ease 53.16
# flesch_kincaid_grade 16.8
# smog_index 17.5
# coleman_liau_index 13.74
# automated_readability_index 13.7
# dale_chall_readability_score 14.76
# difficult_words 449
# linsear_write_formula 12.0
# gunning_fog 19.87
# text_standard 13th and 14th grade
# fernandez_huerta 58.01
# szigriszt_pazos 51.76
# gutierrez_polini 37.01
# crawford 6.2
# gulpease_index 50.2
# osman 38.88

# %% [markdown]
# ## Незнакомка

# %%
print('Readability scores Neznakomka Orig')
print('flesch_reading_ease', textstat.flesch_reading_ease(neznakomka))
print('flesch_kincaid_grade', textstat.flesch_kincaid_grade(neznakomka))
print('smog_index', textstat.smog_index(neznakomka))
print('coleman_liau_index', textstat.coleman_liau_index(neznakomka))
print('automated_readability_index', textstat.automated_readability_index(neznakomka))
print('dale_chall_readability_score', textstat.dale_chall_readability_score(neznakomka))
print('difficult_words', textstat.difficult_words(neznakomka))
print('linsear_write_formula', textstat.linsear_write_formula(neznakomka))
print('gunning_fog', textstat.gunning_fog(neznakomka))
print('text_standard', textstat.text_standard(neznakomka))
print('fernandez_huerta', textstat.fernandez_huerta(neznakomka))
print('szigriszt_pazos', textstat.szigriszt_pazos(neznakomka))
print('gutierrez_polini', textstat.gutierrez_polini(neznakomka))
print('crawford', textstat.crawford(neznakomka))
print('gulpease_index', textstat.gulpease_index(neznakomka))
print('osman', textstat.osman(neznakomka))
# Out:
# Readability scores Neznakomka Orig
# flesch_reading_ease 68.83
# flesch_kincaid_grade 13.4
# smog_index 14.5
# coleman_liau_index 11.65
# automated_readability_index 10.7
# dale_chall_readability_score 16.5
# difficult_words 125
# linsear_write_formula 13.666666666666666
# gunning_fog 16.62
# text_standard 16th and 17th grade
# fernandez_huerta 72.87
# szigriszt_pazos 68.83
# gutierrez_polini 41.02
# crawford 4.9
# gulpease_index 57.4
# osman 51.97

# %%
print('Readability scores Neznakomka Short')
print('flesch_reading_ease', textstat.flesch_reading_ease(neznakomka_short))
print('flesch_kincaid_grade', textstat.flesch_kincaid_grade(neznakomka_short))
print('smog_index', textstat.smog_index(neznakomka_short))
print('coleman_liau_index', textstat.coleman_liau_index(neznakomka_short))
print('automated_readability_index', textstat.automated_readability_index(neznakomka_short))
print('dale_chall_readability_score', textstat.dale_chall_readability_score(neznakomka_short))
print('difficult_words', textstat.difficult_words(neznakomka_short))
print('linsear_write_formula', textstat.linsear_write_formula(neznakomka_short))
print('gunning_fog', textstat.gunning_fog(neznakomka_short))
print('text_standard', textstat.text_standard(neznakomka_short))
print('fernandez_huerta', textstat.fernandez_huerta(neznakomka_short))
print('szigriszt_pazos', textstat.szigriszt_pazos(neznakomka_short))
print('gutierrez_polini', textstat.gutierrez_polini(neznakomka_short))
print('crawford', textstat.crawford(neznakomka_short))
print('gulpease_index', textstat.gulpease_index(neznakomka_short))
print('osman', textstat.osman(neznakomka_short))
# Out:
# Readability scores Neznakomka Short
# flesch_reading_ease 50.02
# flesch_kincaid_grade 17.1
# smog_index 16.1
# coleman_liau_index 16.12
# automated_readability_index 15.1
# dale_chall_readability_score 16.53
# difficult_words 265
# linsear_write_formula 24.25
# gunning_fog 18.66
# text_standard 16th and 17th grade
# fernandez_huerta 54.25
# szigriszt_pazos 49.23
# gutierrez_polini 33.39
# crawford 6.4
# gulpease_index 47.7
# osman 28.49

# %% [markdown]
# ## Петербург

# %%
print('Readability scores Peterburg Orig')
print('flesch_reading_ease', textstat.flesch_reading_ease(peterburg))
print('flesch_kincaid_grade', textstat.flesch_kincaid_grade(peterburg))
print('smog_index', textstat.smog_index(peterburg))
print('coleman_liau_index', textstat.coleman_liau_index(peterburg))
print('automated_readability_index', textstat.automated_readability_index(peterburg))
print('dale_chall_readability_score', textstat.dale_chall_readability_score(peterburg))
print('difficult_words', textstat.difficult_words(peterburg))
print('linsear_write_formula', textstat.linsear_write_formula(peterburg))
print('gunning_fog', textstat.gunning_fog(peterburg))
print('text_standard', textstat.text_standard(peterburg))
print('fernandez_huerta', textstat.fernandez_huerta(peterburg))
print('szigriszt_pazos', textstat.szigriszt_pazos(peterburg))
print('gutierrez_polini', textstat.gutierrez_polini(peterburg))
print('crawford', textstat.crawford(peterburg))
print('gulpease_index', textstat.gulpease_index(peterburg))
print('osman', textstat.osman(peterburg))
# Out:
# Readability scores Peterburg Orig
# flesch_reading_ease 51.34
# flesch_kincaid_grade 17.4
# smog_index 18.1
# coleman_liau_index 15.19
# automated_readability_index 16.3
# dale_chall_readability_score 8.12
# difficult_words 30731
# linsear_write_formula 10.375
# gunning_fog 13.6
# text_standard 16th and 17th grade
# fernandez_huerta 56.58
# szigriszt_pazos 50.21
# gutierrez_polini 34.09
# crawford 6.4
# gulpease_index 44.6
# osman 28.41

# %%
print('Readability scores Peterburg Short')
print('flesch_reading_ease', textstat.flesch_reading_ease(peterburg_short))
print('flesch_kincaid_grade', textstat.flesch_kincaid_grade(peterburg_short))
print('smog_index', textstat.smog_index(peterburg_short))
print('coleman_liau_index', textstat.coleman_liau_index(peterburg_short))
print('automated_readability_index', textstat.automated_readability_index(peterburg_short))
print('dale_chall_readability_score', textstat.dale_chall_readability_score(peterburg_short))
print('difficult_words', textstat.difficult_words(peterburg_short))
print('linsear_write_formula', textstat.linsear_write_formula(peterburg_short))
print('gunning_fog', textstat.gunning_fog(peterburg_short))
print('text_standard', textstat.text_standard(peterburg_short))
print('fernandez_huerta', textstat.fernandez_huerta(peterburg_short))
print('szigriszt_pazos', textstat.szigriszt_pazos(peterburg_short))
print('gutierrez_polini', textstat.gutierrez_polini(peterburg_short))
print('crawford', textstat.crawford(peterburg_short))
print('gulpease_index', textstat.gulpease_index(peterburg_short))
print('osman', textstat.osman(peterburg_short))
# Out:
# Readability scores Peterburg Short
# flesch_reading_ease 51.19
# flesch_kincaid_grade 16.8
# smog_index 16.6
# coleman_liau_index 16.0
# automated_readability_index 13.9
# dale_chall_readability_score 12.85
# difficult_words 1051
# linsear_write_formula 12.428571428571429
# gunning_fog 17.23
# text_standard 16th and 17th grade
# fernandez_huerta 55.17
# szigriszt_pazos 48.98
# gutierrez_polini 33.88
# crawford 6.4
# gulpease_index 50.6
# osman 31.87

# %% [markdown]
# # Readability-Metrics

# %%
# !pip install py-readability-metrics

# %%
import os
from readability import Readability
import nltk
nltk.download('punkt')

# %%
r = Readability(peterburg)

print(r.flesch_kincaid())
print(r.flesch())
print(r.gunning_fog())
print(r.coleman_liau())
print(r.dale_chall())
print(r.ari())
print(r.linsear_write())
print(r.smog())
print(r.spache())
# Out:
# score: -2.170287966349221, grade_level: '-2'
# score: 151.48456171748367, ease: 'very_confusing', grade_levels: ['college_graduate']
# score: 9.564567494509587, grade_level: '10'
# score: 14.467184519227, grade_level: '14'
# score: 20.61081116987245, grade_levels: ['college_graduate']
# score: 15.758636218091965, grade_levels: ['college_graduate'], ages: [24, 100]
# score: 11.957267623206487, grade_level: '12'
# score: 3.1291, grade_level: 3
# score: 12.806804912438478, grade_level: '13'

# %%
r = Readability(peterburg_short)

print(r.flesch_kincaid())
print(r.flesch())
print(r.gunning_fog())
print(r.coleman_liau())
print(r.dale_chall())
print(r.ari())
print(r.linsear_write())
print(r.smog())
print(r.spache())
# Out:
# score: -6.893164455414995, grade_level: '-7'
# score: 167.096120950324, ease: 'very_confusing', grade_levels: ['college_graduate']
# score: 5.291428571428572, grade_level: 'na'
# score: 15.21807343412527, grade_level: '15'
# score: 20.082637142857145, grade_levels: ['college_graduate']
# score: 11.822743597655041, grade_levels: ['12'], ages: [17, 18]
# score: 5.614285714285714, grade_level: '6'
# score: 3.1291, grade_level: 3
# score: 11.304228571428572, grade_level: '11'

# %%
r = Readability(ottepel)

print(r.flesch_kincaid())
print(r.flesch())
print(r.gunning_fog())
print(r.coleman_liau())
print(r.dale_chall())
print(r.ari())
print(r.linsear_write())
print(r.smog())
print(r.spache())
# Out:
# score: -6.584157452397623, grade_level: '-7'
# score: 162.72651295384873, ease: 'very_confusing', grade_levels: ['college_graduate']
# score: 4.787350798325841, grade_level: 'na'
# score: 11.17898404310434, grade_level: '11'
# score: 20.020131498992406, grade_levels: ['college_graduate']
# score: 8.145976266014234, grade_levels: ['9'], ages: [14, 15]
# score: 4.984188497907301, grade_level: '5'
# score: 3.1291, grade_level: 3
# score: 11.126541156409859, grade_level: '11'

# %%
r = Readability(ottepel_short)

print(r.flesch_kincaid())
print(r.flesch())
print(r.gunning_fog())
print(r.coleman_liau())
print(r.dale_chall())
print(r.ari())
print(r.linsear_write())
print(r.smog())
print(r.spache())
# Out:
# score: -4.455419920180461, grade_level: '-4'
# score: 157.3057955925733, ease: 'very_confusing', grade_levels: ['college_graduate']
# score: 7.090196078431373, grade_level: '7'
# score: 12.105707964601773, grade_level: '12'
# score: 20.305684313725493, grade_levels: ['college_graduate']
# score: 11.123419876800277, grade_levels: ['12'], ages: [17, 18]
# score: 7.862745098039216, grade_level: '8'
# score: 3.1291, grade_level: 3
# score: 11.93829411764706, grade_level: '12'
