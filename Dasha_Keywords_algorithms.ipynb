# %%
import os

# %%
#путь к папке corpus_reviews (лемматизированный корпус)
path = "corpus_reviews"
dirs = os.listdir(path)

# %%
i = 0
# словарь с именем файла и оценкой (negative,positive,neutral)
dict_score = {}

# %%
for file in dirs:
    #есть нетекстовые файлы
    if (file[-4:] == '.txt'):
        with open(path + '/' + file, 'r', encoding='utf-8') as readfile:
            for line in readfile:
                list_words = line.split()
                # последним токеном в файле идёт оценка
                dict_score[file] = list_words[len(list_words)-1]
                # формируем файл для анализа
                with open('reviews_for_work.txt', 'a', encoding='utf-8') as wfile:
                    # первым токеном в файле идёт номер файла, он не нужен
                    wfile.write(' '.join(list_words[1:len(list_words) - 1]) + '\n')
                    i += 1

# %%
print(f'files: {i}')

# %%
print(f'dict_score: {len(dict_score)}')

# %%
import re
import math
import pandas as pd
import nltk

# %%
with open('/content/art_m.txt', 'r', encoding='utf-8') as file:
    f = file.read()

# %%
text_words_2 = re.findall(r'[а-яёА-ЯЁ]+', f)

text_words_1 = []
for i in text_words_2:
    k = i.lower()
    text_words_1.append(k)

text_words_2
# Out:
# ['Введение',
#  'Разработка',
#  'новых',
#  'подходов',
#  'к',
#  'лингвистическому',
#  'моделированию',
#  'позволяет',
#  'исследователям',
#  'по',
#  'новому',
#  'взглянуть',
#  'на',
#  'важный',
#  'класс',
#  'задач',
#  'автоматической',
#  'обработки',
#  'естественного',
#  'языка',
#  'а',
#  'именно',
#  'на',
#  'смысловую',
#  'компрессию',
#  'текста',
#  'производимую',
#  'при',
#  'автоматическом',
#  'выделении',
#  'ключевых',
#  'слов',
#  'и',
#  'словосочетаний',
#  'классификации',
#  'и',
#  'кластеризации',
#  'лексики',
#  'и',
#  'документов',
#  'в',
#  'корпусах',
#  'текстов',
#  'выделении',
#  'классов',
#  'слов',
#  'с',
#  'близкими',
#  'дистрибутивными',
#  'свойствами',
#  'оценке',
#  'семантической',
#  'однородности',
#  'неоднородности',
#  'текстов',
#  'и',
#  'т',
#  'п',
#  'ср',
#  'наши',
#  'эксперименты',
#  'описанные',
#  'в',
#  'статьях',
#  'Митрофанова',
#  'Мухин',
#  'Паничева',
#  'Митрофанова',
#  'Митрофанова',
#  'Грачкова',
#  'Шиморина',
#  'В',
#  'данном',
#  'ряду',
#  'особняком',
#  'стоит',
#  'задача',
#  'тематического',
#  'моделирования',
#  'корпусов',
#  'текстов',
#  'В',
#  'последние',
#  'несколько',
#  'лет',
#  'арсенал',
#  'методов',
#  'тематического',
#  'моделирования',
#  'существенно',
#  'расширился',
#  'а',
#  'также',
#  'появились',
#  'доступные',
#  'исследователям',
#  'компьютерные',
#  'инструменты',
#  'автоматической',
#  'обработки',
#  'текстов',
#  'например',
#  'и',
#  'т',
#  'д',
#  'создающие',
#  'предпосылки',
#  'к',
#  'проведению',
#  'экспериментов',
#  'Параллельно',
#  'расширяется',
#  'круг',
#  'практических',
#  'задач',
#  'которые',
#  'решаются',
#  'данными',
#  'средствами',
#  'Особое',
#  'внимание',
#  'исследователей',
#  'сейчас',
#  'обращено',
#  'к',
#  'анализу',
#  'социальных',
#  'сетей',
#  'и',
#  'выявлению',
#  'тематической',
#  'структуры',
#  'сообществ',
#  'например',
#  'В',
#  'связи',
#  'с',
#  'этим',
#  'представляется',
#  'важным',
#  'оценить',
#  'особенности',
#  'различных',
#  'методов',
#  'тематического',
#  'моделирования',
#  'и',
#  'их',
#  'применимость',
#  'к',
#  'тем',
#  'или',
#  'иным',
#  'экспериментальным',
#  'данным',
#  'Тематическое',
#  'моделирование',
#  'что',
#  'это',
#  'такое',
#  'Тематическое',
#  'моделирование',
#  'способ',
#  'построения',
#  'модели',
#  'текстовой',
#  'коллекции',
#  'отражающий',
#  'переход',
#  'от',
#  'совокупности',
#  'документов',
#  'совокупности',
#  'слов',
#  'в',
#  'документах',
#  'коллекции',
#  'к',
#  'набору',
#  'тем',
#  'характеризующих',
#  'текстовую',
#  'коллекцию',
#  'Тематические',
#  'модели',
#  'модели',
#  'со',
#  'скрытыми',
#  'переменными',
#  'факторами',
#  'задающими',
#  'тематику',
#  'текстов',
#  'Для',
#  'выявления',
#  'этих',
#  'скрытых',
#  'переменных',
#  'лучше',
#  'всего',
#  'применять',
#  'нечеткую',
#  'кластеризацию',
#  'разбиение',
#  'текстов',
#  'на',
#  'пересекающиеся',
#  'классы',
#  'В',
#  'таком',
#  'случае',
#  'тема',
#  'это',
#  'результат',
#  'бикластеризации',
#  'т',
#  'е',
#  'одновременной',
#  'кластеризации',
#  'слов',
#  'и',
#  'документов',
#  'с',
#  'точки',
#  'зрения',
#  'их',
#  'семантической',
#  'близости',
#  'в',
#  'пределах',
#  'текстовой',
#  'коллекции',
#  'При',
#  'нечеткой',
#  'кластеризации',
#  'любое',
#  'слово',
#  'или',
#  'документ',
#  'с',
#  'некоторой',
#  'вероятностью',
#  'относится',
#  'к',
#  'нескольким',
#  'темам',
#  'Можно',
#  'сказать',
#  'что',
#  'в',
#  'тематической',
#  'модели',
#  'описанию',
#  'слова',
#  'или',
#  'документа',
#  'в',
#  'текстовой',
#  'коллекции',
#  'ставится',
#  'в',
#  'соответствие',
#  'семейство',
#  'вероятностных',
#  'распределений',
#  'на',
#  'множестве',
#  'тем',
#  'Выявление',
#  'этих',
#  'распределений',
#  'составляет',
#  'основу',
#  'тематического',
#  'моделирования',
#  'В',
#  'тематических',
#  'моделях',
#  'используется',
#  'подход',
#  'к',
#  'обработке',
#  'текстовых',
#  'данных',
#  'называемый',
#  'мешок',
#  'слов',
#  'Это',
#  'значит',
#  'что',
#  'способ',
#  'упорядочения',
#  'слов',
#  'внутри',
#  'документов',
#  'не',
#  'имеет',
#  'значения',
#  'не',
#  'учитывается',
#  'порядок',
#  'слов',
#  'в',
#  'предложении',
#  'взаимное',
#  'расположение',
#  'слов',
#  'в',
#  'тексте',
#  'и',
#  'т',
#  'д',
#  'При',
#  'тематическом',
#  'моделировании',
#  'документ',
#  'описывается',
#  'как',
#  'набор',
#  'тем',
#  'порождаемых',
#  'семейством',
#  'распределений',
#  'В',
#  'то',
#  'же',
#  'время',
#  'любой',
#  'документ',
#  'в',
#  'корпусе',
#  'это',
#  'случайная',
#  'выборка',
#  'слов',
#  'порожденная',
#  'неким',
#  'множеством',
#  'тем',
#  'Исходя',
#  'из',
#  'этого',
#  'можно',
#  'установить',
#  'распределение',
#  'тем',
#  'в',
#  'корпусе',
#  'и',
#  'выяснить',
#  'каким',
#  'набором',
#  'тем',
#  'порождается',
#  'конкретный',
#  'документ',
#  'В',
#  'лингвистическом',
#  'смысле',
#  'тема',
#  'есть',
#  'набор',
#  'ключевых',
#  'слов',
#  'характеризующий',
#  'отдельный',
#  'документ',
#  'или',
#  'набор',
#  'документов',
#  'Например',
#  'в',
#  'тестовой',
#  'коллекции',
#  'могут',
#  'присутствовать',
#  'темы',
#  'Искусство',
#  'Дети',
#  'Образование',
#  'Жизнь',
#  'Ген',
#  'Мозг',
#  'и',
#  'т',
#  'д',
#  'ассоциируемые',
#  'с',
#  'наборами',
#  'слов',
#  'имеющих',
#  'определенную',
#  'частоту',
#  'встречаемости',
#  'в',
#  'текстовой',
#  'коллекции',
#  'и',
#  'вероятность',
#  'появления',
#  'в',
#  'документах',
#  'соответствующих',
#  'теме',
#  'см',
#  'рис',
#  'рис',
#  'Типы',
#  'тематических',
#  'моделей',
#  'текстов',
#  'В',
#  'практических',
#  'разработках',
#  'последних',
#  'лет',
#  'широко',
#  'используется',
#  'ряд',
#  'методов',
#  'тематического',
#  'моделирования',
#  'Среди',
#  'алгебраических',
#  'моделей',
#  'текста',
#  'на',
#  'которые',
#  'опираются',
#  'процедуры',
#  'тематического',
#  'моделирования',
#  'наиболее',
#  'распространены',
#  'стандартная',
#  'векторная',
#  'модель',
#  'текста',
#  'и',
#  'латентно',
#  'семантический',
#  'анализ',
#  'среди',
#  'вероятностных',
#  'генеративных',
#  'моделей',
#  'наиболее',
#  'всего',
#  'применяются',
#  'вероятностный',
#  'латентно',
#  'семантический',
#  'анализ',
#  'латентное',
#  'размещение',
#  'Дирихле',
#  'Дадим',
#  'их',
#  'краткую',
#  'характеристику',
#  'подробные',
#  'обзоры',
#  'см',
#  'и',
#  'т',
#  'д',
#  'В',
#  'текст',
#  'описывается',
#  'матрицей',
#  'совместной',
#  'встречаемости',
#  'термы',
#  'термы',
#  'или',
#  'термы',
#  'документы',
#  'Словам',
#  'или',
#  'текстам',
#  'ставятся',
#  'в',
#  'соответствие',
#  'вектора',
#  'в',
#  'мерном',
#  'пространстве',
#  'Соответственно',
#  'сравнение',
#  'векторов',
#  'как',
#  'правило',
#  'определение',
#  'косинуса',
#  'угла',
#  'между',
#  'векторами',
#  'позволяет',
#  'оценить',
#  'насколько',
#  'слово',
#  'характерно',
#  'для',
#  'некого',
#  'документа',
#  'насколько',
#  'связаны',
#  'слова',
#  'между',
#  'собой',
#  'в',
#  'документе',
#  'насколько',
#  'близки',
#  'документы',
#  'Недостатки',
#  'связаны',
#  'с',
#  'неудобством',
#  'использования',
#  'в',
#  'работе',
#  'с',
#  'текстами',
#  'больших',
#  'объемов',
#  'с',
#  'невозможностью',
#  'учесть',
#  'синонимические',
#  'отношения',
#  'между',
#  'словами',
#  'и',
#  'их',
#  'многозначность',
#  'Модель',
#  'наследует',
#  'основные',
#  'характеристики',
#  'однако',
#  'в',
#  'для',
#  'сокращения',
#  'размерности',
#  'признакового',
#  'пространства',
#  'и',
#  'для',
#  'выявления',
#  'наиболее',
#  'значимых',
#  'слов',
#  'в',
#  'текстах',
#  'используется',
#  'сингулярное',
#  'разложение',
#  'матрицы',
#  'совместной',
#  'встречаемости',
#  'В',
#  'отличие',
#  'от',
#  'модель',
#  'пригодна',
#  'для',
#  'описания',
#  'больших',
#  'текстовых',
#  'коллекций',
#  'и',
#  'позволяет',
#  'частично',
#  'учесть',
#  'контекстную',
#  'синонимию',
#  'однако',
#  'не',
#  'справляется',
#  'с',
#  'многозначностью',
#  'Также',
#  'в',
#  'сложно',
#  'заранее',
#  'задать',
#  'ожидаемое',
#  'число',
#  'тем',
#  'приписать',
#  'метку',
#  'темы',
#  'используя',
#  'какое',
#  'либо',
#  'ключевое',
#  'слово',
#  'из',
#  'этой',
#  'темы',
#  'Модель',
#  'являет',
#  'собой',
#  'вероятностную',
#  'модификацию',
#  'В',
#  'порождение',
#  'документа',
#  'характеризующих',
#  'его',
#  'тем',
#  'ключевых',
#  'слов',
#  'в',
#  'этой',
#  'теме',
#  'производится',
#  'в',
#  'соответствии',
#  'с',
#  'методом',
#  'Байеса',
#  'Модель',
#  'отчасти',
#  'учитывает',
#  'многозначность',
#  'слов',
#  'т',
#  'е',
#  'в',
#  'разных',
#  'значениях',
#  'многозначные',
#  'слова',
#  'могут',
#  'представлять',
#  'разные',
#  'темы',
#  'Основ',
#  'ные',
#  'недостатки',
#  'связаны',
#  'с',
#  'риском',
#  'переобучения',
#  'модели',
#  'а',
#  'также',
#  'со',
#  'сложностью',
#  'добавления',
#  'новых',
#  'документов',
#  'в',
#  'текстовую',
#  'коллекцию',
#  'Модель',
#  'сглаживает',
#  'шероховатости',
#  'имеющиеся',
#  'в',
#  'предыдущих',
#  'моделях',
#  'В',
#  'модели',
#  'опирающейся',
#  'на',
#  'распределение',
#  'Дирихле',
#  'каждая',
#  'тема',
#  'характеризуется',
#  'вероятностным',
#  'распределением',
#  'на',
#  'множестве',
#  'слов',
#  'в',
#  'текстовой',
#  'коллекции',
#  'а',
#  'документы',
#  'описываются',
#  'семейством',
#  'распределений',
#  'тем',
#  'позволяет',
#  'описывать',
#  'корпуса',
#  'текстов',
#  'очень',
#  'большого',
#  'объема',
#  'в',
#  'одну',
#  'тему',
#  'могут',
#  'попадать',
#  'слова',
#  'разных',
#  'частей',
#  'речи',
#  'однако',
#  'данная',
#  'модель',
#  'не',
#  'предусматривает',
#  'установление',
#  'связей',
#  'между',
#  'темами',
#  'Известны',
#  'также',
#  'и',
#  'другие',
#  'тематические',
#  'модели',
#  'в',
#  'той',
#  'или',
#  'иной',
#  'мере',
#  'связанные',
#  'с',
#  'упомянутыми',
#  'выше',
#  'это',
#  'в',
#  'частности',
#  'совместная',
#  'вероятностная',
#  'модель',
#  'скрытая',
#  'тематическая',
#  'марковская',
#  'модель',
#  'автортематическая',
#  'модель',
#  'модель',
#  'автор',
#  'получатель',
#  'корреляционная',
#  'тематическая',
#  'модель',
#  'и',
#  'т',
#  'п',
#  'Спецификация',
#  'тематических',
#  'моделей',
#  'может',
#  'быть',
#  'связана',
#  'с',
#  'различиями',
#  'на',
#  'уровне',
#  'лингвистической',
#  'обработки',
#  'входных',
#  'текстов',
#  'и',
#  'с',
#  'привлечением',
#  'аппарата',
#  'дистрибутивной',
#  'семантики',
#  'Большинство',
#  'разработчиков',
#  'языковых',
#  'ресурсов',
#  'склоняются',
#  'к',
#  'необходимости',
#  'интеграции',
#  'статистических',
#  'и',
#  'традиционных',
#  'лингвистических',
#  'методов',
#  'анализа',
#  'что',
#  'было',
#  'реализовано',
#  'например',
#  'в',
#  'моделях',
#  'семантического',
#  'пространства',
#  'и',
#  'т',
#  'п',
#  'Использование',
#  'многоуровневой',
#  'разметки',
#  'текстов',
#  'лемматизация',
#  'морфосинтаксическая',
#  'и',
#  'в',
#  'случае',
#  'доступности',
#  'семантическая',
#  'аннотация',
#  'учет',
#  'границ',
#  'синтаксических',
#  'групп',
#  'и',
#  'существующих',
#  'внутри',
#  'них',
#  'связей',
#  'ограничение',
#  'контекстного',
#  'окна',
#  'назначение',
#  'весов',
#  'контекстных',
#  'элементов',
#  'нормализация',
#  'значений',
#  'коэффициентов',
#  'совместной',
#  'встречаемости',
#  'свертка',
#  'признакового',
#  'пространства',
#  'эти',
#  'и',
#  'другие',
#  'методы',
#  'способствуют',
#  'повышению',
#  'качества',
#  'автоматической',
#  'обработки',
#  'текстов',
#  'Наши',
#  'эксперименты',
#  'В',
#  'выборе',
#  'инструмента',
#  'тематического',
#  'моделирования',
#  'мы',
#  'руководствовались',
#  'доступностью',
#  'гибкостью',
#  'и',
#  'устойчивостью',
#  'работы',
#  'поэтому',
#  'остановились',
#  'на',
#  'пакете',
#  'реализующем',
#  'модель',
#  'разработчики',
#  'Д',
#  'Ньюмэн',
#  'и',
#  'коллеги',
#  'Калифорнийский',
#  'университет',
#  'Доступные',
#  'для',
#  'исследователей',
#  'программные',
#  'пакеты',
#  'для',
#  'тематического',
#  'моделирования',
#  'приведены',
#  'в',
#  'конце',
#  'статьи',
#  'раздел',
#  'Программные',
#  'реализации',
#  'Программа',
#  'имеет',
#  'удобный',
#  'интерфейс',
#  'см',
#  'рис',
#  'Пользователь',
#  'загружает',
#  'текст',
#  'выбирает',
#  'параметры',
#  'обработки',
#  'число',
#  'тем',
#  'которые',
#  'затем',
#  'автоматически',
#  'генерируются',
#  'число',
#  'итераций',
#  'объем',
#  'списков',
#  'слов',
#  'в',
#  'темах',
#  'и',
#  'т',
#  'п',
#  'Выдача',
#  'результатов',
#  'работы',
#  'программы',
#  'содержит',
#  'списки',
#  'тем',
#  'и',
#  'распределение',
#  'тем',
#  'по',
#  'текстам',
#  'Эксперименты',
#  'проводились',
#  'с',
#  'текстами',
#  'в',
#  'латинице',
#  'на',
#  'английском',
#  'языке',
#  'В',
#  'качестве',
#  'текстовых',
#  'коллекций',
#  'использовались',
#  'публицистические',
#  'тексты',
#  'статьи',
#  'из',
#  'журнала',
#  'по',
#  'мировой',
#  'политике',
#  'статьи',
#  'экклезиологической',
#  'тематики',
#  'научные',
#  'тексты',
#  'материалы',
#  'конференции',
#  'научно',
#  'популярные',
#  'тексты',
#  'статьи',
#  'по',
#  'гомеопатии',
#  'и',
#  'растениеводству',
#  'художественные',
#  'тексты',
#  'рассказы',
#  'и',
#  'повести',
#  'Э',
#  'По',
#  'Ф',
#  'Старк',
#  'Дж',
#  'Даррелла',
#  'деловые',
#  'тексты',
#  'текст',
#  'конвенции',
#  'по',
#  'правам',
#  'человека',
#  'совершенно',
#  'обоснованно',
#  'используется',
#  'для',
#  'описания',
#  'тематической',
#  'структуры',
#  'больших',
#  'текстовых',
#  'коллекций',
#  'Однако',
#  'этот',
#  'метод',
#  'по',
#  'утверждению',
#  'специалистов',
#  'пригоден',
#  'и',
#  'для',
#  'текстов',
#  'умеренных',
#  'объемов',
#  'как',
#  'и',
#  ...]

# %%
text_words_1
# Out:
# ['введение',
#  'разработка',
#  'новых',
#  'подходов',
#  'к',
#  'лингвистическому',
#  'моделированию',
#  'позволяет',
#  'исследователям',
#  'по',
#  'новому',
#  'взглянуть',
#  'на',
#  'важный',
#  'класс',
#  'задач',
#  'автоматической',
#  'обработки',
#  'естественного',
#  'языка',
#  'а',
#  'именно',
#  'на',
#  'смысловую',
#  'компрессию',
#  'текста',
#  'производимую',
#  'при',
#  'автоматическом',
#  'выделении',
#  'ключевых',
#  'слов',
#  'и',
#  'словосочетаний',
#  'классификации',
#  'и',
#  'кластеризации',
#  'лексики',
#  'и',
#  'документов',
#  'в',
#  'корпусах',
#  'текстов',
#  'выделении',
#  'классов',
#  'слов',
#  'с',
#  'близкими',
#  'дистрибутивными',
#  'свойствами',
#  'оценке',
#  'семантической',
#  'однородности',
#  'неоднородности',
#  'текстов',
#  'и',
#  'т',
#  'п',
#  'ср',
#  'наши',
#  'эксперименты',
#  'описанные',
#  'в',
#  'статьях',
#  'митрофанова',
#  'мухин',
#  'паничева',
#  'митрофанова',
#  'митрофанова',
#  'грачкова',
#  'шиморина',
#  'в',
#  'данном',
#  'ряду',
#  'особняком',
#  'стоит',
#  'задача',
#  'тематического',
#  'моделирования',
#  'корпусов',
#  'текстов',
#  'в',
#  'последние',
#  'несколько',
#  'лет',
#  'арсенал',
#  'методов',
#  'тематического',
#  'моделирования',
#  'существенно',
#  'расширился',
#  'а',
#  'также',
#  'появились',
#  'доступные',
#  'исследователям',
#  'компьютерные',
#  'инструменты',
#  'автоматической',
#  'обработки',
#  'текстов',
#  'например',
#  'и',
#  'т',
#  'д',
#  'создающие',
#  'предпосылки',
#  'к',
#  'проведению',
#  'экспериментов',
#  'параллельно',
#  'расширяется',
#  'круг',
#  'практических',
#  'задач',
#  'которые',
#  'решаются',
#  'данными',
#  'средствами',
#  'особое',
#  'внимание',
#  'исследователей',
#  'сейчас',
#  'обращено',
#  'к',
#  'анализу',
#  'социальных',
#  'сетей',
#  'и',
#  'выявлению',
#  'тематической',
#  'структуры',
#  'сообществ',
#  'например',
#  'в',
#  'связи',
#  'с',
#  'этим',
#  'представляется',
#  'важным',
#  'оценить',
#  'особенности',
#  'различных',
#  'методов',
#  'тематического',
#  'моделирования',
#  'и',
#  'их',
#  'применимость',
#  'к',
#  'тем',
#  'или',
#  'иным',
#  'экспериментальным',
#  'данным',
#  'тематическое',
#  'моделирование',
#  'что',
#  'это',
#  'такое',
#  'тематическое',
#  'моделирование',
#  'способ',
#  'построения',
#  'модели',
#  'текстовой',
#  'коллекции',
#  'отражающий',
#  'переход',
#  'от',
#  'совокупности',
#  'документов',
#  'совокупности',
#  'слов',
#  'в',
#  'документах',
#  'коллекции',
#  'к',
#  'набору',
#  'тем',
#  'характеризующих',
#  'текстовую',
#  'коллекцию',
#  'тематические',
#  'модели',
#  'модели',
#  'со',
#  'скрытыми',
#  'переменными',
#  'факторами',
#  'задающими',
#  'тематику',
#  'текстов',
#  'для',
#  'выявления',
#  'этих',
#  'скрытых',
#  'переменных',
#  'лучше',
#  'всего',
#  'применять',
#  'нечеткую',
#  'кластеризацию',
#  'разбиение',
#  'текстов',
#  'на',
#  'пересекающиеся',
#  'классы',
#  'в',
#  'таком',
#  'случае',
#  'тема',
#  'это',
#  'результат',
#  'бикластеризации',
#  'т',
#  'е',
#  'одновременной',
#  'кластеризации',
#  'слов',
#  'и',
#  'документов',
#  'с',
#  'точки',
#  'зрения',
#  'их',
#  'семантической',
#  'близости',
#  'в',
#  'пределах',
#  'текстовой',
#  'коллекции',
#  'при',
#  'нечеткой',
#  'кластеризации',
#  'любое',
#  'слово',
#  'или',
#  'документ',
#  'с',
#  'некоторой',
#  'вероятностью',
#  'относится',
#  'к',
#  'нескольким',
#  'темам',
#  'можно',
#  'сказать',
#  'что',
#  'в',
#  'тематической',
#  'модели',
#  'описанию',
#  'слова',
#  'или',
#  'документа',
#  'в',
#  'текстовой',
#  'коллекции',
#  'ставится',
#  'в',
#  'соответствие',
#  'семейство',
#  'вероятностных',
#  'распределений',
#  'на',
#  'множестве',
#  'тем',
#  'выявление',
#  'этих',
#  'распределений',
#  'составляет',
#  'основу',
#  'тематического',
#  'моделирования',
#  'в',
#  'тематических',
#  'моделях',
#  'используется',
#  'подход',
#  'к',
#  'обработке',
#  'текстовых',
#  'данных',
#  'называемый',
#  'мешок',
#  'слов',
#  'это',
#  'значит',
#  'что',
#  'способ',
#  'упорядочения',
#  'слов',
#  'внутри',
#  'документов',
#  'не',
#  'имеет',
#  'значения',
#  'не',
#  'учитывается',
#  'порядок',
#  'слов',
#  'в',
#  'предложении',
#  'взаимное',
#  'расположение',
#  'слов',
#  'в',
#  'тексте',
#  'и',
#  'т',
#  'д',
#  'при',
#  'тематическом',
#  'моделировании',
#  'документ',
#  'описывается',
#  'как',
#  'набор',
#  'тем',
#  'порождаемых',
#  'семейством',
#  'распределений',
#  'в',
#  'то',
#  'же',
#  'время',
#  'любой',
#  'документ',
#  'в',
#  'корпусе',
#  'это',
#  'случайная',
#  'выборка',
#  'слов',
#  'порожденная',
#  'неким',
#  'множеством',
#  'тем',
#  'исходя',
#  'из',
#  'этого',
#  'можно',
#  'установить',
#  'распределение',
#  'тем',
#  'в',
#  'корпусе',
#  'и',
#  'выяснить',
#  'каким',
#  'набором',
#  'тем',
#  'порождается',
#  'конкретный',
#  'документ',
#  'в',
#  'лингвистическом',
#  'смысле',
#  'тема',
#  'есть',
#  'набор',
#  'ключевых',
#  'слов',
#  'характеризующий',
#  'отдельный',
#  'документ',
#  'или',
#  'набор',
#  'документов',
#  'например',
#  'в',
#  'тестовой',
#  'коллекции',
#  'могут',
#  'присутствовать',
#  'темы',
#  'искусство',
#  'дети',
#  'образование',
#  'жизнь',
#  'ген',
#  'мозг',
#  'и',
#  'т',
#  'д',
#  'ассоциируемые',
#  'с',
#  'наборами',
#  'слов',
#  'имеющих',
#  'определенную',
#  'частоту',
#  'встречаемости',
#  'в',
#  'текстовой',
#  'коллекции',
#  'и',
#  'вероятность',
#  'появления',
#  'в',
#  'документах',
#  'соответствующих',
#  'теме',
#  'см',
#  'рис',
#  'рис',
#  'типы',
#  'тематических',
#  'моделей',
#  'текстов',
#  'в',
#  'практических',
#  'разработках',
#  'последних',
#  'лет',
#  'широко',
#  'используется',
#  'ряд',
#  'методов',
#  'тематического',
#  'моделирования',
#  'среди',
#  'алгебраических',
#  'моделей',
#  'текста',
#  'на',
#  'которые',
#  'опираются',
#  'процедуры',
#  'тематического',
#  'моделирования',
#  'наиболее',
#  'распространены',
#  'стандартная',
#  'векторная',
#  'модель',
#  'текста',
#  'и',
#  'латентно',
#  'семантический',
#  'анализ',
#  'среди',
#  'вероятностных',
#  'генеративных',
#  'моделей',
#  'наиболее',
#  'всего',
#  'применяются',
#  'вероятностный',
#  'латентно',
#  'семантический',
#  'анализ',
#  'латентное',
#  'размещение',
#  'дирихле',
#  'дадим',
#  'их',
#  'краткую',
#  'характеристику',
#  'подробные',
#  'обзоры',
#  'см',
#  'и',
#  'т',
#  'д',
#  'в',
#  'текст',
#  'описывается',
#  'матрицей',
#  'совместной',
#  'встречаемости',
#  'термы',
#  'термы',
#  'или',
#  'термы',
#  'документы',
#  'словам',
#  'или',
#  'текстам',
#  'ставятся',
#  'в',
#  'соответствие',
#  'вектора',
#  'в',
#  'мерном',
#  'пространстве',
#  'соответственно',
#  'сравнение',
#  'векторов',
#  'как',
#  'правило',
#  'определение',
#  'косинуса',
#  'угла',
#  'между',
#  'векторами',
#  'позволяет',
#  'оценить',
#  'насколько',
#  'слово',
#  'характерно',
#  'для',
#  'некого',
#  'документа',
#  'насколько',
#  'связаны',
#  'слова',
#  'между',
#  'собой',
#  'в',
#  'документе',
#  'насколько',
#  'близки',
#  'документы',
#  'недостатки',
#  'связаны',
#  'с',
#  'неудобством',
#  'использования',
#  'в',
#  'работе',
#  'с',
#  'текстами',
#  'больших',
#  'объемов',
#  'с',
#  'невозможностью',
#  'учесть',
#  'синонимические',
#  'отношения',
#  'между',
#  'словами',
#  'и',
#  'их',
#  'многозначность',
#  'модель',
#  'наследует',
#  'основные',
#  'характеристики',
#  'однако',
#  'в',
#  'для',
#  'сокращения',
#  'размерности',
#  'признакового',
#  'пространства',
#  'и',
#  'для',
#  'выявления',
#  'наиболее',
#  'значимых',
#  'слов',
#  'в',
#  'текстах',
#  'используется',
#  'сингулярное',
#  'разложение',
#  'матрицы',
#  'совместной',
#  'встречаемости',
#  'в',
#  'отличие',
#  'от',
#  'модель',
#  'пригодна',
#  'для',
#  'описания',
#  'больших',
#  'текстовых',
#  'коллекций',
#  'и',
#  'позволяет',
#  'частично',
#  'учесть',
#  'контекстную',
#  'синонимию',
#  'однако',
#  'не',
#  'справляется',
#  'с',
#  'многозначностью',
#  'также',
#  'в',
#  'сложно',
#  'заранее',
#  'задать',
#  'ожидаемое',
#  'число',
#  'тем',
#  'приписать',
#  'метку',
#  'темы',
#  'используя',
#  'какое',
#  'либо',
#  'ключевое',
#  'слово',
#  'из',
#  'этой',
#  'темы',
#  'модель',
#  'являет',
#  'собой',
#  'вероятностную',
#  'модификацию',
#  'в',
#  'порождение',
#  'документа',
#  'характеризующих',
#  'его',
#  'тем',
#  'ключевых',
#  'слов',
#  'в',
#  'этой',
#  'теме',
#  'производится',
#  'в',
#  'соответствии',
#  'с',
#  'методом',
#  'байеса',
#  'модель',
#  'отчасти',
#  'учитывает',
#  'многозначность',
#  'слов',
#  'т',
#  'е',
#  'в',
#  'разных',
#  'значениях',
#  'многозначные',
#  'слова',
#  'могут',
#  'представлять',
#  'разные',
#  'темы',
#  'основ',
#  'ные',
#  'недостатки',
#  'связаны',
#  'с',
#  'риском',
#  'переобучения',
#  'модели',
#  'а',
#  'также',
#  'со',
#  'сложностью',
#  'добавления',
#  'новых',
#  'документов',
#  'в',
#  'текстовую',
#  'коллекцию',
#  'модель',
#  'сглаживает',
#  'шероховатости',
#  'имеющиеся',
#  'в',
#  'предыдущих',
#  'моделях',
#  'в',
#  'модели',
#  'опирающейся',
#  'на',
#  'распределение',
#  'дирихле',
#  'каждая',
#  'тема',
#  'характеризуется',
#  'вероятностным',
#  'распределением',
#  'на',
#  'множестве',
#  'слов',
#  'в',
#  'текстовой',
#  'коллекции',
#  'а',
#  'документы',
#  'описываются',
#  'семейством',
#  'распределений',
#  'тем',
#  'позволяет',
#  'описывать',
#  'корпуса',
#  'текстов',
#  'очень',
#  'большого',
#  'объема',
#  'в',
#  'одну',
#  'тему',
#  'могут',
#  'попадать',
#  'слова',
#  'разных',
#  'частей',
#  'речи',
#  'однако',
#  'данная',
#  'модель',
#  'не',
#  'предусматривает',
#  'установление',
#  'связей',
#  'между',
#  'темами',
#  'известны',
#  'также',
#  'и',
#  'другие',
#  'тематические',
#  'модели',
#  'в',
#  'той',
#  'или',
#  'иной',
#  'мере',
#  'связанные',
#  'с',
#  'упомянутыми',
#  'выше',
#  'это',
#  'в',
#  'частности',
#  'совместная',
#  'вероятностная',
#  'модель',
#  'скрытая',
#  'тематическая',
#  'марковская',
#  'модель',
#  'автортематическая',
#  'модель',
#  'модель',
#  'автор',
#  'получатель',
#  'корреляционная',
#  'тематическая',
#  'модель',
#  'и',
#  'т',
#  'п',
#  'спецификация',
#  'тематических',
#  'моделей',
#  'может',
#  'быть',
#  'связана',
#  'с',
#  'различиями',
#  'на',
#  'уровне',
#  'лингвистической',
#  'обработки',
#  'входных',
#  'текстов',
#  'и',
#  'с',
#  'привлечением',
#  'аппарата',
#  'дистрибутивной',
#  'семантики',
#  'большинство',
#  'разработчиков',
#  'языковых',
#  'ресурсов',
#  'склоняются',
#  'к',
#  'необходимости',
#  'интеграции',
#  'статистических',
#  'и',
#  'традиционных',
#  'лингвистических',
#  'методов',
#  'анализа',
#  'что',
#  'было',
#  'реализовано',
#  'например',
#  'в',
#  'моделях',
#  'семантического',
#  'пространства',
#  'и',
#  'т',
#  'п',
#  'использование',
#  'многоуровневой',
#  'разметки',
#  'текстов',
#  'лемматизация',
#  'морфосинтаксическая',
#  'и',
#  'в',
#  'случае',
#  'доступности',
#  'семантическая',
#  'аннотация',
#  'учет',
#  'границ',
#  'синтаксических',
#  'групп',
#  'и',
#  'существующих',
#  'внутри',
#  'них',
#  'связей',
#  'ограничение',
#  'контекстного',
#  'окна',
#  'назначение',
#  'весов',
#  'контекстных',
#  'элементов',
#  'нормализация',
#  'значений',
#  'коэффициентов',
#  'совместной',
#  'встречаемости',
#  'свертка',
#  'признакового',
#  'пространства',
#  'эти',
#  'и',
#  'другие',
#  'методы',
#  'способствуют',
#  'повышению',
#  'качества',
#  'автоматической',
#  'обработки',
#  'текстов',
#  'наши',
#  'эксперименты',
#  'в',
#  'выборе',
#  'инструмента',
#  'тематического',
#  'моделирования',
#  'мы',
#  'руководствовались',
#  'доступностью',
#  'гибкостью',
#  'и',
#  'устойчивостью',
#  'работы',
#  'поэтому',
#  'остановились',
#  'на',
#  'пакете',
#  'реализующем',
#  'модель',
#  'разработчики',
#  'д',
#  'ньюмэн',
#  'и',
#  'коллеги',
#  'калифорнийский',
#  'университет',
#  'доступные',
#  'для',
#  'исследователей',
#  'программные',
#  'пакеты',
#  'для',
#  'тематического',
#  'моделирования',
#  'приведены',
#  'в',
#  'конце',
#  'статьи',
#  'раздел',
#  'программные',
#  'реализации',
#  'программа',
#  'имеет',
#  'удобный',
#  'интерфейс',
#  'см',
#  'рис',
#  'пользователь',
#  'загружает',
#  'текст',
#  'выбирает',
#  'параметры',
#  'обработки',
#  'число',
#  'тем',
#  'которые',
#  'затем',
#  'автоматически',
#  'генерируются',
#  'число',
#  'итераций',
#  'объем',
#  'списков',
#  'слов',
#  'в',
#  'темах',
#  'и',
#  'т',
#  'п',
#  'выдача',
#  'результатов',
#  'работы',
#  'программы',
#  'содержит',
#  'списки',
#  'тем',
#  'и',
#  'распределение',
#  'тем',
#  'по',
#  'текстам',
#  'эксперименты',
#  'проводились',
#  'с',
#  'текстами',
#  'в',
#  'латинице',
#  'на',
#  'английском',
#  'языке',
#  'в',
#  'качестве',
#  'текстовых',
#  'коллекций',
#  'использовались',
#  'публицистические',
#  'тексты',
#  'статьи',
#  'из',
#  'журнала',
#  'по',
#  'мировой',
#  'политике',
#  'статьи',
#  'экклезиологической',
#  'тематики',
#  'научные',
#  'тексты',
#  'материалы',
#  'конференции',
#  'научно',
#  'популярные',
#  'тексты',
#  'статьи',
#  'по',
#  'гомеопатии',
#  'и',
#  'растениеводству',
#  'художественные',
#  'тексты',
#  'рассказы',
#  'и',
#  'повести',
#  'э',
#  'по',
#  'ф',
#  'старк',
#  'дж',
#  'даррелла',
#  'деловые',
#  'тексты',
#  'текст',
#  'конвенции',
#  'по',
#  'правам',
#  'человека',
#  'совершенно',
#  'обоснованно',
#  'используется',
#  'для',
#  'описания',
#  'тематической',
#  'структуры',
#  'больших',
#  'текстовых',
#  'коллекций',
#  'однако',
#  'этот',
#  'метод',
#  'по',
#  'утверждению',
#  'специалистов',
#  'пригоден',
#  'и',
#  'для',
#  'текстов',
#  'умеренных',
#  'объемов',
#  'как',
#  'и',
#  ...]

# %%
with open('/content/stopwords.txt', 'r', encoding='utf-8') as swl:
    swlist = []  # список стоп-слов из файла
    for i in swl:
        i = i.replace('\n','')
        swlist.append(i)
        # print(swlist)

len(swlist)
# Out:
# 995

# %%
text_words = []
for i in text_words_1:
    #i = morph.parse(i)[0].normal_form
    if i not in swlist:
        text_words.append(i)

text_words
# Out:
# ['введение',
#  'разработка',
#  'новых',
#  'подходов',
#  'лингвистическому',
#  'моделированию',
#  'позволяет',
#  'исследователям',
#  'новому',
#  'взглянуть',
#  'важный',
#  'класс',
#  'задач',
#  'автоматической',
#  'обработки',
#  'естественного',
#  'языка',
#  'смысловую',
#  'компрессию',
#  'текста',
#  'производимую',
#  'автоматическом',
#  'выделении',
#  'ключевых',
#  'слов',
#  'словосочетаний',
#  'классификации',
#  'кластеризации',
#  'лексики',
#  'документов',
#  'корпусах',
#  'текстов',
#  'выделении',
#  'классов',
#  'слов',
#  'близкими',
#  'дистрибутивными',
#  'свойствами',
#  'оценке',
#  'семантической',
#  'однородности',
#  'неоднородности',
#  'текстов',
#  'т',
#  'п',
#  'ср',
#  'наши',
#  'эксперименты',
#  'описанные',
#  'статьях',
#  'митрофанова',
#  'мухин',
#  'паничева',
#  'митрофанова',
#  'митрофанова',
#  'грачкова',
#  'шиморина',
#  'данном',
#  'ряду',
#  'особняком',
#  'стоит',
#  'задача',
#  'тематического',
#  'моделирования',
#  'корпусов',
#  'текстов',
#  'последние',
#  'несколько',
#  'лет',
#  'арсенал',
#  'методов',
#  'тематического',
#  'моделирования',
#  'существенно',
#  'расширился',
#  'появились',
#  'доступные',
#  'исследователям',
#  'компьютерные',
#  'инструменты',
#  'автоматической',
#  'обработки',
#  'текстов',
#  'т',
#  'д',
#  'создающие',
#  'предпосылки',
#  'проведению',
#  'экспериментов',
#  'параллельно',
#  'расширяется',
#  'круг',
#  'практических',
#  'задач',
#  'которые',
#  'решаются',
#  'данными',
#  'средствами',
#  'особое',
#  'внимание',
#  'исследователей',
#  'обращено',
#  'анализу',
#  'социальных',
#  'сетей',
#  'выявлению',
#  'тематической',
#  'структуры',
#  'сообществ',
#  'связи',
#  'этим',
#  'представляется',
#  'важным',
#  'оценить',
#  'особенности',
#  'различных',
#  'методов',
#  'тематического',
#  'моделирования',
#  'применимость',
#  'иным',
#  'экспериментальным',
#  'данным',
#  'тематическое',
#  'моделирование',
#  'такое',
#  'тематическое',
#  'моделирование',
#  'способ',
#  'построения',
#  'модели',
#  'текстовой',
#  'коллекции',
#  'отражающий',
#  'переход',
#  'совокупности',
#  'документов',
#  'совокупности',
#  'слов',
#  'документах',
#  'коллекции',
#  'набору',
#  'характеризующих',
#  'текстовую',
#  'коллекцию',
#  'тематические',
#  'модели',
#  'модели',
#  'скрытыми',
#  'переменными',
#  'факторами',
#  'задающими',
#  'тематику',
#  'текстов',
#  'выявления',
#  'этих',
#  'скрытых',
#  'переменных',
#  'применять',
#  'нечеткую',
#  'кластеризацию',
#  'разбиение',
#  'текстов',
#  'пересекающиеся',
#  'классы',
#  'таком',
#  'случае',
#  'тема',
#  'результат',
#  'бикластеризации',
#  'т',
#  'е',
#  'одновременной',
#  'кластеризации',
#  'слов',
#  'документов',
#  'точки',
#  'зрения',
#  'семантической',
#  'близости',
#  'пределах',
#  'текстовой',
#  'коллекции',
#  'нечеткой',
#  'кластеризации',
#  'любое',
#  'слово',
#  'документ',
#  'некоторой',
#  'вероятностью',
#  'относится',
#  'нескольким',
#  'темам',
#  'сказать',
#  'тематической',
#  'модели',
#  'описанию',
#  'слова',
#  'документа',
#  'текстовой',
#  'коллекции',
#  'ставится',
#  'соответствие',
#  'семейство',
#  'вероятностных',
#  'распределений',
#  'множестве',
#  'выявление',
#  'этих',
#  'распределений',
#  'составляет',
#  'основу',
#  'тематического',
#  'моделирования',
#  'тематических',
#  'моделях',
#  'используется',
#  'подход',
#  'обработке',
#  'текстовых',
#  'данных',
#  'называемый',
#  'мешок',
#  'слов',
#  'способ',
#  'упорядочения',
#  'слов',
#  'документов',
#  'имеет',
#  'значения',
#  'учитывается',
#  'порядок',
#  'слов',
#  'предложении',
#  'взаимное',
#  'расположение',
#  'слов',
#  'тексте',
#  'т',
#  'д',
#  'тематическом',
#  'моделировании',
#  'документ',
#  'описывается',
#  'набор',
#  'порождаемых',
#  'семейством',
#  'распределений',
#  'время',
#  'документ',
#  'корпусе',
#  'случайная',
#  'выборка',
#  'слов',
#  'порожденная',
#  'неким',
#  'множеством',
#  'исходя',
#  'этого',
#  'установить',
#  'распределение',
#  'корпусе',
#  'выяснить',
#  'каким',
#  'набором',
#  'порождается',
#  'конкретный',
#  'документ',
#  'лингвистическом',
#  'смысле',
#  'тема',
#  'есть',
#  'набор',
#  'ключевых',
#  'слов',
#  'характеризующий',
#  'отдельный',
#  'документ',
#  'набор',
#  'документов',
#  'тестовой',
#  'коллекции',
#  'могут',
#  'присутствовать',
#  'темы',
#  'искусство',
#  'дети',
#  'образование',
#  'жизнь',
#  'ген',
#  'мозг',
#  'т',
#  'д',
#  'ассоциируемые',
#  'наборами',
#  'слов',
#  'имеющих',
#  'определенную',
#  'частоту',
#  'встречаемости',
#  'текстовой',
#  'коллекции',
#  'вероятность',
#  'появления',
#  'документах',
#  'соответствующих',
#  'теме',
#  'рис',
#  'рис',
#  'типы',
#  'тематических',
#  'моделей',
#  'текстов',
#  'практических',
#  'разработках',
#  'последних',
#  'лет',
#  'широко',
#  'используется',
#  'ряд',
#  'методов',
#  'тематического',
#  'моделирования',
#  'алгебраических',
#  'моделей',
#  'текста',
#  'которые',
#  'опираются',
#  'процедуры',
#  'тематического',
#  'моделирования',
#  'распространены',
#  'стандартная',
#  'векторная',
#  'модель',
#  'текста',
#  'латентно',
#  'семантический',
#  'анализ',
#  'вероятностных',
#  'генеративных',
#  'моделей',
#  'применяются',
#  'вероятностный',
#  'латентно',
#  'семантический',
#  'анализ',
#  'латентное',
#  'размещение',
#  'дирихле',
#  'дадим',
#  'краткую',
#  'характеристику',
#  'подробные',
#  'обзоры',
#  'т',
#  'д',
#  'текст',
#  'описывается',
#  'матрицей',
#  'совместной',
#  'встречаемости',
#  'термы',
#  'термы',
#  'термы',
#  'документы',
#  'словам',
#  'текстам',
#  'ставятся',
#  'соответствие',
#  'вектора',
#  'мерном',
#  'пространстве',
#  'сравнение',
#  'векторов',
#  'правило',
#  'определение',
#  'косинуса',
#  'угла',
#  'векторами',
#  'позволяет',
#  'оценить',
#  'насколько',
#  'слово',
#  'характерно',
#  'документа',
#  'насколько',
#  'связаны',
#  'слова',
#  'собой',
#  'документе',
#  'насколько',
#  'близки',
#  'документы',
#  'недостатки',
#  'связаны',
#  'неудобством',
#  'использования',
#  'работе',
#  'текстами',
#  'больших',
#  'объемов',
#  'невозможностью',
#  'учесть',
#  'синонимические',
#  'отношения',
#  'словами',
#  'многозначность',
#  'модель',
#  'наследует',
#  'основные',
#  'характеристики',
#  'сокращения',
#  'размерности',
#  'признакового',
#  'пространства',
#  'выявления',
#  'значимых',
#  'слов',
#  'текстах',
#  'используется',
#  'сингулярное',
#  'разложение',
#  'матрицы',
#  'совместной',
#  'встречаемости',
#  'отличие',
#  'модель',
#  'пригодна',
#  'описания',
#  'больших',
#  'текстовых',
#  'коллекций',
#  'позволяет',
#  'частично',
#  'учесть',
#  'контекстную',
#  'синонимию',
#  'справляется',
#  'многозначностью',
#  'сложно',
#  'заранее',
#  'задать',
#  'ожидаемое',
#  'число',
#  'приписать',
#  'метку',
#  'темы',
#  'используя',
#  'какое',
#  'ключевое',
#  'слово',
#  'этой',
#  'темы',
#  'модель',
#  'являет',
#  'собой',
#  'вероятностную',
#  'модификацию',
#  'порождение',
#  'документа',
#  'характеризующих',
#  'ключевых',
#  'слов',
#  'этой',
#  'теме',
#  'производится',
#  'соответствии',
#  'методом',
#  'байеса',
#  'модель',
#  'отчасти',
#  'учитывает',
#  'многозначность',
#  'слов',
#  'т',
#  'е',
#  'разных',
#  'значениях',
#  'многозначные',
#  'слова',
#  'могут',
#  'представлять',
#  'разные',
#  'темы',
#  'основ',
#  'ные',
#  'недостатки',
#  'связаны',
#  'риском',
#  'переобучения',
#  'модели',
#  'сложностью',
#  'добавления',
#  'новых',
#  'документов',
#  'текстовую',
#  'коллекцию',
#  'модель',
#  'сглаживает',
#  'шероховатости',
#  'имеющиеся',
#  'предыдущих',
#  'моделях',
#  'модели',
#  'опирающейся',
#  'распределение',
#  'дирихле',
#  'каждая',
#  'тема',
#  'характеризуется',
#  'вероятностным',
#  'распределением',
#  'множестве',
#  'слов',
#  'текстовой',
#  'коллекции',
#  'документы',
#  'описываются',
#  'семейством',
#  'распределений',
#  'позволяет',
#  'описывать',
#  'корпуса',
#  'текстов',
#  'большого',
#  'объема',
#  'одну',
#  'тему',
#  'могут',
#  'попадать',
#  'слова',
#  'разных',
#  'частей',
#  'речи',
#  'данная',
#  'модель',
#  'предусматривает',
#  'установление',
#  'связей',
#  'темами',
#  'известны',
#  'тематические',
#  'модели',
#  'мере',
#  'связанные',
#  'упомянутыми',
#  'частности',
#  'совместная',
#  'вероятностная',
#  'модель',
#  'скрытая',
#  'тематическая',
#  'марковская',
#  'модель',
#  'автортематическая',
#  'модель',
#  'модель',
#  'автор',
#  'получатель',
#  'корреляционная',
#  'тематическая',
#  'модель',
#  'т',
#  'п',
#  'спецификация',
#  'тематических',
#  'моделей',
#  'быть',
#  'связана',
#  'различиями',
#  'уровне',
#  'лингвистической',
#  'обработки',
#  'входных',
#  'текстов',
#  'привлечением',
#  'аппарата',
#  'дистрибутивной',
#  'семантики',
#  'большинство',
#  'разработчиков',
#  'языковых',
#  'ресурсов',
#  'склоняются',
#  'необходимости',
#  'интеграции',
#  'статистических',
#  'традиционных',
#  'лингвистических',
#  'методов',
#  'анализа',
#  'реализовано',
#  'моделях',
#  'семантического',
#  'пространства',
#  'т',
#  'п',
#  'использование',
#  'многоуровневой',
#  'разметки',
#  'текстов',
#  'лемматизация',
#  'морфосинтаксическая',
#  'случае',
#  'доступности',
#  'семантическая',
#  'аннотация',
#  'учет',
#  'границ',
#  'синтаксических',
#  'групп',
#  'существующих',
#  'них',
#  'связей',
#  'ограничение',
#  'контекстного',
#  'окна',
#  'назначение',
#  'весов',
#  'контекстных',
#  'элементов',
#  'нормализация',
#  'значений',
#  'коэффициентов',
#  'совместной',
#  'встречаемости',
#  'свертка',
#  'признакового',
#  'пространства',
#  'эти',
#  'методы',
#  'способствуют',
#  'повышению',
#  'качества',
#  'автоматической',
#  'обработки',
#  'текстов',
#  'наши',
#  'эксперименты',
#  'выборе',
#  'инструмента',
#  'тематического',
#  'моделирования',
#  'руководствовались',
#  'доступностью',
#  'гибкостью',
#  'устойчивостью',
#  'работы',
#  'остановились',
#  'пакете',
#  'реализующем',
#  'модель',
#  'разработчики',
#  'д',
#  'ньюмэн',
#  'коллеги',
#  'калифорнийский',
#  'университет',
#  'доступные',
#  'исследователей',
#  'программные',
#  'пакеты',
#  'тематического',
#  'моделирования',
#  'приведены',
#  'конце',
#  'статьи',
#  'раздел',
#  'программные',
#  'реализации',
#  'программа',
#  'имеет',
#  'удобный',
#  'интерфейс',
#  'рис',
#  'пользователь',
#  'загружает',
#  'текст',
#  'выбирает',
#  'параметры',
#  'обработки',
#  'число',
#  'которые',
#  'автоматически',
#  'генерируются',
#  'число',
#  'итераций',
#  'объем',
#  'списков',
#  'слов',
#  'темах',
#  'т',
#  'п',
#  'выдача',
#  'результатов',
#  'работы',
#  'программы',
#  'содержит',
#  'списки',
#  'распределение',
#  'текстам',
#  'эксперименты',
#  'проводились',
#  'текстами',
#  'латинице',
#  'английском',
#  'языке',
#  'качестве',
#  'текстовых',
#  'коллекций',
#  'использовались',
#  'публицистические',
#  'тексты',
#  'статьи',
#  'журнала',
#  'мировой',
#  'политике',
#  'статьи',
#  'экклезиологической',
#  'тематики',
#  'научные',
#  'тексты',
#  'материалы',
#  'конференции',
#  'научно',
#  'популярные',
#  'тексты',
#  'статьи',
#  'гомеопатии',
#  'растениеводству',
#  'художественные',
#  'тексты',
#  'рассказы',
#  'повести',
#  'ф',
#  'старк',
#  'дж',
#  'даррелла',
#  'деловые',
#  'тексты',
#  'текст',
#  'конвенции',
#  'правам',
#  'человека',
#  'обоснованно',
#  'используется',
#  'описания',
#  'тематической',
#  'структуры',
#  'больших',
#  'текстовых',
#  'коллекций',
#  'метод',
#  'утверждению',
#  'специалистов',
#  'пригоден',
#  'текстов',
#  'умеренных',
#  'объемов',
#  'нашем',
#  'случае',
#  'число',
#  'обработке',
#  'больших',
#  'текстов',
#  'модели',
#  'варьироваться',
#  'нескольких',
#  'десятков',
#  'нескольких',
#  'сотен',
#  'средней',
#  'текстовой',
#  'коллекции',
#  'быть',
#  'достаточно',
#  'эксперименты',
#  'выполнялись',
#  'пошагово',
#  'тема',
#  'темы',
#  'приведем',
#  'отдельные',
#  'иллюстрации',
#  'дающие',
#  'представление',
#  'результатах',
#  'экспериментов',
#  'прокомментируем',
#  'полученные',
#  'данные',
#  'пример',
#  'проведено',
#  'тематическое',
#  'моделирование',
#  'научных',
#  'текстов',
#  'материалов',
#  'конференции',
#  'компьютерной',
#  'лингвистике',
#  'общий',
#  'объем',
#  'текстов',
#  'составляет',
#  'примерно',
#  'тыс',
#  'имеется',
#  'подробная',
#  'информация',
#  'разработчиков',
#  'данной',
#  'текстовой',
#  'коллекции',
#  'том',
#  'числе',
#  'описание',
#  'основных',
#  'результаты',
#  'обработки',
#  'текстов',
#  'основе',
#  'приведены',
#  'табл',
#  'заметить',
#  'перечень',
#  'наполнение',
#  'адекватно',
#  'отражают',
#  'содержательное',
#  'разнообразие',
#  'текстовой',
#  'коллекции',
#  'охватывающей',
#  'направления',
#  'компьютерной',
#  'лингвистики',
#  'полученные',
#  'темы',
#  'редким',
#  'исключением',
#  'отличаются',
#  'компактностью',
#  'низкой',
#  'долей',
#  'шума',
#  'тема',
#  'имеет',
#  'следующее',
#  'наполнение',
#  'имели',
#  'возможность',
#  'сравнить',
#  'эти',
#  'данные',
#  'ранними',
#  'результатами',
#  'автоматического',
#  'выделения',
#  'ключевых',
#  'слов',
#  'полученных',
#  'работе',
#  'стандартной',
#  'векторной',
#  'моделью',
#  'перечень',
#  'ключевых',
#  'слов',
#  'ассоциированных',
#  'темой',
#  'заметно',
#  'значимыми',
#  'этом',
#  'перечне',
#  'являются',
#  'первые',
#  'три',
#  'ключевых',
#  'слова',
#  'том',
#  'числе',
#  'имена',
#  'собственные',
#  'семантике',
#  'связаны',
#  'темой',
#  'напрямую',
#  'всё',
#  'свидетельствует',
#  'пользу',
#  'пример',
#  'проанализированы',
#  'публицистические',
#  'тексты',
#  'истории',
#  'косово',
#  'метохии',
#  'объем',
#  'каждого',
#  'тыс',
#  'тыс',
#  'рассматриваемые',
#  'тексты',
#  'имеют',
#  'частично',
#  'пересекающуюся',
#  'тематику',
#  'православие',
#  'политическая',
#  'история',
#  'нашло',
#  'отражение',
#  'наборах',
#  'ключевых',
#  'слов',
#  'характеризующих',
#  'указанные',
#  'тексты',
#  'имен',
#  'собственных',
#  'общих',
#  'двух',
#  'текстов',
#  'т',
#  'д',
#  'темы',
#  'первого',
#  'текста',
#  'содержат',
#  'слова',
#  'т',
#  'д',
#  'темах',
#  'второго',
#  'текста',
#  'приводятся',
#  'слова',
#  'т',
#  'д',
#  'результаты',
#  'автоматической',
#  'обработки',
#  'текстов',
#  'проиллюстрированы',
#  'табл',
#  'пример',
#  'провели',
#  'автоматическую',
#  'обработку',
#  'текстов',
#  'гомеопатии',
#  'растениеводству',
#  'рассматривались',
#  'описания',
#  'лекарственных',
#  'средств',
#  'некоторых',
#  'других',
#  'имеющиеся',
#  'трех',
#  'источниках',
#  'книга',
#  'дж',
#  'кента',
#  'которая',
#  'считается',
#  'авторитетным',
#  'справочником',
#  'гомеопатии',
#  'энциклопедия',
#  'современных',
#  'растений',
#  'грив',
#  'база',
#  'данных',
#  'растениеводству',
#  'табл',
#  'сравнение',
#  'автоматически',
#  'сформированных',
#  'вошедших',
#  'них',
#  'слов',
#  'дает',
#  'возможность',
#  'заметить',
#  'первый',
#  'источник',
#  'предсказуемым',
#  'образом',
#  'содержит',
#  'сведения',
#  'симптомах',
#  'связанных',
#  'лекарственными',
#  'средствами',
#  'т',
#  'д',
#  ...]

# %%
len(text_words)
# Out:
# 1095

# %%
frequency={}
for word in text_words:  # добываем частоты слов
    count = frequency.get(word,0)  # создаём словарь СЛОВО и ЧАСТОТА
    frequency[word] = count + 1  # увеличиваем ЧАСТОТУ при встрече одинаковых лемм слова

frequency
# Out:
# {'введение': 1,
#  'разработка': 1,
#  'новых': 2,
#  'подходов': 1,
#  'лингвистическому': 1,
#  'моделированию': 2,
#  'позволяет': 4,
#  'исследователям': 2,
#  'новому': 1,
#  'взглянуть': 1,
#  'важный': 1,
#  'класс': 1,
#  'задач': 3,
#  'автоматической': 4,
#  'обработки': 7,
#  'естественного': 1,
#  'языка': 1,
#  'смысловую': 1,
#  'компрессию': 1,
#  'текста': 6,
#  'производимую': 1,
#  'автоматическом': 1,
#  'выделении': 2,
#  'ключевых': 7,
#  'слов': 20,
#  'словосочетаний': 1,
#  'классификации': 1,
#  'кластеризации': 3,
#  'лексики': 1,
#  'документов': 6,
#  'корпусах': 1,
#  'текстов': 20,
#  'классов': 1,
#  'близкими': 1,
#  'дистрибутивными': 1,
#  'свойствами': 1,
#  'оценке': 1,
#  'семантической': 2,
#  'однородности': 1,
#  'неоднородности': 1,
#  'т': 19,
#  'п': 6,
#  'ср': 1,
#  'наши': 2,
#  'эксперименты': 4,
#  'описанные': 1,
#  'статьях': 1,
#  'митрофанова': 3,
#  'мухин': 1,
#  'паничева': 1,
#  'грачкова': 1,
#  'шиморина': 1,
#  'данном': 1,
#  'ряду': 1,
#  'особняком': 1,
#  'стоит': 1,
#  'задача': 1,
#  'тематического': 10,
#  'моделирования': 10,
#  'корпусов': 1,
#  'последние': 1,
#  'несколько': 1,
#  'лет': 2,
#  'арсенал': 1,
#  'методов': 4,
#  'существенно': 1,
#  'расширился': 1,
#  'появились': 1,
#  'доступные': 2,
#  'компьютерные': 1,
#  'инструменты': 1,
#  'д': 12,
#  'создающие': 1,
#  'предпосылки': 1,
#  'проведению': 2,
#  'экспериментов': 4,
#  'параллельно': 1,
#  'расширяется': 1,
#  'круг': 1,
#  'практических': 2,
#  'которые': 3,
#  'решаются': 1,
#  'данными': 1,
#  'средствами': 2,
#  'особое': 1,
#  'внимание': 1,
#  'исследователей': 2,
#  'обращено': 1,
#  'анализу': 1,
#  'социальных': 1,
#  'сетей': 1,
#  'выявлению': 1,
#  'тематической': 3,
#  'структуры': 2,
#  'сообществ': 1,
#  'связи': 1,
#  'этим': 1,
#  'представляется': 1,
#  'важным': 1,
#  'оценить': 2,
#  'особенности': 1,
#  'различных': 1,
#  'применимость': 1,
#  'иным': 1,
#  'экспериментальным': 1,
#  'данным': 1,
#  'тематическое': 3,
#  'моделирование': 3,
#  'такое': 1,
#  'способ': 2,
#  'построения': 1,
#  'модели': 9,
#  'текстовой': 8,
#  'коллекции': 11,
#  'отражающий': 1,
#  'переход': 1,
#  'совокупности': 2,
#  'документах': 2,
#  'набору': 1,
#  'характеризующих': 3,
#  'текстовую': 2,
#  'коллекцию': 2,
#  'тематические': 2,
#  'скрытыми': 1,
#  'переменными': 1,
#  'факторами': 1,
#  'задающими': 1,
#  'тематику': 2,
#  'выявления': 2,
#  'этих': 4,
#  'скрытых': 1,
#  'переменных': 1,
#  'применять': 1,
#  'нечеткую': 1,
#  'кластеризацию': 1,
#  'разбиение': 1,
#  'пересекающиеся': 1,
#  'классы': 1,
#  'таком': 1,
#  'случае': 3,
#  'тема': 5,
#  'результат': 1,
#  'бикластеризации': 1,
#  'е': 2,
#  'одновременной': 1,
#  'точки': 1,
#  'зрения': 1,
#  'близости': 1,
#  'пределах': 1,
#  'нечеткой': 1,
#  'любое': 1,
#  'слово': 3,
#  'документ': 5,
#  'некоторой': 1,
#  'вероятностью': 1,
#  'относится': 1,
#  'нескольким': 1,
#  'темам': 1,
#  'сказать': 1,
#  'описанию': 1,
#  'слова': 7,
#  'документа': 3,
#  'ставится': 1,
#  'соответствие': 2,
#  'семейство': 1,
#  'вероятностных': 2,
#  'распределений': 4,
#  'множестве': 2,
#  'выявление': 1,
#  'составляет': 2,
#  'основу': 1,
#  'тематических': 3,
#  'моделях': 3,
#  'используется': 4,
#  'подход': 1,
#  'обработке': 2,
#  'текстовых': 4,
#  'данных': 2,
#  'называемый': 1,
#  'мешок': 1,
#  'упорядочения': 1,
#  'имеет': 3,
#  'значения': 1,
#  'учитывается': 1,
#  'порядок': 1,
#  'предложении': 1,
#  'взаимное': 1,
#  'расположение': 1,
#  'тексте': 1,
#  'тематическом': 1,
#  'моделировании': 1,
#  'описывается': 2,
#  'набор': 3,
#  'порождаемых': 1,
#  'семейством': 2,
#  'время': 1,
#  'корпусе': 2,
#  'случайная': 1,
#  'выборка': 1,
#  'порожденная': 1,
#  'неким': 1,
#  'множеством': 1,
#  'исходя': 1,
#  'этого': 1,
#  'установить': 1,
#  'распределение': 3,
#  'выяснить': 1,
#  'каким': 1,
#  'набором': 1,
#  'порождается': 1,
#  'конкретный': 1,
#  'лингвистическом': 1,
#  'смысле': 1,
#  'есть': 1,
#  'характеризующий': 1,
#  'отдельный': 1,
#  'тестовой': 1,
#  'могут': 3,
#  'присутствовать': 1,
#  'темы': 7,
#  'искусство': 1,
#  'дети': 1,
#  'образование': 1,
#  'жизнь': 1,
#  'ген': 1,
#  'мозг': 1,
#  'ассоциируемые': 1,
#  'наборами': 1,
#  'имеющих': 1,
#  'определенную': 1,
#  'частоту': 1,
#  'встречаемости': 4,
#  'вероятность': 1,
#  'появления': 1,
#  'соответствующих': 1,
#  'теме': 2,
#  'рис': 3,
#  'типы': 1,
#  'моделей': 4,
#  'разработках': 1,
#  'последних': 1,
#  'широко': 1,
#  'ряд': 1,
#  'алгебраических': 1,
#  'опираются': 1,
#  'процедуры': 1,
#  'распространены': 1,
#  'стандартная': 1,
#  'векторная': 1,
#  'модель': 14,
#  'латентно': 2,
#  'семантический': 2,
#  'анализ': 2,
#  'генеративных': 1,
#  'применяются': 1,
#  'вероятностный': 1,
#  'латентное': 1,
#  'размещение': 1,
#  'дирихле': 2,
#  'дадим': 1,
#  'краткую': 1,
#  'характеристику': 1,
#  'подробные': 1,
#  'обзоры': 1,
#  'текст': 3,
#  'матрицей': 1,
#  'совместной': 3,
#  'термы': 3,
#  'документы': 3,
#  'словам': 1,
#  'текстам': 2,
#  'ставятся': 1,
#  'вектора': 1,
#  'мерном': 1,
#  'пространстве': 1,
#  'сравнение': 2,
#  'векторов': 1,
#  'правило': 1,
#  'определение': 1,
#  'косинуса': 1,
#  'угла': 1,
#  'векторами': 1,
#  'насколько': 3,
#  'характерно': 1,
#  'связаны': 5,
#  'собой': 2,
#  'документе': 1,
#  'близки': 1,
#  'недостатки': 2,
#  'неудобством': 1,
#  'использования': 1,
#  'работе': 3,
#  'текстами': 3,
#  'больших': 4,
#  'объемов': 2,
#  'невозможностью': 1,
#  'учесть': 2,
#  'синонимические': 1,
#  'отношения': 1,
#  'словами': 1,
#  'многозначность': 2,
#  'наследует': 1,
#  'основные': 1,
#  'характеристики': 1,
#  'сокращения': 1,
#  'размерности': 1,
#  'признакового': 2,
#  'пространства': 3,
#  'значимых': 1,
#  'текстах': 1,
#  'сингулярное': 1,
#  'разложение': 1,
#  'матрицы': 1,
#  'отличие': 1,
#  'пригодна': 1,
#  'описания': 3,
#  'коллекций': 3,
#  'частично': 2,
#  'контекстную': 1,
#  'синонимию': 1,
#  'справляется': 1,
#  'многозначностью': 1,
#  'сложно': 1,
#  'заранее': 1,
#  'задать': 1,
#  'ожидаемое': 1,
#  'число': 4,
#  'приписать': 1,
#  'метку': 1,
#  'используя': 1,
#  'какое': 1,
#  'ключевое': 1,
#  'этой': 2,
#  'являет': 1,
#  'вероятностную': 1,
#  'модификацию': 1,
#  'порождение': 1,
#  'производится': 1,
#  'соответствии': 1,
#  'методом': 1,
#  'байеса': 1,
#  'отчасти': 1,
#  'учитывает': 1,
#  'разных': 2,
#  'значениях': 1,
#  'многозначные': 1,
#  'представлять': 1,
#  'разные': 1,
#  'основ': 1,
#  'ные': 1,
#  'риском': 1,
#  'переобучения': 1,
#  'сложностью': 1,
#  'добавления': 1,
#  'сглаживает': 1,
#  'шероховатости': 1,
#  'имеющиеся': 2,
#  'предыдущих': 1,
#  'опирающейся': 1,
#  'каждая': 1,
#  'характеризуется': 1,
#  'вероятностным': 1,
#  'распределением': 1,
#  'описываются': 1,
#  'описывать': 1,
#  'корпуса': 1,
#  'большого': 1,
#  'объема': 1,
#  'одну': 1,
#  'тему': 1,
#  'попадать': 1,
#  'частей': 1,
#  'речи': 1,
#  'данная': 1,
#  'предусматривает': 1,
#  'установление': 1,
#  'связей': 2,
#  'темами': 1,
#  'известны': 1,
#  'мере': 1,
#  'связанные': 1,
#  'упомянутыми': 1,
#  'частности': 2,
#  'совместная': 1,
#  'вероятностная': 1,
#  'скрытая': 1,
#  'тематическая': 2,
#  'марковская': 1,
#  'автортематическая': 1,
#  'автор': 1,
#  'получатель': 1,
#  'корреляционная': 1,
#  'спецификация': 1,
#  'быть': 2,
#  'связана': 1,
#  'различиями': 1,
#  'уровне': 1,
#  'лингвистической': 1,
#  'входных': 1,
#  'привлечением': 1,
#  'аппарата': 1,
#  'дистрибутивной': 1,
#  'семантики': 1,
#  'большинство': 1,
#  'разработчиков': 2,
#  'языковых': 1,
#  'ресурсов': 1,
#  'склоняются': 1,
#  'необходимости': 1,
#  'интеграции': 1,
#  'статистических': 1,
#  'традиционных': 1,
#  'лингвистических': 1,
#  'анализа': 1,
#  'реализовано': 1,
#  'семантического': 2,
#  'использование': 1,
#  'многоуровневой': 1,
#  'разметки': 1,
#  'лемматизация': 1,
#  'морфосинтаксическая': 1,
#  'доступности': 1,
#  'семантическая': 1,
#  'аннотация': 1,
#  'учет': 1,
#  'границ': 1,
#  'синтаксических': 1,
#  'групп': 1,
#  'существующих': 1,
#  'них': 2,
#  'ограничение': 1,
#  'контекстного': 1,
#  'окна': 1,
#  'назначение': 1,
#  'весов': 1,
#  'контекстных': 1,
#  'элементов': 1,
#  'нормализация': 1,
#  'значений': 1,
#  'коэффициентов': 1,
#  'свертка': 1,
#  'эти': 2,
#  'методы': 1,
#  'способствуют': 1,
#  'повышению': 1,
#  'качества': 1,
#  'выборе': 1,
#  'инструмента': 1,
#  'руководствовались': 1,
#  'доступностью': 1,
#  'гибкостью': 1,
#  'устойчивостью': 1,
#  'работы': 2,
#  'остановились': 1,
#  'пакете': 1,
#  'реализующем': 1,
#  'разработчики': 1,
#  'ньюмэн': 1,
#  'коллеги': 1,
#  'калифорнийский': 1,
#  'университет': 1,
#  'программные': 2,
#  'пакеты': 1,
#  'приведены': 2,
#  'конце': 1,
#  'статьи': 4,
#  'раздел': 1,
#  'реализации': 1,
#  'программа': 1,
#  'удобный': 1,
#  'интерфейс': 1,
#  'пользователь': 1,
#  'загружает': 1,
#  'выбирает': 1,
#  'параметры': 1,
#  'автоматически': 2,
#  'генерируются': 1,
#  'итераций': 1,
#  'объем': 3,
#  'списков': 1,
#  'темах': 2,
#  'выдача': 1,
#  'результатов': 1,
#  'программы': 1,
#  'содержит': 2,
#  'списки': 1,
#  'проводились': 1,
#  'латинице': 1,
#  'английском': 1,
#  'языке': 1,
#  'качестве': 1,
#  'использовались': 1,
#  'публицистические': 2,
#  'тексты': 8,
#  'журнала': 1,
#  'мировой': 1,
#  'политике': 1,
#  'экклезиологической': 1,
#  'тематики': 2,
#  'научные': 1,
#  'материалы': 1,
#  'конференции': 2,
#  'научно': 1,
#  'популярные': 1,
#  'гомеопатии': 3,
#  'растениеводству': 3,
#  'художественные': 1,
#  'рассказы': 1,
#  'повести': 1,
#  'ф': 1,
#  'старк': 1,
#  'дж': 2,
#  'даррелла': 1,
#  'деловые': 1,
#  'конвенции': 1,
#  'правам': 1,
#  'человека': 1,
#  'обоснованно': 1,
#  'метод': 1,
#  'утверждению': 1,
#  'специалистов': 1,
#  'пригоден': 1,
#  'умеренных': 1,
#  'нашем': 1,
#  'варьироваться': 1,
#  'нескольких': 2,
#  'десятков': 1,
#  'сотен': 1,
#  'средней': 1,
#  'достаточно': 1,
#  'выполнялись': 1,
#  'пошагово': 1,
#  'приведем': 1,
#  'отдельные': 1,
#  'иллюстрации': 1,
#  'дающие': 1,
#  'представление': 1,
#  'результатах': 1,
#  'прокомментируем': 1,
#  'полученные': 2,
#  'данные': 2,
#  'пример': 3,
#  'проведено': 1,
#  'научных': 1,
#  'материалов': 1,
#  'компьютерной': 2,
#  'лингвистике': 1,
#  'общий': 1,
#  'примерно': 1,
#  'тыс': 3,
#  'имеется': 1,
#  'подробная': 1,
#  'информация': 1,
#  'данной': 1,
#  'том': 2,
#  'числе': 2,
#  'описание': 1,
#  'основных': 1,
#  'результаты': 2,
#  'основе': 1,
#  'табл': 3,
#  'заметить': 2,
#  'перечень': 2,
#  'наполнение': 2,
#  'адекватно': 1,
#  'отражают': 1,
#  'содержательное': 1,
#  'разнообразие': 1,
#  'охватывающей': 1,
#  'направления': 1,
#  'лингвистики': 1,
#  'редким': 1,
#  'исключением': 1,
#  'отличаются': 1,
#  'компактностью': 1,
#  'низкой': 1,
#  'долей': 1,
#  'шума': 1,
#  'следующее': 1,
#  'имели': 1,
#  'возможность': 2,
#  'сравнить': 1,
#  'ранними': 1,
#  'результатами': 1,
#  'автоматического': 1,
#  'выделения': 1,
#  'полученных': 1,
#  'стандартной': 1,
#  'векторной': 1,
#  'моделью': 1,
#  'ассоциированных': 1,
#  'темой': 2,
#  'заметно': 1,
#  'значимыми': 1,
#  'этом': 1,
#  'перечне': 1,
#  'являются': 1,
#  'первые': 1,
#  'три': 1,
#  'имена': 1,
#  'собственные': 1,
#  'семантике': 1,
#  'напрямую': 1,
#  'всё': 1,
#  'свидетельствует': 1,
#  'пользу': 1,
#  'проанализированы': 1,
#  'истории': 1,
#  'косово': 1,
#  'метохии': 1,
#  'каждого': 1,
#  'рассматриваемые': 1,
#  'имеют': 1,
#  'пересекающуюся': 1,
#  'православие': 1,
#  'политическая': 1,
#  'история': 1,
#  'нашло': 1,
#  'отражение': 1,
#  'наборах': 1,
#  'указанные': 1,
#  'имен': 1,
#  'собственных': 1,
#  'общих': 1,
#  'двух': 1,
#  'первого': 1,
#  'содержат': 1,
#  'второго': 1,
#  'приводятся': 1,
#  'проиллюстрированы': 1,
#  'провели': 1,
#  'автоматическую': 1,
#  'обработку': 1,
#  'рассматривались': 1,
#  'лекарственных': 2,
#  'средств': 1,
#  'некоторых': 1,
#  'других': 1,
#  'трех': 1,
#  'источниках': 1,
#  'книга': 1,
#  'кента': 1,
#  'которая': 1,
#  'считается': 1,
#  'авторитетным': 1,
#  'справочником': 1,
#  'энциклопедия': 1,
#  'современных': 1,
#  'растений': 3,
#  'грив': 1,
#  'база': 1,
#  'сформированных': 1,
#  'вошедших': 1,
#  'дает': 3,
#  'первый': 1,
#  'источник': 3,
#  'предсказуемым': 1,
#  'образом': 1,
#  'сведения': 2,
#  'симптомах': 1,
#  'связанных': 1,
#  'лекарственными': 1,
#  'второй': 1,
#  'ожиданиям': 1,
#  'скорее': 1,
#  'медицинского': 1,
#  'ботанического': 1,
#  'характера': 1,
#  'третий': 1,
#  'следовало': 1,
#  'информацию': 1,
#  'внешнем': 1,
#  'виде': 1,
#  'условиях': 1,
#  'произрастания': 1,
#  'особенностях': 1,
#  'сбора': 1,
#  'хранения': 1,
#  'меньшей': 1,
#  'степени': 1,
#  'свойствах': 1,
#  'заключение': 1,
#  'наблюдения': 1,
#  'сделанные': 1,
#  'нами': 1,
#  'ходе': 1,
#  'позволяют': 1,
#  'одобрительно': 1,
#  'относиться': 1,
#  'алгоритму': 1,
#  'средству': 1,
#  'пригодному': 1,
#  'качественного': 1,
#  'сжатия': 1,
#  'оценки': 1,
#  'содержания': 1,
#  'соответствия': 1,
#  'тематике': 1,
#  'перспективы': 1,
#  'исследования': 1,
#  'сопоставительным': 1,
#  'анализом': 1,
#  'набора': 1,
#  'имеющихся': 1,
#  'открытом': 1,
#  'доступе': 1,
#  'инструментов': 2,
#  'которых': 1,
#  'реализована': 1,
#  'адаптацией': 1,
#  'русскоязычными': 1,
#  'решение': 1,
#  'будет': 1,
#  'способствовать': 1,
#  'автоматическому': 1,
#  'русскоязычных': 1}

# %%
freq = sorted(frequency.items(), key=lambda x:x[1], reverse = True) #создаём список, в котором пары СЛОВО и ЧАСТОТА упорядочены по убыванию
length = len(text_words)

print(length)
print(freq)
# Out:
# 1095
# [('слов', 20), ('текстов', 20), ('т', 19), ('модель', 14), ('д', 12), ('коллекции', 11), ('тематического', 10), ('моделирования', 10), ('модели', 9), ('текстовой', 8), ('тексты', 8), ('обработки', 7), ('ключевых', 7), ('слова', 7), ('темы', 7), ('текста', 6), ('документов', 6), ('п', 6), ('тема', 5), ('документ', 5), ('связаны', 5), ('позволяет', 4), ('автоматической', 4), ('эксперименты', 4), ('методов', 4), ('экспериментов', 4), ('этих', 4), ('распределений', 4), ('используется', 4), ('текстовых', 4), ('встречаемости', 4), ('моделей', 4), ('больших', 4), ('число', 4), ('статьи', 4), ('задач', 3), ('кластеризации', 3), ('митрофанова', 3), ('которые', 3), ('тематической', 3), ('тематическое', 3), ('моделирование', 3), ('характеризующих', 3), ('случае', 3), ('слово', 3), ('документа', 3), ('тематических', 3), ('моделях', 3), ('имеет', 3), ('набор', 3), ('распределение', 3), ('могут', 3), ('рис', 3), ('текст', 3), ('совместной', 3), ('термы', 3), ('документы', 3), ('насколько', 3), ('работе', 3), ('текстами', 3), ('пространства', 3), ('описания', 3), ('коллекций', 3), ('объем', 3), ('гомеопатии', 3), ('растениеводству', 3), ('пример', 3), ('тыс', 3), ('табл', 3), ('растений', 3), ('дает', 3), ('источник', 3), ('новых', 2), ('моделированию', 2), ('исследователям', 2), ('выделении', 2), ('семантической', 2), ('наши', 2), ('лет', 2), ('доступные', 2), ('проведению', 2), ('практических', 2), ('средствами', 2), ('исследователей', 2), ('структуры', 2), ('оценить', 2), ('способ', 2), ('совокупности', 2), ('документах', 2), ('текстовую', 2), ('коллекцию', 2), ('тематические', 2), ('тематику', 2), ('выявления', 2), ('е', 2), ('соответствие', 2), ('вероятностных', 2), ('множестве', 2), ('составляет', 2), ('обработке', 2), ('данных', 2), ('описывается', 2), ('семейством', 2), ('корпусе', 2), ('теме', 2), ('латентно', 2), ('семантический', 2), ('анализ', 2), ('дирихле', 2), ('текстам', 2), ('сравнение', 2), ('собой', 2), ('недостатки', 2), ('объемов', 2), ('учесть', 2), ('многозначность', 2), ('признакового', 2), ('частично', 2), ('этой', 2), ('разных', 2), ('имеющиеся', 2), ('связей', 2), ('частности', 2), ('тематическая', 2), ('быть', 2), ('разработчиков', 2), ('семантического', 2), ('них', 2), ('эти', 2), ('работы', 2), ('программные', 2), ('приведены', 2), ('автоматически', 2), ('темах', 2), ('содержит', 2), ('публицистические', 2), ('тематики', 2), ('конференции', 2), ('дж', 2), ('нескольких', 2), ('полученные', 2), ('данные', 2), ('компьютерной', 2), ('том', 2), ('числе', 2), ('результаты', 2), ('заметить', 2), ('перечень', 2), ('наполнение', 2), ('возможность', 2), ('темой', 2), ('лекарственных', 2), ('сведения', 2), ('инструментов', 2), ('введение', 1), ('разработка', 1), ('подходов', 1), ('лингвистическому', 1), ('новому', 1), ('взглянуть', 1), ('важный', 1), ('класс', 1), ('естественного', 1), ('языка', 1), ('смысловую', 1), ('компрессию', 1), ('производимую', 1), ('автоматическом', 1), ('словосочетаний', 1), ('классификации', 1), ('лексики', 1), ('корпусах', 1), ('классов', 1), ('близкими', 1), ('дистрибутивными', 1), ('свойствами', 1), ('оценке', 1), ('однородности', 1), ('неоднородности', 1), ('ср', 1), ('описанные', 1), ('статьях', 1), ('мухин', 1), ('паничева', 1), ('грачкова', 1), ('шиморина', 1), ('данном', 1), ('ряду', 1), ('особняком', 1), ('стоит', 1), ('задача', 1), ('корпусов', 1), ('последние', 1), ('несколько', 1), ('арсенал', 1), ('существенно', 1), ('расширился', 1), ('появились', 1), ('компьютерные', 1), ('инструменты', 1), ('создающие', 1), ('предпосылки', 1), ('параллельно', 1), ('расширяется', 1), ('круг', 1), ('решаются', 1), ('данными', 1), ('особое', 1), ('внимание', 1), ('обращено', 1), ('анализу', 1), ('социальных', 1), ('сетей', 1), ('выявлению', 1), ('сообществ', 1), ('связи', 1), ('этим', 1), ('представляется', 1), ('важным', 1), ('особенности', 1), ('различных', 1), ('применимость', 1), ('иным', 1), ('экспериментальным', 1), ('данным', 1), ('такое', 1), ('построения', 1), ('отражающий', 1), ('переход', ...

# %%
n_list=[]
for words in freq:  # проверяем каждую пару СЛОВО и ЧАСТОТА в отсортированном тексте
    fr_lst = list(words) # превращаем пары в круглых скобках, созданные анонимной функцией LAMBDA, в список из двух элементов - СЛОВО и ЧАСТОТА
    n_list.append(fr_lst)

n_list
# Out:
# [['слов', 20],
#  ['текстов', 20],
#  ['т', 19],
#  ['модель', 14],
#  ['д', 12],
#  ['коллекции', 11],
#  ['тематического', 10],
#  ['моделирования', 10],
#  ['модели', 9],
#  ['текстовой', 8],
#  ['тексты', 8],
#  ['обработки', 7],
#  ['ключевых', 7],
#  ['слова', 7],
#  ['темы', 7],
#  ['текста', 6],
#  ['документов', 6],
#  ['п', 6],
#  ['тема', 5],
#  ['документ', 5],
#  ['связаны', 5],
#  ['позволяет', 4],
#  ['автоматической', 4],
#  ['эксперименты', 4],
#  ['методов', 4],
#  ['экспериментов', 4],
#  ['этих', 4],
#  ['распределений', 4],
#  ['используется', 4],
#  ['текстовых', 4],
#  ['встречаемости', 4],
#  ['моделей', 4],
#  ['больших', 4],
#  ['число', 4],
#  ['статьи', 4],
#  ['задач', 3],
#  ['кластеризации', 3],
#  ['митрофанова', 3],
#  ['которые', 3],
#  ['тематической', 3],
#  ['тематическое', 3],
#  ['моделирование', 3],
#  ['характеризующих', 3],
#  ['случае', 3],
#  ['слово', 3],
#  ['документа', 3],
#  ['тематических', 3],
#  ['моделях', 3],
#  ['имеет', 3],
#  ['набор', 3],
#  ['распределение', 3],
#  ['могут', 3],
#  ['рис', 3],
#  ['текст', 3],
#  ['совместной', 3],
#  ['термы', 3],
#  ['документы', 3],
#  ['насколько', 3],
#  ['работе', 3],
#  ['текстами', 3],
#  ['пространства', 3],
#  ['описания', 3],
#  ['коллекций', 3],
#  ['объем', 3],
#  ['гомеопатии', 3],
#  ['растениеводству', 3],
#  ['пример', 3],
#  ['тыс', 3],
#  ['табл', 3],
#  ['растений', 3],
#  ['дает', 3],
#  ['источник', 3],
#  ['новых', 2],
#  ['моделированию', 2],
#  ['исследователям', 2],
#  ['выделении', 2],
#  ['семантической', 2],
#  ['наши', 2],
#  ['лет', 2],
#  ['доступные', 2],
#  ['проведению', 2],
#  ['практических', 2],
#  ['средствами', 2],
#  ['исследователей', 2],
#  ['структуры', 2],
#  ['оценить', 2],
#  ['способ', 2],
#  ['совокупности', 2],
#  ['документах', 2],
#  ['текстовую', 2],
#  ['коллекцию', 2],
#  ['тематические', 2],
#  ['тематику', 2],
#  ['выявления', 2],
#  ['е', 2],
#  ['соответствие', 2],
#  ['вероятностных', 2],
#  ['множестве', 2],
#  ['составляет', 2],
#  ['обработке', 2],
#  ['данных', 2],
#  ['описывается', 2],
#  ['семейством', 2],
#  ['корпусе', 2],
#  ['теме', 2],
#  ['латентно', 2],
#  ['семантический', 2],
#  ['анализ', 2],
#  ['дирихле', 2],
#  ['текстам', 2],
#  ['сравнение', 2],
#  ['собой', 2],
#  ['недостатки', 2],
#  ['объемов', 2],
#  ['учесть', 2],
#  ['многозначность', 2],
#  ['признакового', 2],
#  ['частично', 2],
#  ['этой', 2],
#  ['разных', 2],
#  ['имеющиеся', 2],
#  ['связей', 2],
#  ['частности', 2],
#  ['тематическая', 2],
#  ['быть', 2],
#  ['разработчиков', 2],
#  ['семантического', 2],
#  ['них', 2],
#  ['эти', 2],
#  ['работы', 2],
#  ['программные', 2],
#  ['приведены', 2],
#  ['автоматически', 2],
#  ['темах', 2],
#  ['содержит', 2],
#  ['публицистические', 2],
#  ['тематики', 2],
#  ['конференции', 2],
#  ['дж', 2],
#  ['нескольких', 2],
#  ['полученные', 2],
#  ['данные', 2],
#  ['компьютерной', 2],
#  ['том', 2],
#  ['числе', 2],
#  ['результаты', 2],
#  ['заметить', 2],
#  ['перечень', 2],
#  ['наполнение', 2],
#  ['возможность', 2],
#  ['темой', 2],
#  ['лекарственных', 2],
#  ['сведения', 2],
#  ['инструментов', 2],
#  ['введение', 1],
#  ['разработка', 1],
#  ['подходов', 1],
#  ['лингвистическому', 1],
#  ['новому', 1],
#  ['взглянуть', 1],
#  ['важный', 1],
#  ['класс', 1],
#  ['естественного', 1],
#  ['языка', 1],
#  ['смысловую', 1],
#  ['компрессию', 1],
#  ['производимую', 1],
#  ['автоматическом', 1],
#  ['словосочетаний', 1],
#  ['классификации', 1],
#  ['лексики', 1],
#  ['корпусах', 1],
#  ['классов', 1],
#  ['близкими', 1],
#  ['дистрибутивными', 1],
#  ['свойствами', 1],
#  ['оценке', 1],
#  ['однородности', 1],
#  ['неоднородности', 1],
#  ['ср', 1],
#  ['описанные', 1],
#  ['статьях', 1],
#  ['мухин', 1],
#  ['паничева', 1],
#  ['грачкова', 1],
#  ['шиморина', 1],
#  ['данном', 1],
#  ['ряду', 1],
#  ['особняком', 1],
#  ['стоит', 1],
#  ['задача', 1],
#  ['корпусов', 1],
#  ['последние', 1],
#  ['несколько', 1],
#  ['арсенал', 1],
#  ['существенно', 1],
#  ['расширился', 1],
#  ['появились', 1],
#  ['компьютерные', 1],
#  ['инструменты', 1],
#  ['создающие', 1],
#  ['предпосылки', 1],
#  ['параллельно', 1],
#  ['расширяется', 1],
#  ['круг', 1],
#  ['решаются', 1],
#  ['данными', 1],
#  ['особое', 1],
#  ['внимание', 1],
#  ['обращено', 1],
#  ['анализу', 1],
#  ['социальных', 1],
#  ['сетей', 1],
#  ['выявлению', 1],
#  ['сообществ', 1],
#  ['связи', 1],
#  ['этим', 1],
#  ['представляется', 1],
#  ['важным', 1],
#  ['особенности', 1],
#  ['различных', 1],
#  ['применимость', 1],
#  ['иным', 1],
#  ['экспериментальным', 1],
#  ['данным', 1],
#  ['такое', 1],
#  ['построения', 1],
#  ['отражающий', 1],
#  ['переход', 1],
#  ['набору', 1],
#  ['скрытыми', 1],
#  ['переменными', 1],
#  ['факторами', 1],
#  ['задающими', 1],
#  ['скрытых', 1],
#  ['переменных', 1],
#  ['применять', 1],
#  ['нечеткую', 1],
#  ['кластеризацию', 1],
#  ['разбиение', 1],
#  ['пересекающиеся', 1],
#  ['классы', 1],
#  ['таком', 1],
#  ['результат', 1],
#  ['бикластеризации', 1],
#  ['одновременной', 1],
#  ['точки', 1],
#  ['зрения', 1],
#  ['близости', 1],
#  ['пределах', 1],
#  ['нечеткой', 1],
#  ['любое', 1],
#  ['некоторой', 1],
#  ['вероятностью', 1],
#  ['относится', 1],
#  ['нескольким', 1],
#  ['темам', 1],
#  ['сказать', 1],
#  ['описанию', 1],
#  ['ставится', 1],
#  ['семейство', 1],
#  ['выявление', 1],
#  ['основу', 1],
#  ['подход', 1],
#  ['называемый', 1],
#  ['мешок', 1],
#  ['упорядочения', 1],
#  ['значения', 1],
#  ['учитывается', 1],
#  ['порядок', 1],
#  ['предложении', 1],
#  ['взаимное', 1],
#  ['расположение', 1],
#  ['тексте', 1],
#  ['тематическом', 1],
#  ['моделировании', 1],
#  ['порождаемых', 1],
#  ['время', 1],
#  ['случайная', 1],
#  ['выборка', 1],
#  ['порожденная', 1],
#  ['неким', 1],
#  ['множеством', 1],
#  ['исходя', 1],
#  ['этого', 1],
#  ['установить', 1],
#  ['выяснить', 1],
#  ['каким', 1],
#  ['набором', 1],
#  ['порождается', 1],
#  ['конкретный', 1],
#  ['лингвистическом', 1],
#  ['смысле', 1],
#  ['есть', 1],
#  ['характеризующий', 1],
#  ['отдельный', 1],
#  ['тестовой', 1],
#  ['присутствовать', 1],
#  ['искусство', 1],
#  ['дети', 1],
#  ['образование', 1],
#  ['жизнь', 1],
#  ['ген', 1],
#  ['мозг', 1],
#  ['ассоциируемые', 1],
#  ['наборами', 1],
#  ['имеющих', 1],
#  ['определенную', 1],
#  ['частоту', 1],
#  ['вероятность', 1],
#  ['появления', 1],
#  ['соответствующих', 1],
#  ['типы', 1],
#  ['разработках', 1],
#  ['последних', 1],
#  ['широко', 1],
#  ['ряд', 1],
#  ['алгебраических', 1],
#  ['опираются', 1],
#  ['процедуры', 1],
#  ['распространены', 1],
#  ['стандартная', 1],
#  ['векторная', 1],
#  ['генеративных', 1],
#  ['применяются', 1],
#  ['вероятностный', 1],
#  ['латентное', 1],
#  ['размещение', 1],
#  ['дадим', 1],
#  ['краткую', 1],
#  ['характеристику', 1],
#  ['подробные', 1],
#  ['обзоры', 1],
#  ['матрицей', 1],
#  ['словам', 1],
#  ['ставятся', 1],
#  ['вектора', 1],
#  ['мерном', 1],
#  ['пространстве', 1],
#  ['векторов', 1],
#  ['правило', 1],
#  ['определение', 1],
#  ['косинуса', 1],
#  ['угла', 1],
#  ['векторами', 1],
#  ['характерно', 1],
#  ['документе', 1],
#  ['близки', 1],
#  ['неудобством', 1],
#  ['использования', 1],
#  ['невозможностью', 1],
#  ['синонимические', 1],
#  ['отношения', 1],
#  ['словами', 1],
#  ['наследует', 1],
#  ['основные', 1],
#  ['характеристики', 1],
#  ['сокращения', 1],
#  ['размерности', 1],
#  ['значимых', 1],
#  ['текстах', 1],
#  ['сингулярное', 1],
#  ['разложение', 1],
#  ['матрицы', 1],
#  ['отличие', 1],
#  ['пригодна', 1],
#  ['контекстную', 1],
#  ['синонимию', 1],
#  ['справляется', 1],
#  ['многозначностью', 1],
#  ['сложно', 1],
#  ['заранее', 1],
#  ['задать', 1],
#  ['ожидаемое', 1],
#  ['приписать', 1],
#  ['метку', 1],
#  ['используя', 1],
#  ['какое', 1],
#  ['ключевое', 1],
#  ['являет', 1],
#  ['вероятностную', 1],
#  ['модификацию', 1],
#  ['порождение', 1],
#  ['производится', 1],
#  ['соответствии', 1],
#  ['методом', 1],
#  ['байеса', 1],
#  ['отчасти', 1],
#  ['учитывает', 1],
#  ['значениях', 1],
#  ['многозначные', 1],
#  ['представлять', 1],
#  ['разные', 1],
#  ['основ', 1],
#  ['ные', 1],
#  ['риском', 1],
#  ['переобучения', 1],
#  ['сложностью', 1],
#  ['добавления', 1],
#  ['сглаживает', 1],
#  ['шероховатости', 1],
#  ['предыдущих', 1],
#  ['опирающейся', 1],
#  ['каждая', 1],
#  ['характеризуется', 1],
#  ['вероятностным', 1],
#  ['распределением', 1],
#  ['описываются', 1],
#  ['описывать', 1],
#  ['корпуса', 1],
#  ['большого', 1],
#  ['объема', 1],
#  ['одну', 1],
#  ['тему', 1],
#  ['попадать', 1],
#  ['частей', 1],
#  ['речи', 1],
#  ['данная', 1],
#  ['предусматривает', 1],
#  ['установление', 1],
#  ['темами', 1],
#  ['известны', 1],
#  ['мере', 1],
#  ['связанные', 1],
#  ['упомянутыми', 1],
#  ['совместная', 1],
#  ['вероятностная', 1],
#  ['скрытая', 1],
#  ['марковская', 1],
#  ['автортематическая', 1],
#  ['автор', 1],
#  ['получатель', 1],
#  ['корреляционная', 1],
#  ['спецификация', 1],
#  ['связана', 1],
#  ['различиями', 1],
#  ['уровне', 1],
#  ['лингвистической', 1],
#  ['входных', 1],
#  ['привлечением', 1],
#  ['аппарата', 1],
#  ['дистрибутивной', 1],
#  ['семантики', 1],
#  ['большинство', 1],
#  ['языковых', 1],
#  ['ресурсов', 1],
#  ['склоняются', 1],
#  ['необходимости', 1],
#  ['интеграции', 1],
#  ['статистических', 1],
#  ['традиционных', 1],
#  ['лингвистических', 1],
#  ['анализа', 1],
#  ['реализовано', 1],
#  ['использование', 1],
#  ['многоуровневой', 1],
#  ['разметки', 1],
#  ['лемматизация', 1],
#  ['морфосинтаксическая', 1],
#  ['доступности', 1],
#  ['семантическая', 1],
#  ['аннотация', 1],
#  ['учет', 1],
#  ['границ', 1],
#  ['синтаксических', 1],
#  ['групп', 1],
#  ['существующих', 1],
#  ['ограничение', 1],
#  ['контекстного', 1],
#  ['окна', 1],
#  ['назначение', 1],
#  ['весов', 1],
#  ['контекстных', 1],
#  ['элементов', 1],
#  ['нормализация', 1],
#  ['значений', 1],
#  ['коэффициентов', 1],
#  ['свертка', 1],
#  ['методы', 1],
#  ['способствуют', 1],
#  ['повышению', 1],
#  ['качества', 1],
#  ['выборе', 1],
#  ['инструмента', 1],
#  ['руководствовались', 1],
#  ['доступностью', 1],
#  ['гибкостью', 1],
#  ['устойчивостью', 1],
#  ['остановились', 1],
#  ['пакете', 1],
#  ['реализующем', 1],
#  ['разработчики', 1],
#  ['ньюмэн', 1],
#  ['коллеги', 1],
#  ['калифорнийский', 1],
#  ['университет', 1],
#  ['пакеты', 1],
#  ['конце', 1],
#  ['раздел', 1],
#  ['реализации', 1],
#  ['программа', 1],
#  ['удобный', 1],
#  ['интерфейс', 1],
#  ['пользователь', 1],
#  ['загружает', 1],
#  ['выбирает', 1],
#  ['параметры', 1],
#  ['генерируются', 1],
#  ['итераций', 1],
#  ['списков', 1],
#  ['выдача', 1],
#  ['результатов', 1],
#  ['программы', 1],
#  ['списки', 1],
#  ['проводились', 1],
#  ['латинице', 1],
#  ['английском', 1],
#  ['языке', 1],
#  ['качестве', 1],
#  ['использовались', 1],
#  ['журнала', 1],
#  ['мировой', 1],
#  ['политике', 1],
#  ['экклезиологической', 1],
#  ['научные', 1],
#  ['материалы', 1],
#  ['научно', 1],
#  ['популярные', 1],
#  ['художественные', 1],
#  ['рассказы', 1],
#  ['повести', 1],
#  ['ф', 1],
#  ['старк', 1],
#  ['даррелла', 1],
#  ['деловые', 1],
#  ['конвенции', 1],
#  ['правам', 1],
#  ['человека', 1],
#  ['обоснованно', 1],
#  ['метод', 1],
#  ['утверждению', 1],
#  ['специалистов', 1],
#  ['пригоден', 1],
#  ['умеренных', 1],
#  ['нашем', 1],
#  ['варьироваться', 1],
#  ['десятков', 1],
#  ['сотен', 1],
#  ['средней', 1],
#  ['достаточно', 1],
#  ['выполнялись', 1],
#  ['пошагово', 1],
#  ['приведем', 1],
#  ['отдельные', 1],
#  ['иллюстрации', 1],
#  ['дающие', 1],
#  ['представление', 1],
#  ['результатах', 1],
#  ['прокомментируем', 1],
#  ['проведено', 1],
#  ['научных', 1],
#  ['материалов', 1],
#  ['лингвистике', 1],
#  ['общий', 1],
#  ['примерно', 1],
#  ['имеется', 1],
#  ['подробная', 1],
#  ['информация', 1],
#  ['данной', 1],
#  ['описание', 1],
#  ['основных', 1],
#  ['основе', 1],
#  ['адекватно', 1],
#  ['отражают', 1],
#  ['содержательное', 1],
#  ['разнообразие', 1],
#  ['охватывающей', 1],
#  ['направления', 1],
#  ['лингвистики', 1],
#  ['редким', 1],
#  ['исключением', 1],
#  ['отличаются', 1],
#  ['компактностью', 1],
#  ['низкой', 1],
#  ['долей', 1],
#  ['шума', 1],
#  ['следующее', 1],
#  ['имели', 1],
#  ['сравнить', 1],
#  ['ранними', 1],
#  ['результатами', 1],
#  ['автоматического', 1],
#  ['выделения', 1],
#  ['полученных', 1],
#  ['стандартной', 1],
#  ['векторной', 1],
#  ['моделью', 1],
#  ['ассоциированных', 1],
#  ['заметно', 1],
#  ['значимыми', 1],
#  ['этом', 1],
#  ['перечне', 1],
#  ['являются', 1],
#  ['первые', 1],
#  ['три', 1],
#  ['имена', 1],
#  ['собственные', 1],
#  ['семантике', 1],
#  ['напрямую', 1],
#  ['всё', 1],
#  ['свидетельствует', 1],
#  ['пользу', 1],
#  ['проанализированы', 1],
#  ['истории', 1],
#  ['косово', 1],
#  ['метохии', 1],
#  ['каждого', 1],
#  ['рассматриваемые', 1],
#  ['имеют', 1],
#  ['пересекающуюся', 1],
#  ['православие', 1],
#  ['политическая', 1],
#  ['история', 1],
#  ['нашло', 1],
#  ['отражение', 1],
#  ['наборах', 1],
#  ['указанные', 1],
#  ['имен', 1],
#  ['собственных', 1],
#  ['общих', 1],
#  ['двух', 1],
#  ['первого', 1],
#  ['содержат', 1],
#  ['второго', 1],
#  ['приводятся', 1],
#  ['проиллюстрированы', 1],
#  ['провели', 1],
#  ['автоматическую', 1],
#  ['обработку', 1],
#  ['рассматривались', 1],
#  ['средств', 1],
#  ['некоторых', 1],
#  ['других', 1],
#  ['трех', 1],
#  ['источниках', 1],
#  ['книга', 1],
#  ['кента', 1],
#  ['которая', 1],
#  ['считается', 1],
#  ['авторитетным', 1],
#  ['справочником', 1],
#  ['энциклопедия', 1],
#  ['современных', 1],
#  ['грив', 1],
#  ['база', 1],
#  ['сформированных', 1],
#  ['вошедших', 1],
#  ['первый', 1],
#  ['предсказуемым', 1],
#  ['образом', 1],
#  ['симптомах', 1],
#  ['связанных', 1],
#  ['лекарственными', 1],
#  ['второй', 1],
#  ['ожиданиям', 1],
#  ['скорее', 1],
#  ['медицинского', 1],
#  ['ботанического', 1],
#  ['характера', 1],
#  ['третий', 1],
#  ['следовало', 1],
#  ['информацию', 1],
#  ['внешнем', 1],
#  ['виде', 1],
#  ['условиях', 1],
#  ['произрастания', 1],
#  ['особенностях', 1],
#  ['сбора', 1],
#  ['хранения', 1],
#  ['меньшей', 1],
#  ['степени', 1],
#  ['свойствах', 1],
#  ['заключение', 1],
#  ['наблюдения', 1],
#  ['сделанные', 1],
#  ['нами', 1],
#  ['ходе', 1],
#  ['позволяют', 1],
#  ['одобрительно', 1],
#  ['относиться', 1],
#  ['алгоритму', 1],
#  ['средству', 1],
#  ['пригодному', 1],
#  ['качественного', 1],
#  ['сжатия', 1],
#  ['оценки', 1],
#  ['содержания', 1],
#  ['соответствия', 1],
#  ['тематике', 1],
#  ['перспективы', 1],
#  ['исследования', 1],
#  ['сопоставительным', 1],
#  ['анализом', 1],
#  ['набора', 1],
#  ['имеющихся', 1],
#  ['открытом', 1],
#  ['доступе', 1],
#  ['которых', 1],
#  ['реализована', 1],
#  ['адаптацией', 1],
#  ['русскоязычными', 1],
#  ['решение', 1],
#  ['будет', 1],
#  ['способствовать', 1],
#  ['автоматическому', 1],
#  ['русскоязычных', 1]]

# %%
k = 1
for i in n_list:
    logfr = math.log(int(i[1]),10)
    logrank = math.log(k, 10)  # берём десятичные логарифмы для ранга и для частоты
    i.append(k)
    i.append(logfr)
    i.append(logrank)
    k+=1

# %%
n_list
# Out:
# [['слов', 20, 1, 1.301029995663981, 0.0],
#  ['текстов', 20, 2, 1.301029995663981, 0.30102999566398114],
#  ['т', 19, 3, 1.2787536009528289, 0.47712125471966244],
#  ['модель', 14, 4, 1.1461280356782377, 0.6020599913279623],
#  ['д', 12, 5, 1.0791812460476247, 0.6989700043360187],
#  ['коллекции', 11, 6, 1.041392685158225, 0.7781512503836435],
#  ['тематического', 10, 7, 1.0, 0.8450980400142567],
#  ['моделирования', 10, 8, 1.0, 0.9030899869919434],
#  ['модели', 9, 9, 0.9542425094393249, 0.9542425094393249],
#  ['текстовой', 8, 10, 0.9030899869919434, 1.0],
#  ['тексты', 8, 11, 0.9030899869919434, 1.041392685158225],
#  ['обработки', 7, 12, 0.8450980400142567, 1.0791812460476247],
#  ['ключевых', 7, 13, 0.8450980400142567, 1.1139433523068367],
#  ['слова', 7, 14, 0.8450980400142567, 1.1461280356782377],
#  ['темы', 7, 15, 0.8450980400142567, 1.1760912590556811],
#  ['текста', 6, 16, 0.7781512503836435, 1.2041199826559246],
#  ['документов', 6, 17, 0.7781512503836435, 1.2304489213782739],
#  ['п', 6, 18, 0.7781512503836435, 1.2552725051033058],
#  ['тема', 5, 19, 0.6989700043360187, 1.2787536009528289],
#  ['документ', 5, 20, 0.6989700043360187, 1.301029995663981],
#  ['связаны', 5, 21, 0.6989700043360187, 1.322219294733919],
#  ['позволяет', 4, 22, 0.6020599913279623, 1.3424226808222062],
#  ['автоматической', 4, 23, 0.6020599913279623, 1.3617278360175928],
#  ['эксперименты', 4, 24, 0.6020599913279623, 1.380211241711606],
#  ['методов', 4, 25, 0.6020599913279623, 1.3979400086720375],
#  ['экспериментов', 4, 26, 0.6020599913279623, 1.414973347970818],
#  ['этих', 4, 27, 0.6020599913279623, 1.4313637641589871],
#  ['распределений', 4, 28, 0.6020599913279623, 1.447158031342219],
#  ['используется', 4, 29, 0.6020599913279623, 1.462397997898956],
#  ['текстовых', 4, 30, 0.6020599913279623, 1.4771212547196624],
#  ['встречаемости', 4, 31, 0.6020599913279623, 1.4913616938342726],
#  ['моделей', 4, 32, 0.6020599913279623, 1.5051499783199058],
#  ['больших', 4, 33, 0.6020599913279623, 1.5185139398778873],
#  ['число', 4, 34, 0.6020599913279623, 1.5314789170422551],
#  ['статьи', 4, 35, 0.6020599913279623, 1.5440680443502754],
#  ['задач', 3, 36, 0.47712125471966244, 1.556302500767287],
#  ['кластеризации', 3, 37, 0.47712125471966244, 1.5682017240669948],
#  ['митрофанова', 3, 38, 0.47712125471966244, 1.57978359661681],
#  ['которые', 3, 39, 0.47712125471966244, 1.591064607026499],
#  ['тематической', 3, 40, 0.47712125471966244, 1.6020599913279623],
#  ['тематическое', 3, 41, 0.47712125471966244, 1.6127838567197355],
#  ['моделирование', 3, 42, 0.47712125471966244, 1.6232492903979003],
#  ['характеризующих', 3, 43, 0.47712125471966244, 1.6334684555795864],
#  ['случае', 3, 44, 0.47712125471966244, 1.6434526764861872],
#  ['слово', 3, 45, 0.47712125471966244, 1.6532125137753435],
#  ['документа', 3, 46, 0.47712125471966244, 1.6627578316815739],
#  ['тематических', 3, 47, 0.47712125471966244, 1.6720978579357173],
#  ['моделях', 3, 48, 0.47712125471966244, 1.6812412373755872],
#  ['имеет', 3, 49, 0.47712125471966244, 1.6901960800285134],
#  ['набор', 3, 50, 0.47712125471966244, 1.6989700043360185],
#  ['распределение', 3, 51, 0.47712125471966244, 1.7075701760979363],
#  ['могут', 3, 52, 0.47712125471966244, 1.716003343634799],
#  ['рис', 3, 53, 0.47712125471966244, 1.724275869600789],
#  ['текст', 3, 54, 0.47712125471966244, 1.7323937598229684],
#  ['совместной', 3, 55, 0.47712125471966244, 1.7403626894942439],
#  ['термы', 3, 56, 0.47712125471966244, 1.7481880270062005],
#  ['документы', 3, 57, 0.47712125471966244, 1.7558748556724912],
#  ['насколько', 3, 58, 0.47712125471966244, 1.7634279935629371],
#  ['работе', 3, 59, 0.47712125471966244, 1.7708520116421442],
#  ['текстами', 3, 60, 0.47712125471966244, 1.7781512503836434],
#  ['пространства', 3, 61, 0.47712125471966244, 1.785329835010767],
#  ['описания', 3, 62, 0.47712125471966244, 1.7923916894982537],
#  ['коллекций', 3, 63, 0.47712125471966244, 1.7993405494535815],
#  ['объем', 3, 64, 0.47712125471966244, 1.8061799739838869],
#  ['гомеопатии', 3, 65, 0.47712125471966244, 1.8129133566428552],
#  ['растениеводству', 3, 66, 0.47712125471966244, 1.8195439355418683],
#  ['пример', 3, 67, 0.47712125471966244, 1.8260748027008262],
#  ['тыс', 3, 68, 0.47712125471966244, 1.8325089127062362],
#  ['табл', 3, 69, 0.47712125471966244, 1.8388490907372552],
#  ['растений', 3, 70, 0.47712125471966244, 1.845098040014257],
#  ['дает', 3, 71, 0.47712125471966244, 1.851258348719075],
#  ['источник', 3, 72, 0.47712125471966244, 1.8573324964312683],
#  ['новых', 2, 73, 0.30102999566398114, 1.8633228601204557],
#  ['моделированию', 2, 74, 0.30102999566398114, 1.8692317197309762],
#  ['исследователям', 2, 75, 0.30102999566398114, 1.8750612633916997],
#  ['выделении', 2, 76, 0.30102999566398114, 1.8808135922807911],
#  ['семантической', 2, 77, 0.30102999566398114, 1.8864907251724818],
#  ['наши', 2, 78, 0.30102999566398114, 1.8920946026904801],
#  ['лет', 2, 79, 0.30102999566398114, 1.8976270912904412],
#  ['доступные', 2, 80, 0.30102999566398114, 1.9030899869919433],
#  ['проведению', 2, 81, 0.30102999566398114, 1.9084850188786497],
#  ['практических', 2, 82, 0.30102999566398114, 1.9138138523837167],
#  ['средствами', 2, 83, 0.30102999566398114, 1.919078092376074],
#  ['исследователей', 2, 84, 0.30102999566398114, 1.9242792860618814],
#  ['структуры', 2, 85, 0.30102999566398114, 1.9294189257142926],
#  ['оценить', 2, 86, 0.30102999566398114, 1.9344984512435675],
#  ['способ', 2, 87, 0.30102999566398114, 1.9395192526186182],
#  ['совокупности', 2, 88, 0.30102999566398114, 1.9444826721501687],
#  ['документах', 2, 89, 0.30102999566398114, 1.9493900066449126],
#  ['текстовую', 2, 90, 0.30102999566398114, 1.9542425094393248],
#  ['коллекцию', 2, 91, 0.30102999566398114, 1.9590413923210932],
#  ['тематические', 2, 92, 0.30102999566398114, 1.9637878273455551],
#  ['тематику', 2, 93, 0.30102999566398114, 1.968482948553935],
#  ['выявления', 2, 94, 0.30102999566398114, 1.9731278535996983],
#  ['е', 2, 95, 0.30102999566398114, 1.9777236052888476],
#  ['соответствие', 2, 96, 0.30102999566398114, 1.9822712330395682],
#  ['вероятностных', 2, 97, 0.30102999566398114, 1.9867717342662448],
#  ['множестве', 2, 98, 0.30102999566398114, 1.9912260756924949],
#  ['составляет', 2, 99, 0.30102999566398114, 1.9956351945975497],
#  ['обработке', 2, 100, 0.30102999566398114, 2.0],
#  ['данных', 2, 101, 0.30102999566398114, 2.0043213737826426],
#  ['описывается', 2, 102, 0.30102999566398114, 2.008600171761917],
#  ['семейством', 2, 103, 0.30102999566398114, 2.012837224705172],
#  ['корпусе', 2, 104, 0.30102999566398114, 2.0170333392987803],
#  ['теме', 2, 105, 0.30102999566398114, 2.021189299069938],
#  ['латентно', 2, 106, 0.30102999566398114, 2.02530586526477],
#  ['семантический', 2, 107, 0.30102999566398114, 2.0293837776852093],
#  ['анализ', 2, 108, 0.30102999566398114, 2.0334237554869494],
#  ['дирихле', 2, 109, 0.30102999566398114, 2.0374264979406234],
#  ['текстам', 2, 110, 0.30102999566398114, 2.041392685158225],
#  ['сравнение', 2, 111, 0.30102999566398114, 2.045322978786657],
#  ['собой', 2, 112, 0.30102999566398114, 2.049218022670181],
#  ['недостатки', 2, 113, 0.30102999566398114, 2.0530784434834195],
#  ['объемов', 2, 114, 0.30102999566398114, 2.0569048513364723],
#  ['учесть', 2, 115, 0.30102999566398114, 2.0606978403536114],
#  ['многозначность', 2, 116, 0.30102999566398114, 2.064457989226918],
#  ['признакового', 2, 117, 0.30102999566398114, 2.0681858617461617],
#  ['частично', 2, 118, 0.30102999566398114, 2.0718820073061255],
#  ['этой', 2, 119, 0.30102999566398114, 2.0755469613925306],
#  ['разных', 2, 120, 0.30102999566398114, 2.0791812460476247],
#  ['имеющиеся', 2, 121, 0.30102999566398114, 2.08278537031645],
#  ['связей', 2, 122, 0.30102999566398114, 2.086359830674748],
#  ['частности', 2, 123, 0.30102999566398114, 2.0899051114393976],
#  ['тематическая', 2, 124, 0.30102999566398114, 2.093421685162235],
#  ['быть', 2, 125, 0.30102999566398114, 2.0969100130080562],
#  ['разработчиков', 2, 126, 0.30102999566398114, 2.1003705451175625],
#  ['семантического', 2, 127, 0.30102999566398114, 2.103803720955957],
#  ['них', 2, 128, 0.30102999566398114, 2.107209969647868],
#  ['эти', 2, 129, 0.30102999566398114, 2.110589710299249],
#  ['работы', 2, 130, 0.30102999566398114, 2.1139433523068365],
#  ['программные', 2, 131, 0.30102999566398114, 2.117271295655764],
#  ['приведены', 2, 132, 0.30102999566398114, 2.1205739312058496],
#  ['автоматически', 2, 133, 0.30102999566398114, 2.123851640967086],
#  ['темах', 2, 134, 0.30102999566398114, 2.1271047983648073],
#  ['содержит', 2, 135, 0.30102999566398114, 2.130333768495006],
#  ['публицистические', 2, 136, 0.30102999566398114, 2.1335389083702174],
#  ['тематики', 2, 137, 0.30102999566398114, 2.1367205671564067],
#  ['конференции', 2, 138, 0.30102999566398114, 2.1398790864012365],
#  ['дж', 2, 139, 0.30102999566398114, 2.143014800254095],
#  ['нескольких', 2, 140, 0.30102999566398114, 2.1461280356782377],
#  ['полученные', 2, 141, 0.30102999566398114, 2.1492191126553797],
#  ['данные', 2, 142, 0.30102999566398114, 2.1522883443830563],
#  ['компьютерной', 2, 143, 0.30102999566398114, 2.1553360374650614],
#  ['том', 2, 144, 0.30102999566398114, 2.1583624920952493],
#  ['числе', 2, 145, 0.30102999566398114, 2.1613680022349744],
#  ['результаты', 2, 146, 0.30102999566398114, 2.1643528557844367],
#  ['заметить', 2, 147, 0.30102999566398114, 2.1673173347481756],
#  ['перечень', 2, 148, 0.30102999566398114, 2.170261715394957],
#  ['наполнение', 2, 149, 0.30102999566398114, 2.173186268412274],
#  ['возможность', 2, 150, 0.30102999566398114, 2.176091259055681],
#  ['темой', 2, 151, 0.30102999566398114, 2.1789769472931693],
#  ['лекарственных', 2, 152, 0.30102999566398114, 2.181843587944772],
#  ['сведения', 2, 153, 0.30102999566398114, 2.1846914308175984],
#  ['инструментов', 2, 154, 0.30102999566398114, 2.187520720836463],
#  ['введение', 1, 155, 0.0, 2.1903316981702914],
#  ['разработка', 1, 156, 0.0, 2.1931245983544616],
#  ['подходов', 1, 157, 0.0, 2.1958996524092336],
#  ['лингвистическому', 1, 158, 0.0, 2.1986570869544226],
#  ['новому', 1, 159, 0.0, 2.2013971243204513],
#  ['взглянуть', 1, 160, 0.0, 2.2041199826559246],
#  ['важный', 1, 161, 0.0, 2.2068258760318495],
#  ['класс', 1, 162, 0.0, 2.2095150145426303],
#  ['естественного', 1, 163, 0.0, 2.2121876044039577],
#  ['языка', 1, 164, 0.0, 2.214843848047698],
#  ['смысловую', 1, 165, 0.0, 2.217483944213906],
#  ['компрессию', 1, 166, 0.0, 2.220108088040055],
#  ['производимую', 1, 167, 0.0, 2.2227164711475833],
#  ['автоматическом', 1, 168, 0.0, 2.2253092817258624],
#  ['словосочетаний', 1, 169, 0.0, 2.2278867046136734],
#  ['классификации', 1, 170, 0.0, 2.2304489213782737],
#  ['лексики', 1, 171, 0.0, 2.2329961103921536],
#  ['корпусах', 1, 172, 0.0, 2.2355284469075487],
#  ['классов', 1, 173, 0.0, 2.2380461031287955],
#  ['близкими', 1, 174, 0.0, 2.2405492482825995],
#  ['дистрибутивными', 1, 175, 0.0, 2.2430380486862944],
#  ['свойствами', 1, 176, 0.0, 2.2455126678141495],
#  ['оценке', 1, 177, 0.0, 2.2479732663618064],
#  ['однородности', 1, 178, 0.0, 2.2504200023088936],
#  ['неоднородности', 1, 179, 0.0, 2.252853030979893],
#  ['ср', 1, 180, 0.0, 2.255272505103306],
#  ['описанные', 1, 181, 0.0, 2.2576785748691846],
#  ['статьях', 1, 182, 0.0, 2.2600713879850747],
#  ['мухин', 1, 183, 0.0, 2.2624510897304293],
#  ['паничева', 1, 184, 0.0, 2.2648178230095364],
#  ['грачкова', 1, 185, 0.0, 2.2671717284030133],
#  ['шиморина', 1, 186, 0.0, 2.2695129442179165],
#  ['данном', 1, 187, 0.0, 2.271841606536499],
#  ['ряду', 1, 188, 0.0, 2.2741578492636796],
#  ['особняком', 1, 189, 0.0, 2.276461804173244],
#  ['стоит', 1, 190, 0.0, 2.278753600952829],
#  ['задача', 1, 191, 0.0, 2.281033367247727],
#  ['корпусов', 1, 192, 0.0, 2.2833012287035492],
#  ['последние', 1, 193, 0.0, 2.2855573090077734],
#  ['несколько', 1, 194, 0.0, 2.287801729930226],
#  ['арсенал', 1, 195, 0.0, 2.290034611362518],
#  ['существенно', 1, 196, 0.0, 2.2922560713564755],
#  ['расширился', 1, 197, 0.0, 2.294466226161593],
#  ['появились', 1, 198, 0.0, 2.296665190261531],
#  ['компьютерные', 1, 199, 0.0, 2.2988530764097064],
#  ['инструменты', 1, 200, 0.0, 2.301029995663981],
#  ['создающие', 1, 201, 0.0, 2.3031960574204886],
#  ['предпосылки', 1, 202, 0.0, 2.305351369446624],
#  ['параллельно', 1, 203, 0.0, 2.3074960379132126],
#  ['расширяется', 1, 204, 0.0, 2.3096301674258983],
#  ['круг', 1, 205, 0.0, 2.311753861055754],
#  ['решаются', 1, 206, 0.0, 2.3138672203691533],
#  ['данными', 1, 207, 0.0, 2.3159703454569174],
#  ['особое', 1, 208, 0.0, 2.3180633349627615],
#  ['внимание', 1, 209, 0.0, 2.320146286111054],
#  ['обращено', 1, 210, 0.0, 2.322219294733919],
#  ['анализу', 1, 211, 0.0, 2.3242824552976926],
#  ['социальных', 1, 212, 0.0, 2.326335860928751],
#  ['сетей', 1, 213, 0.0, 2.3283796034387376],
#  ['выявлению', 1, 214, 0.0, 2.3304137733491905],
#  ['сообществ', 1, 215, 0.0, 2.332438459915605],
#  ['связи', 1, 216, 0.0, 2.3344537511509307],
#  ['этим', 1, 217, 0.0, 2.3364597338485296],
#  ['представляется', 1, 218, 0.0, 2.3384564936046046],
#  ['важным', 1, 219, 0.0, 2.340444114840118],
#  ['особенности', 1, 220, 0.0, 2.342422680822206],
#  ['различных', 1, 221, 0.0, 2.34439227368511],
#  ['применимость', 1, 222, 0.0, 2.3463529744506384],
#  ['иным', 1, 223, 0.0, 2.3483048630481607],
#  ['экспериментальным', 1, 224, 0.0, 2.3502480183341623],
#  ['данным', 1, 225, 0.0, 2.3521825181113623],
#  ['такое', 1, 226, 0.0, 2.3541084391474008],
#  ['построения', 1, 227, 0.0, 2.3560258571931225],
#  ['отражающий', 1, 228, 0.0, 2.3579348470004535],
#  ['переход', 1, 229, 0.0, 2.359835482339888],
#  ['набору', 1, 230, 0.0, 2.3617278360175926],
#  ['скрытыми', 1, 231, 0.0, 2.363611979892144],
#  ['переменными', 1, 232, 0.0, 2.3654879848908994],
#  ['факторами', 1, 233, 0.0, 2.3673559210260184],
#  ['задающими', 1, 234, 0.0, 2.3692158574101425],
#  ['скрытых', 1, 235, 0.0, 2.371067862271736],
#  ['переменных', 1, 236, 0.0, 2.3729120029701067],
#  ['применять', 1, 237, 0.0, 2.374748346010104],
#  ['нечеткую', 1, 238, 0.0, 2.376576957056512],
#  ['кластеризацию', 1, 239, 0.0, 2.3783979009481375],
#  ['разбиение', 1, 240, 0.0, 2.380211241711606],
#  ['пересекающиеся', 1, 241, 0.0, 2.382017042574868],
#  ['классы', 1, 242, 0.0, 2.383815365980431],
#  ['таком', 1, 243, 0.0, 2.3856062735983117],
#  ['результат', 1, 244, 0.0, 2.387389826338729],
#  ['бикластеризации', 1, 245, 0.0, 2.3891660843645326],
#  ['одновременной', 1, 246, 0.0, 2.390935107103379],
#  ['точки', 1, 247, 0.0, 2.392696953259666],
#  ['зрения', 1, 248, 0.0, 2.394451680826216],
#  ['близости', 1, 249, 0.0, 2.396199347095736],
#  ['пределах', 1, 250, 0.0, 2.397940008672037],
#  ['нечеткой', 1, 251, 0.0, 2.3996737214810375],
#  ['любое', 1, 252, 0.0, 2.4014005407815437],
#  ['некоторой', 1, 253, 0.0, 2.4031205211758175],
#  ['вероятностью', 1, 254, 0.0, 2.404833716619938],
#  ['относится', 1, 255, 0.0, 2.4065401804339546],
#  ['нескольким', 1, 256, 0.0, 2.408239965311849],
#  ['темам', 1, 257, 0.0, 2.4099331233312946],
#  ['сказать', 1, 258, 0.0, 2.41161970596323],
#  ['описанию', 1, 259, 0.0, 2.4132997640812515],
#  ['ставится', 1, 260, 0.0, 2.4149733479708178],
#  ['семейство', 1, 261, 0.0, 2.416640507338281],
#  ['выявление', 1, 262, 0.0, 2.4183012913197452],
#  ['основу', 1, 263, 0.0, 2.4199557484897576],
#  ['подход', 1, 264, 0.0, 2.421603926869831],
#  ['называемый', 1, 265, 0.0, 2.4232458739368075],
#  ['мешок', 1, 266, 0.0, 2.4248816366310666],
#  ['упорядочения', 1, 267, 0.0, 2.426511261364575],
#  ['значения', 1, 268, 0.0, 2.4281347940287885],
#  ['учитывается', 1, 269, 0.0, 2.4297522800024076],
#  ['порядок', 1, 270, 0.0, 2.4313637641589874],
#  ['предложении', 1, 271, 0.0, 2.4329692908744054],
#  ['взаимное', 1, 272, 0.0, 2.4345689040341987],
#  ['расположение', 1, 273, 0.0, 2.436162647040756],
#  ['тексте', 1, 274, 0.0, 2.437750562820388],
#  ['тематическом', 1, 275, 0.0, 2.4393326938302624],
#  ['моделировании', 1, 276, 0.0, 2.4409090820652173],
#  ['порождаемых', 1, 277, 0.0, 2.442479769064448],
#  ['время', 1, 278, 0.0, 2.4440447959180758],
#  ['случайная', 1, 279, 0.0, 2.4456042032735974],
#  ['выборка', 1, 280, 0.0, 2.447158031342219],
#  ['порожденная', 1, 281, 0.0, 2.4487063199050794],
#  ['неким', 1, 282, 0.0, 2.450249108319361],
#  ['множеством', 1, 283, 0.0, 2.45178643552429],
#  ['исходя', 1, 284, 0.0, 2.4533183400470375],
#  ['этого', 1, 285, 0.0, 2.45484486000851],
#  ['установить', 1, 286, 0.0, 2.4563660331290427],
#  ['выяснить', 1, 287, 0.0, 2.4578818967339924],
#  ['каким', 1, 288, 0.0, 2.4593924877592306],
#  ['набором', 1, 289, 0.0, 2.4608978427565478],
#  ['порождается', 1, 290, 0.0, 2.4623979978989556],
#  ['конкретный', 1, 291, 0.0, 2.4638929889859074],
#  ['лингвистическом', 1, 292, 0.0, 2.465382851448418],
#  ['смысле', 1, 293, 0.0, 2.4668676203541096],
#  ['есть', 1, 294, 0.0, 2.468347330412157],
#  ['характеризующий', 1, 295, 0.0, 2.469822015978163],
#  ['отдельный', 1, 296, 0.0, 2.4712917110589383],
#  ['тестовой', 1, 297, 0.0, 2.4727564493172123],
#  ['присутствовать', 1, 298, 0.0, 2.4742162640762553],
#  ['искусство', 1, 299, 0.0, 2.4756711883244296],
#  ['дети', 1, 300, 0.0, 2.477121254719662],
#  ['образование', 1, 301, 0.0, 2.478566495593843],
#  ['жизнь', 1, 302, 0.0, 2.4800069429571505],
#  ['ген', 1, 303, 0.0, 2.481442628502305],
#  ['мозг', 1, 304, 0.0, 2.4828735836087534],
#  ['ассоциируемые', 1, 305, 0.0, 2.484299839346786],
#  ['наборами', 1, 306, 0.0, 2.4857214264815797],
#  ['имеющих', 1, 307, 0.0, 2.487138375477186],
#  ['определенную', 1, 308, 0.0, 2.488550716500444],
#  ['частоту', 1, 309, 0.0, 2.4899584794248346],
#  ['вероятность', 1, 310, 0.0, 2.4913616938342726],
#  ['появления', 1, 311, 0.0, 2.492760389026837],
#  ['соответствующих', 1, 312, 0.0, 2.4941545940184424],
#  ['типы', 1, 313, 0.0, 2.4955443375464483],
#  ['разработках', 1, 314, 0.0, 2.4969296480732144],
#  ['последних', 1, 315, 0.0, 2.4983105537896004],
#  ['широко', 1, 316, 0.0, 2.4996870826184034],
#  ['ряд', 1, 317, 0.0, 2.501059262217751],
#  ['алгебраических', 1, 318, 0.0, 2.5024271199844326],
#  ['опираются', 1, 319, 0.0, 2.503790683057181],
#  ['процедуры', 1, 320, 0.0, 2.505149978319906],
#  ['распространены', 1, 321, 0.0, 2.506505032404872],
#  ['стандартная', 1, 322, 0.0, 2.507855871695831],
#  ['векторная', 1, 323, 0.0, 2.5092025223311025],
#  ['генеративных', 1, 324, 0.0, 2.5105450102066116],
#  ['применяются', 1, 325, 0.0, 2.511883360978874],
#  ['вероятностный', 1, 326, 0.0, 2.513217600067939],
#  ['латентное', 1, 327, 0.0, 2.514547752660286],
#  ['размещение', 1, 328, 0.0, 2.515873843711679],
#  ['дадим', 1, 329, 0.0, 2.517195897949974],
#  ['краткую', 1, 330, 0.0, 2.518513939877887],
#  ['характеристику', 1, 331, 0.0, 2.5198279937757184],
#  ['подробные', 1, 332, 0.0, 2.521138083704036],
#  ['обзоры', 1, 333, 0.0, 2.5224442335063197],
#  ['матрицей', 1, 334, 0.0, 2.5237464668115646],
#  ['словам', 1, 335, 0.0, 2.5250448070368448],
#  ['ставятся', 1, 336, 0.0, 2.5263392773898437],
#  ['вектора', 1, 337, 0.0, 2.5276299008713385],
#  ['мерном', 1, 338, 0.0, 2.5289167002776547],
#  ['пространстве', 1, 339, 0.0, 2.5301996982030817],
#  ['векторов', 1, 340, 0.0, 2.531478917042255],
#  ['правило', 1, 341, 0.0, 2.5327543789924976],
#  ['определение', 1, 342, 0.0, 2.5340261060561344],
#  ['косинуса', 1, 343, 0.0, 2.53529412004277],
#  ['угла', 1, 344, 0.0, 2.53655844257153],
#  ['векторами', 1, 345, 0.0, 2.537819095073274],
#  ['характерно', 1, 346, 0.0, 2.5390760987927767],
#  ['документе', 1, 347, 0.0, 2.5403294747908736],
#  ['близки', 1, 348, 0.0, 2.5415792439465807],
#  ['неудобством', 1, 349, 0.0, 2.5428254269591797],
#  ['использования', 1, 350, 0.0, 2.5440680443502752],
#  ['невозможностью', 1, 351, 0.0, 2.545307116465824],
#  ['синонимические', 1, 352, 0.0, 2.5465426634781307],
#  ['отношения', 1, 353, 0.0, 2.5477747053878224],
#  ['словами', 1, 354, 0.0, 2.5490032620257876],
#  ['наследует', 1, 355, 0.0, 2.5502283530550938],
#  ['основные', 1, 356, 0.0, 2.551449997972875],
#  ['характеристики', 1, 357, 0.0, 2.5526682161121927],
#  ['сокращения', 1, 358, 0.0, 2.553883026643874],
#  ['размерности', 1, 359, 0.0, 2.555094448578319],
#  ['значимых', 1, 360, 0.0, 2.5563025007672873],
#  ['текстах', 1, 361, 0.0, 2.5575072019056577],
#  ['сингулярное', 1, 362, 0.0, 2.558708570533166],
#  ['разложение', 1, 363, 0.0, 2.559906625036112],
#  ['матрицы', 1, 364, 0.0, 2.5611013836490555],
#  ['отличие', 1, 365, 0.0, 2.5622928644564746],
#  ['пригодна', 1, 366, 0.0, 2.56348108539441],
#  ['контекстную', 1, 367, 0.0, 2.5646660642520893],
#  ['синонимию', 1, 368, 0.0, 2.5658478186735176],
#  ['справляется', 1, 369, 0.0, 2.56702636615906],
#  ['многозначностью', 1, 370, 0.0, 2.5682017240669945],
#  ['сложно', 1, 371, 0.0, 2.5693739096150456],
#  ['заранее', 1, 372, 0.0, 2.5705429398818973],
#  ['задать', 1, 373, 0.0, 2.5717088318086874],
#  ['ожидаемое', 1, 374, 0.0, 2.57287160220048],
#  ['приписать', 1, 375, 0.0, 2.5740312677277184],
#  ['метку', 1, 376, 0.0, 2.575187844927661],
#  ['используя', 1, 377, 0.0, 2.5763413502057926],
#  ['какое', 1, 378, 0.0, 2.577491799837225],
#  ['ключевое', 1, 379, 0.0, 2.578639209968072],
#  ['являет', 1, 380, 0.0, 2.57978359661681],
#  ['вероятностную', 1, 381, 0.0, 2.580924975675619],
#  ['модификацию', 1, 382, 0.0, 2.5820633629117085],
#  ['порождение', 1, 383, 0.0, 2.5831987739686224],
#  ['производится', 1, 384, 0.0, 2.5843312243675305],
#  ['соответствии', 1, 385, 0.0, 2.5854607295085006],
#  ['методом', 1, 386, 0.0, 2.5865873046717547],
#  ['байеса', 1, 387, 0.0, 2.5877109650189114],
#  ['отчасти', 1, 388, 0.0, 2.5888317255942073],
#  ['учитывает', 1, 389, 0.0, 2.5899496013257073],
#  ['значениях', 1, 390, 0.0, 2.591064607026499],
#  ['многозначные', 1, 391, 0.0, 2.5921767573958667],
#  ['представлять', 1, 392, 0.0, 2.5932860670204567],
#  ['разные', 1, 393, 0.0, 2.5943925503754266],
#  ['основ', 1, 394, 0.0, 2.5954962218255737],
#  ['ные', 1, 395, 0.0, 2.59659709562646],
#  ['риском', 1, 396, 0.0, 2.597695185925512],
#  ['переобучения', 1, 397, 0.0, 2.598790506763115],
#  ['сложностью', 1, 398, 0.0, 2.5998830720736876],
#  ['добавления', 1, 399, 0.0, 2.600972895686748],
#  ['сглаживает', 1, 400, 0.0, 2.602059991327962],
#  ['шероховатости', 1, 401, 0.0, 2.603144372620182],
#  ['предыдущих', 1, 402, 0.0, 2.60422605308447],
#  ['опирающейся', 1, 403, 0.0, 2.605305046141109],
#  ['каждая', 1, 404, 0.0, 2.6063813651106047],
#  ['характеризуется', 1, 405, 0.0, 2.6074550232146683],
#  ['вероятностным', 1, 406, 0.0, 2.608526033577194],
#  ['распределением', 1, 407, 0.0, 2.6095944092252195],
#  ['описываются', 1, 408, 0.0, 2.6106601630898796],
#  ['описывать', 1, 409, 0.0, 2.611723308007342],
#  ['корпуса', 1, 410, 0.0, 2.6127838567197355],
#  ['большого', 1, 411, 0.0, 2.613841821876069],
#  ['объема', 1, 412, 0.0, 2.6148972160331345],
#  ['одну', 1, 413, 0.0, 2.615950051656401],
#  ['тему', 1, 414, 0.0, 2.6170003411208986],
#  ['попадать', 1, 415, 0.0, 2.6180480967120925],
#  ['частей', 1, 416, 0.0, 2.6190933306267423],
#  ['речи', 1, 417, 0.0, 2.620136054973757],
#  ['данная', 1, 418, 0.0, 2.621176281775035],
#  ['предусматривает', 1, 419, 0.0, 2.622214022966295],
#  ['установление', 1, 420, 0.0, 2.6232492903979003],
#  ['темами', 1, 421, 0.0, 2.624282095835668],
#  ['известны', 1, 422, 0.0, 2.625312450961674],
#  ['мере', 1, 423, 0.0, 2.626340367375042],
#  ['связанные', 1, 424, 0.0, 2.6273658565927325],
#  ['упомянутыми', 1, 425, 0.0, 2.6283889300503116],
#  ['совместная', 1, 426, 0.0, 2.629409599102719],
#  ['вероятностная', 1, 427, 0.0, 2.6304278750250236],
#  ['скрытая', 1, 428, 0.0, 2.631443769013172],
#  ['марковская', 1, 429, 0.0, 2.632457292184724],
#  ['автортематическая', 1, 430, 0.0, 2.633468455579586],
#  ['автор', 1, 431, 0.0, 2.634477270160731],
#  ['получатель', 1, 432, 0.0, 2.635483746814912],
#  ['корреляционная', 1, 433, 0.0, 2.636487896353365],
#  ['спецификация', 1, 434, 0.0, 2.6374897295125104],
#  ['связана', 1, 435, 0.0, 2.638489256954637],
#  ['различиями', 1, 436, 0.0, 2.639486489268586],
#  ['уровне', 1, 437, 0.0, 2.6404814369704215],
#  ['лингвистической', 1, 438, 0.0, 2.6414741105040993],
#  ['входных', 1, 439, 0.0, 2.6424645202421213],
#  ['привлечением', 1, 440, 0.0, 2.643452676486187],
#  ['аппарата', 1, 441, 0.0, 2.644438589467838],
#  ['дистрибутивной', 1, 442, 0.0, 2.6454222693490914],
#  ['семантики', 1, 443, 0.0, 2.6464037262230695],
#  ['большинство', 1, 444, 0.0, 2.6473829701146196],
#  ['языковых', 1, 445, 0.0, 2.648360010980931],
#  ['ресурсов', 1, 446, 0.0, 2.649334858712142],
#  ['склоняются', 1, 447, 0.0, 2.650307523131936],
#  ['необходимости', 1, 448, 0.0, 2.6512780139981436],
#  ['интеграции', 1, 449, 0.0, 2.6522463410033232],
#  ['статистических', 1, 450, 0.0, 2.6532125137753435],
#  ['традиционных', 1, 451, 0.0, 2.6541765418779604],
#  ['лингвистических', 1, 452, 0.0, 2.655138434811382],
#  ['анализа', 1, 453, 0.0, 2.656098202012832],
#  ['реализовано', 1, 454, 0.0, 2.6570558528571038],
#  ['использование', 1, 455, 0.0, 2.658011396657112],
#  ['многоуровневой', 1, 456, 0.0, 2.658964842664435],
#  ['разметки', 1, 457, 0.0, 2.65991620006985],
#  ['лемматизация', 1, 458, 0.0, 2.660865478003869],
#  ['морфосинтаксическая', 1, 459, 0.0, 2.661812685537261],
#  ['доступности', 1, 460, 0.0, 2.662757831681574],
#  ['семантическая', 1, 461, 0.0, 2.663700925389648],
#  ['аннотация', 1, 462, 0.0, 2.6646419755561253],
#  ['учет', 1, 463, 0.0, 2.665580991017953],
#  ['границ', 1, 464, 0.0, 2.6665179805548807],
#  ['синтаксических', 1, 465, 0.0, 2.6674529528899535],
#  ['групп', 1, 466, 0.0, 2.6683859166899997],
#  ['существующих', 1, 467, 0.0, 2.669316880566112],
#  ['ограничение', 1, 468, 0.0, 2.6702458530741238],
#  ['контекстного', 1, 469, 0.0, 2.671172842715083],
#  ['окна', 1, 470, 0.0, 2.672097857935717],
#  ['назначение', 1, 471, 0.0, 2.6730209071288957],
#  ['весов', 1, 472, 0.0, 2.6739419986340875],
#  ['контекстных', 1, 473, 0.0, 2.674861140737811],
#  ['элементов', 1, 474, 0.0, 2.675778341674085],
#  ['нормализация', 1, 475, 0.0, 2.6766936096248664],
#  ['значений', 1, 476, 0.0, 2.677606952720493],
#  ['коэффициентов', 1, 477, 0.0, 2.678518379040114],
#  ['свертка', 1, 478, 0.0, 2.6794278966121188],
#  ['методы', 1, 479, 0.0, 2.6803355134145628],
#  ['способствуют', 1, 480, 0.0, 2.681241237375587],
#  ['повышению', 1, 481, 0.0, 2.6821450763738315],
#  ['качества', 1, 482, 0.0, 2.683047038238849],
#  ['выборе', 1, 483, 0.0, 2.6839471307515117],
#  ['инструмента', 1, 484, 0.0, 2.6848453616444123],
#  ['руководствовались', 1, 485, 0.0, 2.6857417386022635],
#  ['доступностью', 1, 486, 0.0, 2.686636269262293],
#  ['гибкостью', 1, 487, 0.0, 2.687528961214634],
#  ['устойчивостью', 1, 488, 0.0, 2.6884198220027105],
#  ['остановились', 1, 489, 0.0, 2.6893088591236203],
#  ['пакете', 1, 490, 0.0, 2.6901960800285134],
#  ['реализующем', 1, 491, 0.0, 2.691081492122968],
#  ['разработчики', 1, 492, 0.0, 2.69196510276736],
#  ['ньюмэн', 1, 493, 0.0, 2.6928469192772297],
#  ['коллеги', 1, 494, 0.0, 2.6937269489236466],
#  ['калифорнийский', 1, 495, 0.0, 2.6946051989335684],
#  ['университет', 1, 496, 0.0, 2.695481676490197],
#  ['пакеты', 1, 497, 0.0, 2.696356388733332],
#  ['конце', 1, 498, 0.0, 2.697229342759717],
#  ['раздел', 1, 499, 0.0, 2.6981005456233897],
#  ['реализации', 1, 500, 0.0, 2.6989700043360183],
#  ['программа', 1, 501, 0.0, 2.6998377258672455],
#  ['удобный', 1, 502, 0.0, 2.700703717145019],
#  ['интерфейс', 1, 503, 0.0, 2.7015679850559273],
#  ['пользователь', 1, 504, 0.0, 2.702430536445525],
#  ['загружает', 1, 505, 0.0, 2.7032913781186614],
#  ['выбирает', 1, 506, 0.0, 2.704150516839799],
#  ['параметры', 1, 507, 0.0, 2.705007959333336],
#  ['генерируются', 1, 508, 0.0, 2.705863712283919],
#  ['итераций', 1, 509, 0.0, 2.7067177823367583],
#  ['списков', 1, 510, 0.0, 2.707570176097936],
#  ['выдача', 1, 511, 0.0, 2.7084209001347124],
#  ['результатов', 1, 512, 0.0, 2.7092699609758304],
#  ['программы', 1, 513, 0.0, 2.710117365111816],
#  ['списки', 1, 514, 0.0, 2.7109631189952754],
#  ['проводились', 1, 515, 0.0, 2.7118072290411908],
#  ['латинице', 1, 516, 0.0, 2.7126497016272113],
#  ['английском', 1, 517, 0.0, 2.7134905430939424],
#  ['языке', 1, 518, 0.0, 2.7143297597452327],
#  ['качестве', 1, 519, 0.0, 2.7151673578484576],
#  ['использовались', 1, 520, 0.0, 2.716003343634799],
#  ['журнала', 1, 521, 0.0, 2.716837723299524],
#  ['мировой', 1, 522, 0.0, 2.717670503002262],
#  ['политике', 1, 523, 0.0, 2.718501688867274],
#  ['экклезиологической', 1, 524, 0.0, 2.7193312869837265],
#  ['научные', 1, 525, 0.0, 2.7201593034059566],
#  ['материалы', 1, 526, 0.0, 2.720985744153739],
#  ['научно', 1, 527, 0.0, 2.7218106152125463],
#  ['популярные', 1, 528, 0.0, 2.722633922533812],
#  ['художественные', 1, 529, 0.0, 2.7234556720351857],
#  ['рассказы', 1, 530, 0.0, 2.7242758696007887],
#  ['повести', 1, 531, 0.0, 2.725094521081469],
#  ['ф', 1, 532, 0.0, 2.725911632295048],
#  ['старк', 1, 533, 0.0, 2.726727209026572],
#  ['даррелла', 1, 534, 0.0, 2.727541257028556],
#  ['деловые', 1, 535, 0.0, 2.728353782021228],
#  ['конвенции', 1, 536, 0.0, 2.7291647896927698],
#  ['правам', 1, 537, 0.0, 2.7299742856995555],
#  ['человека', 1, 538, 0.0, 2.730782275666389],
#  ['обоснованно', 1, 539, 0.0, 2.7315887651867388],
#  ['метод', 1, 540, 0.0, 2.7323937598229686],
#  ['утверждению', 1, 541, 0.0, 2.733197265106569],
#  ['специалистов', 1, 542, 0.0, 2.7339992865383866],
#  ['пригоден', 1, 543, 0.0, 2.7347998295888467],
#  ['умеренных', 1, 544, 0.0, 2.7355988996981795],
#  ['нашем', 1, 545, 0.0, 2.736396502276642],
#  ['варьироваться', 1, 546, 0.0, 2.737192642704737],
#  ['десятков', 1, 547, 0.0, 2.7379873263334304],
#  ['сотен', 1, 548, 0.0, 2.738780558484369],
#  ['средней', 1, 549, 0.0, 2.7395723444500915],
#  ['достаточно', 1, 550, 0.0, 2.740362689494243],
#  ['выполнялись', 1, 551, 0.0, 2.741151598851785],
#  ['пошагово', 1, 552, 0.0, 2.7419390777291985],
#  ['приведем', 1, 553, 0.0, 2.742725131304698],
#  ['отдельные', 1, 554, 0.0, 2.7435097647284294],
#  ['иллюстрации', 1, 555, 0.0, 2.744292983122676],
#  ['дающие', 1, 556, 0.0, 2.745074791582057],
#  ['представление', 1, 557, 0.0, 2.745855195173729],
#  ['результатах', 1, 558, 0.0, 2.746634198937578],
#  ['прокомментируем', 1, 559, 0.0, 2.747411807886423],
#  ['проведено', 1, 560, 0.0, 2.7481880270062002],
#  ['научных', 1, 561, 0.0, 2.748962861256161],
#  ['материалов', 1, 562, 0.0, 2.7497363155690606],
#  ['лингвистике', 1, 563, 0.0, 2.7505083948513462],
#  ['общий', 1, 564, 0.0, 2.751279103983342],
#  ['примерно', 1, 565, 0.0, 2.7520484478194382],
#  ['имеется', 1, 566, 0.0, 2.7528164311882715],
#  ['подробная', 1, 567, 0.0, 2.753583058892906],
#  ['информация', 1, 568, 0.0, 2.754348335711019],
#  ['данной', 1, 569, 0.0, 2.755112266395071],
#  ['описание', 1, 570, 0.0, 2.7558748556724915],
#  ['основных', 1, 571, 0.0, 2.7566361082458477],
#  ['основе', 1, 572, 0.0, 2.757396028793024],
#  ['адекватно', 1, 573, 0.0, 2.75815462196739],
#  ['отражают', 1, 574, 0.0, 2.7589118923979736],
#  ['содержательное', 1, 575, 0.0, 2.75966784468963],
#  ['разнообразие', 1, 576, 0.0, 2.760422483423212],
#  ['охватывающей', 1, 577, 0.0, 2.7611758131557314],
#  ['направления', 1, 578, 0.0, 2.761927838420529],
#  ['лингвистики', 1, 579, 0.0, 2.762678563727436],
#  ['редким', 1, 580, 0.0, 2.763427993562937],
#  ['исключением', 1, 581, 0.0, 2.76417613239033],
#  ['отличаются', 1, 582, 0.0, 2.7649229846498886],
#  ['компактностью', 1, 583, 0.0, 2.7656685547590136],
#  ['низкой', 1, 584, 0.0, 2.766412847112399],
#  ['долей', 1, 585, 0.0, 2.7671558660821804],
#  ['шума', 1, 586, 0.0, 2.7678976160180904],
#  ['следующее', 1, 587, 0.0, 2.7686381012476144],
#  ['имели', 1, 588, 0.0, 2.769377326076138],
#  ['сравнить', 1, 589, 0.0, 2.7701152947871015],
#  ['ранними', 1, 590, 0.0, 2.770852011642144],
#  ['результатами', 1, 591, 0.0, 2.771587480881255],
#  ['автоматического', 1, 592, 0.0, 2.7723217067229196],
#  ['выделения', 1, 593, 0.0, 2.7730546933642626],
#  ['полученных', 1, 594, 0.0, 2.7737864449811935],
#  ['стандартной', 1, 595, 0.0, 2.7745169657285493],
#  ['векторной', 1, 596, 0.0, 2.775246259740236],
#  ['моделью', 1, 597, 0.0, 2.775974331129369],
#  ['ассоциированных', 1, 598, 0.0, 2.7767011839884104],
#  ['заметно', 1, 599, 0.0, 2.777426822389311],
#  ['значимыми', 1, 600, 0.0, 2.7781512503836434],
#  ['этом', 1, 601, 0.0, 2.778874472002739],
#  ['перечне', 1, 602, 0.0, 2.7795964912578244],
#  ['являются', 1, 603, 0.0, 2.780317312140151],
#  ['первые', 1, 604, 0.0, 2.7810369386211318],
#  ['три', 1, 605, 0.0, 2.7817553746524686],
#  ['имена', 1, 606, 0.0, 2.782472624166286],
#  ['собственные', 1, 607, 0.0, 2.7831886910752575],
#  ['семантике', 1, 608, 0.0, 2.7839035792727347],
#  ['напрямую', 1, 609, 0.0, 2.784617292632875],
#  ['всё', 1, 610, 0.0, 2.7853298350107667],
#  ['свидетельствует', 1, 611, 0.0, 2.786041210242554],
#  ['пользу', 1, 612, 0.0, 2.786751422145561],
#  ['проанализированы', 1, 613, 0.0, 2.787460474518415],
#  ['истории', 1, 614, 0.0, 2.7881683711411673],
#  ['косово', 1, 615, 0.0, 2.7888751157754164],
#  ['метохии', 1, 616, 0.0, 2.789580712164425],
#  ['каждого', 1, 617, 0.0, 2.7902851640332416],
#  ['рассматриваемые', 1, 618, 0.0, 2.7909884750888154],
#  ['имеют', 1, 619, 0.0, 2.7916906490201177],
#  ['пересекающуюся', 1, 620, 0.0, 2.792391689498254],
#  ['православие', 1, 621, 0.0, 2.79309160017658],
#  ['политическая', 1, 622, 0.0, 2.7937903846908183],
#  ['история', 1, 623, 0.0, 2.7944880466591693],
#  ['нашло', 1, 624, 0.0, 2.7951845896824237],
#  ['отражение', 1, 625, 0.0, 2.795880017344075],
#  ['наборах', 1, 626, 0.0, 2.796574333210429],
#  ['указанные', 1, 627, 0.0, 2.7972675408307164],
#  ['имен', 1, 628, 0.0, 2.7979596437371956],
#  ['собственных', 1, 629, 0.0, 2.7986506454452686],
#  ['общих', 1, 630, 0.0, 2.7993405494535817],
#  ['двух', 1, 631, 0.0, 2.800029359244134],
#  ['первого', 1, 632, 0.0, 2.8007170782823847],
#  ['содержат', 1, 633, 0.0, 2.8014037100173548],
#  ['второго', 1, 634, 0.0, 2.8020892578817325],
#  ['приводятся', 1, 635, 0.0, 2.8027737252919755],
#  ['проиллюстрированы', 1, 636, 0.0, 2.803457115648414],
#  ['провели', 1, 637, 0.0, 2.80413943233535],
#  ['автоматическую', 1, 638, 0.0, 2.804820678721162],
#  ['обработку', 1, 639, 0.0, 2.8055008581584],
#  ['рассматривались', 1, 640, 0.0, 2.8061799739838866],
#  ['средств', 1, 641, 0.0, 2.8068580295188172],
#  ['некоторых', 1, 642, 0.0, 2.807535028068853],
#  ['других', 1, 643, 0.0, 2.8082109729242215],
#  ['трех', 1, 644, 0.0, 2.808885867359812],
#  ['источниках', 1, 645, 0.0, 2.8095597146352675],
#  ['книга', 1, 646, 0.0, 2.810232517995084],
#  ['кента', 1, 647, 0.0, 2.8109042806687],
#  ['которая', 1, 648, 0.0, 2.811575005870593],
#  ['считается', 1, 649, 0.0, 2.812244696800369],
#  ['авторитетным', 1, 650, 0.0, 2.8129133566428552],
#  ['справочником', 1, 651, 0.0, 2.8135809885681917],
#  ['энциклопедия', 1, 652, 0.0, 2.81424759573192],
#  ['современных', 1, 653, 0.0, 2.814913181275074],
#  ['грив', 1, 654, 0.0, 2.815577748324267],
#  ['база', 1, 655, 0.0, 2.8162412999917827],
#  ['сформированных', 1, 656, 0.0, 2.81690383937566],
#  ['вошедших', 1, 657, 0.0, 2.81756536955978],
#  ['первый', 1, 658, 0.0, 2.8182258936139553],
#  ['предсказуемым', 1, 659, 0.0, 2.8188854145940097],
#  ['образом', 1, 660, 0.0, 2.8195439355418683],
#  ['симптомах', 1, 661, 0.0, 2.8202014594856397],
#  ['связанных', 1, 662, 0.0, 2.8208579894396997],
#  ['лекарственными', 1, 663, 0.0, 2.8215135284047728],
#  ['второй', 1, 664, 0.0, 2.822168079368017],
#  ['ожиданиям', 1, 665, 0.0, 2.8228216453031045],
#  ['скорее', 1, 666, 0.0, 2.823474229170301],
#  ['медицинского', 1, 667, 0.0, 2.8241258339165487],
#  ['ботанического', 1, 668, 0.0, 2.8247764624755454],
#  ['характера', 1, 669, 0.0, 2.825426117767823],
#  ['третий', 1, 670, 0.0, 2.826074802700826],
#  ['следовало', 1, 671, 0.0, 2.826722520168992],
#  ['информацию', 1, 672, 0.0, 2.827369273053825],
#  ['внешнем', 1, 673, 0.0, 2.8280150642239765],
#  ['виде', 1, 674, 0.0, 2.8286598965353194],
#  ['условиях', 1, 675, 0.0, 2.829303772831025],
#  ['произрастания', 1, 676, 0.0, 2.829946695941636],
#  ['особенностях', 1, 677, 0.0, 2.8305886686851442],
#  ['сбора', 1, 678, 0.0, 2.831229693867063],
#  ['хранения', 1, 679, 0.0, 2.8318697742805017],
#  ['меньшей', 1, 680, 0.0, 2.8325089127062357],
#  ['степени', 1, 681, 0.0, 2.8331471119127847],
#  ['свойствах', 1, 682, 0.0, 2.833784374656479],
#  ['заключение', 1, 683, 0.0, 2.8344207036815323],
#  ['наблюдения', 1, 684, 0.0, 2.8350561017201157],
#  ['сделанные', 1, 685, 0.0, 2.8356905714924254],
#  ['нами', 1, 686, 0.0, 2.836324115706751],
#  ['ходе', 1, 687, 0.0, 2.83695673705955],
#  ['позволяют', 1, 688, 0.0, 2.8375884382355108],
#  ['одобрительно', 1, 689, 0.0, 2.8382192219076257],
#  ['относиться', 1, 690, 0.0, 2.8388490907372548],
#  ['алгоритму', 1, 691, 0.0, 2.839478047374198],
#  ['средству', 1, 692, 0.0, 2.8401060944567575],
#  ['пригодному', 1, 693, 0.0, 2.8407332346118066],
#  ['качественного', 1, 694, 0.0, 2.841359470454855],
#  ['сжатия', 1, 695, 0.0, 2.8419848045901137],
#  ['оценки', 1, 696, 0.0, 2.842609239610562],
#  ['содержания', 1, 697, 0.0, 2.843232778098009],
#  ['соответствия', 1, 698, 0.0, 2.843855422623161],
#  ['тематике', 1, 699, 0.0, 2.844477175745681],
#  ['перспективы', 1, 700, 0.0, 2.8450980400142565],
#  ['исследования', 1, 701, 0.0, 2.8457180179666586],
#  ['сопоставительным', 1, 702, 0.0, 2.8463371121298047],
#  ['анализом', 1, 703, 0.0, 2.846955325019824],
#  ['набора', 1, 704, 0.0, 2.847572659142112],
#  ['имеющихся', 1, 705, 0.0, 2.8481891169913984],
#  ['открытом', 1, 706, 0.0, 2.8488047010518036],
#  ['доступе', 1, 707, 0.0, 2.849419413796899],
#  ['которых', 1, 708, 0.0, 2.850033257689769],
#  ['реализована', 1, 709, 0.0, 2.850646235183066],
#  ['адаптацией', 1, 710, 0.0, 2.851258348719075],
#  ['русскоязычными', 1, 711, 0.0, 2.851869600729766],
#  ['решение', 1, 712, 0.0, 2.852479993636856],
#  ['будет', 1, 713, 0.0, 2.8530895298518653],
#  ['способствовать', 1, 714, 0.0, 2.853698211776174],
#  ['автоматическому', 1, 715, 0.0, 2.85430604180108],
#  ['русскоязычных', 1, 716, 0.0, 2.8549130223078554]]

# %%
frame = pd.DataFrame(n_list, columns=['Words','Frequencies','Ranks', 'Logarithm of Frequencies', 'Logarithm of ranks']) # собираем фрейм
frame.to_csv('Frequency Dictionary.csv',encoding='utf-8', sep=';', index=False) #экспортируем в файл

# %%
bigrams = nltk.collocations.BigramAssocMeasures()
trigrams = nltk.collocations.TrigramAssocMeasures()

bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(text_words)
trigramFinder = nltk.collocations.TrigramCollocationFinder.from_words(text_words)

# bigrams
bigram_freq = bigramFinder.ngram_fd.items()
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)
bigramFreqTable.to_csv('Bigrams.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# trigrams
trigram_freq = trigramFinder.ngram_fd.items()
trigramFreqTable = pd.DataFrame(list(trigram_freq), columns=['trigram','freq']).sort_values(by='freq', ascending=False)
trigramFreqTable.to_csv('Trigrams.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# %%
bigram_freq
# Out:
# dict_items([(('введение', 'разработка'), 1), (('разработка', 'новых'), 1), (('новых', 'подходов'), 1), (('подходов', 'лингвистическому'), 1), (('лингвистическому', 'моделированию'), 1), (('моделированию', 'позволяет'), 1), (('позволяет', 'исследователям'), 1), (('исследователям', 'новому'), 1), (('новому', 'взглянуть'), 1), (('взглянуть', 'важный'), 1), (('важный', 'класс'), 1), (('класс', 'задач'), 1), (('задач', 'автоматической'), 1), (('автоматической', 'обработки'), 4), (('обработки', 'естественного'), 1), (('естественного', 'языка'), 1), (('языка', 'смысловую'), 1), (('смысловую', 'компрессию'), 1), (('компрессию', 'текста'), 1), (('текста', 'производимую'), 1), (('производимую', 'автоматическом'), 1), (('автоматическом', 'выделении'), 1), (('выделении', 'ключевых'), 1), (('ключевых', 'слов'), 6), (('слов', 'словосочетаний'), 1), (('словосочетаний', 'классификации'), 1), (('классификации', 'кластеризации'), 1), (('кластеризации', 'лексики'), 1), (('лексики', 'документов'), 1), (('документов', 'корпусах'), 1), (('корпусах', 'текстов'), 1), (('текстов', 'выделении'), 1), (('выделении', 'классов'), 1), (('классов', 'слов'), 1), (('слов', 'близкими'), 1), (('близкими', 'дистрибутивными'), 1), (('дистрибутивными', 'свойствами'), 1), (('свойствами', 'оценке'), 1), (('оценке', 'семантической'), 1), (('семантической', 'однородности'), 1), (('однородности', 'неоднородности'), 1), (('неоднородности', 'текстов'), 1), (('текстов', 'т'), 3), (('т', 'п'), 6), (('п', 'ср'), 1), (('ср', 'наши'), 1), (('наши', 'эксперименты'), 2), (('эксперименты', 'описанные'), 1), (('описанные', 'статьях'), 1), (('статьях', 'митрофанова'), 1), (('митрофанова', 'мухин'), 1), (('мухин', 'паничева'), 1), (('паничева', 'митрофанова'), 1), (('митрофанова', 'митрофанова'), 1), (('митрофанова', 'грачкова'), 1), (('грачкова', 'шиморина'), 1), (('шиморина', 'данном'), 1), (('данном', 'ряду'), 1), (('ряду', 'особняком'), 1), (('особняком', 'стоит'), 1), (('стоит', 'задача'), 1), (('задача', 'тематического'), 1), (('тематического', 'моделирования'), 10), (('моделирования', 'корпусов'), 1), (('корпусов', 'текстов'), 1), (('текстов', 'последние'), 1), (('последние', 'несколько'), 1), (('несколько', 'лет'), 1), (('лет', 'арсенал'), 1), (('арсенал', 'методов'), 1), (('методов', 'тематического'), 3), (('моделирования', 'существенно'), 1), (('существенно', 'расширился'), 1), (('расширился', 'появились'), 1), (('появились', 'доступные'), 1), (('доступные', 'исследователям'), 1), (('исследователям', 'компьютерные'), 1), (('компьютерные', 'инструменты'), 1), (('инструменты', 'автоматической'), 1), (('обработки', 'текстов'), 4), (('т', 'д'), 11), (('д', 'создающие'), 1), (('создающие', 'предпосылки'), 1), (('предпосылки', 'проведению'), 1), (('проведению', 'экспериментов'), 2), (('экспериментов', 'параллельно'), 1), (('параллельно', 'расширяется'), 1), (('расширяется', 'круг'), 1), (('круг', 'практических'), 1), (('практических', 'задач'), 1), (('задач', 'которые'), 1), (('которые', 'решаются'), 1), (('решаются', 'данными'), 1), (('данными', 'средствами'), 1), (('средствами', 'особое'), 1), (('особое', 'внимание'), 1), (('внимание', 'исследователей'), 1), (('исследователей', 'обращено'), 1), (('обращено', 'анализу'), 1), (('анализу', 'социальных'), 1), (('социальных', 'сетей'), 1), (('сетей', 'выявлению'), 1), (('выявлению', 'тематической'), 1), (('тематической', 'структуры'), 2), (('структуры', 'сообществ'), 1), (('сообществ', 'связи'), 1), (('связи', 'этим'), 1), (('этим', 'представляется'), 1), (('представляется', 'важным'), 1), (('важным', 'оценить'), 1), (('оценить', 'особенности'), 1), (('особенности', 'различных'), 1), (('различных', 'методов'), 1), (('моделирования', 'применимость'), 1), (('применимость', 'иным'), 1), (('иным', 'экспериментальным'), 1), (('экспериментальным', 'данным'), 1), (('данным', 'тематическое'), 1), (('тематическое', 'моделирование'), 3), (('моделирование', 'такое'), 1), (('такое', 'тематическое'), 1), (('моделирование', 'способ'), 1), (('спо ...

# %%
# t-test
bigramTtable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.student_t)), columns=['bigram','T-test']).sort_values(by='T-test', ascending=False)
trigramTtable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.student_t)), columns=['trigram','T-test']).sort_values(by='T-test', ascending=False)
bigramTtable = bigramTtable.head(20)
trigramTtable = trigramTtable.head(20) #вычленяем первые 20 лучших би- и триграммов
bigramTtable.to_csv('Bigrams-T-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramTtable.to_csv('Trigrams-T-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# chi-squared
bigramCHItable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.chi_sq)), columns=['bigram','Chi-squared']).sort_values(by='Chi-squared', ascending=False)
trigramCHItable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.chi_sq)), columns=['trigram','Chi-squared']).sort_values(by='Chi-squared', ascending=False)
bigramCHItable = bigramCHItable.head(20)
trigramCHItable = trigramCHItable.head(20) #вычленяем первые 20 лучших би- и триграммов
bigramCHItable.to_csv('Bigrams-CHI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramCHItable.to_csv('Trigrams-CHI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# log-likelihood
bigramlikelihoodtable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.likelihood_ratio)), columns=['bigram','Log-Likelihood']).sort_values(by='Log-Likelihood', ascending=False)
trigramlikelihoodtable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.likelihood_ratio)), columns=['trigram','Log-Likelihood']).sort_values(by='Log-Likelihood', ascending=False)
bigramlikelihoodtable = bigramlikelihoodtable.head(20)
trigramlikelihoodtable = trigramlikelihoodtable.head(20) #вычленяем первые 20 лучших би- и триграммов
bigramlikelihoodtable.to_csv('Bigrams-likelihood-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramlikelihoodtable.to_csv('Trigrams-likelihood-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# pmi
bigramPMItable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.pmi)), columns=['bigram','PMI']).sort_values(by='PMI', ascending=False)
trigramPMItable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.pmi)), columns=['trigram','PMI']).sort_values(by='PMI', ascending=False)
bigramPMItable = bigramPMItable.head(20)
trigramPMItable = trigramPMItable.head(20) #вычленяем первые 20 лучших би- и триграммов
bigramPMItable.to_csv('Bigrams-PMI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramPMItable.to_csv('Trigrams-PMI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# %%
#RAKE

# %%
# !pip install pymorphy2

# %%
import pymorphy2 as pm
import codecs
import string

# %%
m = pm.MorphAnalyzer()

# %%
words = []
words2 = ""

# %%
with open('/content/art_m.txt', 'r', encoding='utf-8') as f:
    text = f.read()
    words = text.split()
    for i in range(len(words) - 1):
        if m.parse(words[i])[0].tag.POS == "ADVB" or m.parse(words[i])[0].tag.POS == "VERB" or m.parse(words[i][:-1])[0].tag.POS == "VERB" or m.parse(words[i])[0].tag.POS == "PRTS"or m.parse(words[i])[0].tag.POS == "INFN"or m.parse(words[i])[0].tag.POS == "COMP" or m.parse(words[i])[0].tag.POS == "ADJS" or m.parse(words[i])[0].tag.POS == "GRND"or m.parse(words[i])[0].tag.POS == "CONJ":
            words2 += " | " + words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i])[0].tag.case == ("gent" or "accs")):
            words2 += words[i] + " | "
        elif m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i + 1])[0].tag.POS == ("NOUN" or "ADJF") and m.parse(words[i])[0].tag.case != m.parse(words[i + 1])[0].tag.case and m.parse(words[i + 1])[0].tag.case != "gent":
            words2 += words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i])[0].tag.case != ("nomn" or "accs") and m.parse(words[i + 1])[0].tag.POS == "NOUN" and m.parse(words[i + 1])[0].tag.case == ("nomn" or "accs")):
            words2 += words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == None and m.parse(words[i][:-1])[0].tag.POS == None and m.parse(words[i][1:])[0].tag.POS == None):
            words2 += " | " + words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i - 1])[0].tag.POS == "ADJF" or m.parse(words[i - 1])[0].tag.POS == "PRTF") and m.parse(words[i])[0].tag.case == m.parse(words[i + 1])[0].tag.case:
            words2 += words[i] + " | "
        else:
            words2 += words[i] + " "

# %%
words2
# Out:
# '1.Введение Разработка новых подходов | к лингвистическому моделированию  | позволяет | исследователям  | по-новому |  | взглянуть | на важный класс задач | автоматической обработки | естественного языка,  | а | именно<—<на смысловую компрессию текста, производимую при автоматическом выделении ключевых слов |  | и | словосочетаний, классификации |  | и | кластеризации | лексики |  | и | документов | в корпусах текстов, выделении классов | слов | с близкими дистрибутивными свойствами, оценке семантической однородности/неоднородности | текстов |  | и | т. п.  | (ср. | наши эксперименты, описанные в статьях [Митрофанова, Мухин, Паничева,  | 2007; |  | Mitrofanova, |  | Mukhin, |  | Panicheva, |  | 2007; | Митрофанова,  | 2008; |  | Mitrofanova, |  | 2009; | Митрофанова, Грачкова, Шиморина,  | 2010]). | В данном ряду  | особняком |  | стоит | задача тематического моделирования | корпусов | текстов. В последние  | несколько | лет | арсенал методов | тематического моделирования |  | существенно |  | расширился, |  | а | также  | появились | доступные исследователям компьютерные инструменты автоматической обработки | текстов | (например,  | GATE, |  | LingPipe, |  | NLTK, |  | Stanford |  | Toolkit |  | и | т.  | д.), | создающие предпосылки к проведению экспериментов.  | Параллельно |  | расширяется | круг практических задач, которые  | решаются | данными средствами. Особое внимание исследователей |  | сейчас |  | обращено | к анализу социальных сетей |  | и | выявлению тематической структуры |  | сообществ | (например,  | [Bodrunova |  | et |  | al., |  | 2013; |  | Koltsova |  | et |  | al., |  | 2012]). | В  | связи | с этим  | представляется | важным  | оценить | особенности различных методов | тематического моделирования | и<их применимость к  | тем |  | или | иным экспериментальным данным. 2.Тематическое  | моделирование—что | это такое? Тематическое моделирование<—<способ  | построения |  | модели | текстовой коллекции, отражающий переход от совокупности документов, совокупности слов | в документах коллекции | к набору тем, характеризующих текстовую коллекцию. Тематические модели<  | — |  | модели | со скрытыми переменными  | (факторами), | задающими тематику текстов. Для выявления | этих скрытых переменных  | лучше | всего  | применять |  | нечеткую |  | кластеризацию<— |  | разбиение | текстов | на пересекающиеся классы. | В таком случае,  | тема<—<это | результат бикластеризации, т.  | е. | одновременной кластеризации | слов |  | и | документов | с точки | зрения | их семантической близости в пределах текстовой коллекции. При нечеткой кластеризации | любое слово  | или | документ с некоторой вероятностью  | относится | к нескольким темам. Можно сказать,  | что | в тематической  | модели | описанию слова |  | или | документа | в текстовой коллекции |  | ставится | в  | соответствие | семейство вероятностных  | распределений | на множестве тем. Выявление этих  | распределений |  | составляет | основу тематического моделирования. В тематических моделях  | используется | подход к обработке текстовых данных, называемый «мешок  | слов». | Это значит,  | что | способ упорядочения | слов | внутри документов | не  | имеет | значения: не  | учитывается | порядок слов | в предложении, взаимное  | расположение | слов | в тексте и<  | т.< | д. При тематическом моделировании | документ  | описывается |  | как | набор тем, порождаемых семейством распределений. В  | то | же  | время | любой документ в  | корпусе<—< | это случайная выборка слов, порожденная неким | множеством тем.  | Исходя | из этого, можно  | установить |  | распределение |  | тем | в корпусе  | и | выяснить, каким набором  | тем |  | порождается | конкретный документ. В лингвистическом смысле | тема  | есть | набор ключевых слов, характеризующий отдельный документ  | или | набор документов. Например, в тестовой коллекции |  | могут |  | присутствовать | темы |  | «Искусство», |  | «Дети», |  | «Образование», |  | «Жизнь», |  | «Ген», | «Мозг»  | и | т.  | д., | ассоциир ...

# %%
with open('/content/art_m.txt', 'w', encoding='utf-8') as f2:
    f2.write(words2)

# %%
from __future__ import division
import operator
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
punct = open('/content/punct.txt', 'r', encoding='utf-8').read()

# %%
punct_list = nltk.word_tokenize(punct)

# %%
stop = open("/content/stopwords.txt", 'r', encoding='utf-8').read()

# %%
pronouns = open("/content/pronouns.txt", 'r', encoding='utf-8').read()

# %%
preps = open("/content/preps.txt", 'r', encoding='utf-8').read()

# %%
preps
# Out:
# 'а-ля\nбез\nбезо\nблагодаря\nблиз\nв\nвблизи\nввиду\nвглубь\nвдогон\nвдоль\nвзамен\nвключая\nвкруг\nвместо\nвне\nвнизу\nвнутри\nвнутрь\nво\nво имя\nвовнутрь\nвозле\nвокруг\nвопреки\nвослед\nвпереди\nвразрез\nвроде\nвслед\nвследствие\nдля\nдля-ради\nдо\nза\nзаместо\nиз\nиз-за\nиз-под\nизнутри\nизо\nк\nкасательно\nко\nкроме\nкругом\nмеж\nмежду\nмимо\nна\nнаверху\nнавроде\nнавстречу\nнад\nнадо\nназад\nнакануне\nнаперекор\nнаперерез\nнаподобие\nнапротив\nнасупротив\nнасчёт\nниже\nо\nоб\nобо\nобок\nоколо\nокрест\nокромя\nокруг\nопосля\nот\nотносительно\nото\nперед\nпередо\nпо\nпо-за\nпо-над\nпо-под\nповерх\nпод\nподле\nподо\nподобно\nпозади\nпозднее\nпомимо\nпоперёд\nпоперёк\nпорядка\nпосередине\nпосередь\nпосле\nпосреди\nпосредине\nпосредством\nпред\nпредо\nпрежде\nпри\nпро\nпротив\nпутём\nради\nс\nсверх\nсверху\nсвыше\nсзади\nсквозь\nскрозь\nснизу\nсо\nсогласно\nспустя\nсреди\nсредь\nсродни\nсупротив\nчерез\nчрез\n'

# %%
mystop = open("/content/stopwords.txt", 'r', encoding='utf-8').read()

# %%
#nltk.word_tokenize(preps.decode("utf8")) + nltk.word_tokenize(mystop.decode("utf8"))
nltk.word_tokenize(preps) + nltk.word_tokenize(mystop)
# Out:
# ['а-ля',
#  'без',
#  'безо',
#  'благодаря',
#  'близ',
#  'в',
#  'вблизи',
#  'ввиду',
#  'вглубь',
#  'вдогон',
#  'вдоль',
#  'взамен',
#  'включая',
#  'вкруг',
#  'вместо',
#  'вне',
#  'внизу',
#  'внутри',
#  'внутрь',
#  'во',
#  'во',
#  'имя',
#  'вовнутрь',
#  'возле',
#  'вокруг',
#  'вопреки',
#  'вослед',
#  'впереди',
#  'вразрез',
#  'вроде',
#  'вслед',
#  'вследствие',
#  'для',
#  'для-ради',
#  'до',
#  'за',
#  'заместо',
#  'из',
#  'из-за',
#  'из-под',
#  'изнутри',
#  'изо',
#  'к',
#  'касательно',
#  'ко',
#  'кроме',
#  'кругом',
#  'меж',
#  'между',
#  'мимо',
#  'на',
#  'наверху',
#  'навроде',
#  'навстречу',
#  'над',
#  'надо',
#  'назад',
#  'накануне',
#  'наперекор',
#  'наперерез',
#  'наподобие',
#  'напротив',
#  'насупротив',
#  'насчёт',
#  'ниже',
#  'о',
#  'об',
#  'обо',
#  'обок',
#  'около',
#  'окрест',
#  'окромя',
#  'округ',
#  'опосля',
#  'от',
#  'относительно',
#  'ото',
#  'перед',
#  'передо',
#  'по',
#  'по-за',
#  'по-над',
#  'по-под',
#  'поверх',
#  'под',
#  'подле',
#  'подо',
#  'подобно',
#  'позади',
#  'позднее',
#  'помимо',
#  'поперёд',
#  'поперёк',
#  'порядка',
#  'посередине',
#  'посередь',
#  'после',
#  'посреди',
#  'посредине',
#  'посредством',
#  'пред',
#  'предо',
#  'прежде',
#  'при',
#  'про',
#  'против',
#  'путём',
#  'ради',
#  'с',
#  'сверх',
#  'сверху',
#  'свыше',
#  'сзади',
#  'сквозь',
#  'скрозь',
#  'снизу',
#  'со',
#  'согласно',
#  'спустя',
#  'среди',
#  'средь',
#  'сродни',
#  'супротив',
#  'через',
#  'чрез',
#  '\ufeffбыть',
#  'мочь',
#  'еще',
#  'а',
#  'а.',
#  'л.',
#  'а.л',
#  '.',
#  'а/о',
#  'аа',
#  'а-а',
#  'ааа',
#  'а-а-а',
#  'а-а-а-а',
#  'абы',
#  'авось',
#  'авт',
#  '.',
#  'л.',
#  'авт.л',
#  '.',
#  'ага',
#  'адм.-терр',
#  '.',
#  'аж',
#  'аз',
#  'ай',
#  'ай-ай-ай',
#  'айда',
#  'ай-яй-яй',
#  'акад',
#  '.',
#  'аки',
#  'але',
#  'али',
#  'алле',
#  'алло',
#  'аль',
#  'а-ля',
#  'аминь',
#  'ан',
#  'апчхи',
#  'атас',
#  'ау',
#  'аф',
#  'ах',
#  'ахти',
#  'аще',
#  'б',
#  'б',
#  'ба',
#  'бабах',
#  'ба-бах',
#  'баста',
#  'бах',
#  'бац',
#  'без',
#  'безо',
#  'бен',
#  'бис',
#  'бишь',
#  'б-ка',
#  'благо',
#  'благодаря',
#  'близ',
#  'бо',
#  'более',
#  'больше',
#  'бом',
#  'браво',
#  'брр',
#  'бррр',
#  'брысь',
#  'бу-бу-бу',
#  'буде',
#  'будто',
#  'буль-буль',
#  'бум',
#  'бы',
#  'было',
#  'в',
#  'в.',
#  'в/о',
#  'вай',
#  'ван',
#  'вау',
#  'ваш',
#  'вблизи',
#  'вв',
#  '.',
#  'ввиду',
#  'вглубь',
#  'вдоль',
#  'вдруг',
#  'ведь',
#  'везде',
#  'весь',
#  'весьма',
#  'взамен',
#  'виват',
#  'вишь',
#  'вкз',
#  '.',
#  'включая',
#  'вкруг',
#  'вместе',
#  'вместо',
#  'вне',
#  'внизу',
#  'внутри',
#  'внутрь',
#  'во',
#  'во-во',
#  'возле',
#  'возможно',
#  'вокруг',
#  'вон',
#  'вона',
#  'вообще',
#  'вообще-то',
#  'во-он',
#  'во-от',
#  'вопреки',
#  'вослед',
#  'вост.-европ',
#  '.',
#  'вот',
#  'вперед',
#  'впереди',
#  'вполне',
#  'впрочем',
#  'впрямь',
#  'вроде',
#  'все',
#  'всегда',
#  'всего',
#  'все-таки',
#  'вслед',
#  'вследствие',
#  'всюду',
#  'всякий',
#  'всяко',
#  'всякое',
#  'вы',
#  'выше',
#  'г',
#  'г.',
#  'гг',
#  '.',
#  'гг',
#  '.',
#  'г-да',
#  'где',
#  'где-либо',
#  'где-нибудь',
#  'где-то',
#  'геть',
#  'г-жа',
#  'глядь',
#  'гм',
#  'г-н',
#  'гоп',
#  'гор',
#  '.',
#  'гос',
#  '.',
#  'гос-во',
#  'господи',
#  'гр',
#  '.',
#  'гр-ка',
#  'гр-не',
#  'гы',
#  'д.',
#  'о.',
#  'д.о',
#  '.',
#  'д/о',
#  'да',
#  'да',
#  'да-а',
#  'да-а-а',
#  'дабы',
#  'давай',
#  'давайте',
#  'давно',
#  'да-да',
#  'да-да-да',
#  'даже',
#  'дай',
#  'дайте',
#  'дак',
#  'далее',
#  'данный',
#  'д-да',
#  'де',
#  'действительно',
#  'дель',
#  'ден',
#  'деп',
#  '.',
#  'дер',
#  'дер',
#  '.',
#  'ди',
#  'дисс',
#  '.',
#  'для',
#  'до',
#  'добро',
#  'довольно',
#  'доколе',
#  'дол',
#  '.',
#  'долл',
#  '.',
#  'дон',
#  'доселе',
#  'дотоле',
#  'другие',
#  'другое',
#  'другой',
#  'дудки',
#  'ды',
#  'дык',
#  'его',
#  'едва',
#  'ее',
#  'ежедн',
#  '.',
#  'ежели',
#  'ежли',
#  'ей-богу',
#  'ей-ей',
#  'ейный',
#  'елки-палки',
#  'е-мое',
#  'если',
#  'ет',
#  'ето',
#  'етот',
#  'еще',
#  'ж',
#  'ж.',
#  'ж.',
#  'д.',
#  'ж.д',
#  '.',
#  'ж.-д',
#  '.',
#  'ж/д',
#  'же',
#  'жен',
#  '.',
#  'з.',
#  'з.',
#  'к.',
#  'з.к',
#  '.',
#  'з/к',
#  'з/о',
#  'за',
#  'заместо',
#  'зап',
#  '.',
#  'зап.-европ',
#  '.',
#  'заруб',
#  '.',
#  'затем',
#  'зато',
#  'зачем',
#  'зачем-то',
#  'здесь',
#  'здеся',
#  'здорово',
#  'здравствуй',
#  'здравствуйте',
#  'здрасте',
#  'значит',
#  'зы',
#  'и',
#  'и',
#  'т.',
#  'д.',
#  'и',
#  'т.',
#  'д.',
#  'и',
#  'т.',
#  'п.',
#  'и',
#  'т.',
#  'п.',
#  'и',
#  'т.д',
#  '.',
#  'и',
#  'т.д',
#  '.',
#  'и',
#  'т.п',
#  '.',
#  'и',
#  'т.п',
#  '.',
#  'и.',
#  'о.',
#  'и.о',
#  '.',
#  'ибн',
#  'ибо',
#  'иже',
#  'из',
#  'изд-во',
#  'из-за',
#  'изнутри',
#  'изо',
#  'из-под',
#  'и-и',
#  'или',
#  'иль',
#  'именно',
#  'имхо',
#  'ин',
#  'ин',
#  '.',
#  'иначе',
#  'иной',
#  'иностр',
#  '.',
#  'инст',
#  '.',
#  'ин-т',
#  'исключая',
#  'исключительно',
#  'итак',
#  'ить',
#  'их',
#  'ихний',
#  'ишь',
#  'к',
#  'к.',
#  'ка',
#  'ка-ак',
#  'кабы',
#  'каждый',
#  'кажный',
#  'как',
#  'как-либо',
#  'как-нибудь',
#  'как-никак',
#  'како',
#  'каков',
#  'каково',
#  'каковой',
#  'какой',
#  'какой-либо',
#  'какой-нибудь',
#  'какой-никакой',
#  'какой-то',
#  'как-то',
#  'канд',
#  '.',
#  'караул',
#  'касательно',
#  'кв',
#  '.',
#  'кг',
#  'кг',
#  '.',
#  'кис-кис',
#  'ко',
#  'когда',
#  'когда-либо',
#  'когда-нибудь',
#  'когда-то',
#  'кое',
#  'кое-где',
#  'кое-как',
#  'кое-какой',
#  'кое-кто',
#  'кое-что',
#  'кой',
#  'кой-какой',
#  'кой-кто',
#  'кой-то',
#  'кой-что',
#  'коли',
#  'коль',
#  'конечно',
#  'конечно',
#  'корп',
#  '.',
#  'который',
#  'кроме',
#  'кругом',
#  'кстати',
#  'кто',
#  'кто-кто',
#  'кто-либо',
#  'кто-нибудь',
#  'кто-то',
#  'ку',
#  'куда',
#  'куда-либо',
#  'куда-нибудь',
#  'куда-то',
#  'куды',
#  'ку-ку',
#  'кыш',
#  'ла',
#  'ладно',
#  'ле',
#  'ли',
#  'либо',
#  'лишь',
#  'лучше',
#  'ль',
#  'любой',
#  'м',
#  'м',
#  'м.',
#  'марш',
#  'мб',
#  'мбайт',
#  'мда',
#  'м-да',
#  'мдя',
#  'меж',
#  'между',
#  'менее',
#  'мерси',
#  'мимо',
#  'мин',
#  '.',
#  'мин',
#  '.',
#  'мин-во',
#  'миним',
#  '.',
#  'минус',
#  'млн',
#  'мля',
#  'мм',
#  'мм',
#  'м-м',
#  'ммм',
#  'м-м-м',
#  'многие',
#  'многий',
#  'много',
#  'многое',
#  'может',
#  'можно',
#  'мой',
#  'мол',
#  'моск',
#  '.',
#  'муж',
#  '.',
#  'мы',
#  'мяу',
#  'на',
#  'наверное',
#  'навроде',
#  'навсегда',
#  'над',
#  'надо',
#  'надо',
#  'назад',
#  'наиболее',
#  'на-ка',
#  'накануне',
#  'наконец',
#  'наперекор',
#  'наподобие',
#  'например',
#  'напротив',
#  'насчет',
#  'нате',
#  'наш',
#  'н-да',
#  'не',
#  'неа',
#  'не-а',
#  'небось',
#  'невесть',
#  'нед',
#  '.',
#  'не-е',
#  'не-е-ет',
#  'не-ет',
#  'нежели',
#  'неизвестно',
#  'некий',
#  'некогда',
#  'некого',
#  'некоторые',
#  'некоторый',
#  'некто',
#  'нельзя',
#  'немногие',
#  'немногий',
#  'немногое',
#  'нет',
#  'нет',
#  'нет-нет',
#  'нет-нет-нет',
#  'неужели',
#  'неужто',
#  'нехай',
#  'нечего',
#  'нечто',
#  'нешто',
#  'ни',
#  'нибудь',
#  'нигде',
#  'ниже',
#  'никак',
#  'никакой',
#  'никогда',
#  'никой',
#  'никто',
#  'никуда',
#  'ниоткуда',
#  'нипочем',
#  'нисколечко',
#  'нисколько',
#  'ниче',
#  'ничего',
#  'ничей',
#  'ничо',
#  'ничто',
#  'ничуть',
#  'ништяк',
#  'н-не',
#  'н-нет',
#  'н-ну',
#  'но',
#  'но-но',
#  'ну',
#  'нужно',
#  'ну-ка',
#  'ну-ко',
#  'ну-ну',
#  'ну-с',
#  'ну-у',
#  'ну-у',
#  'нэ',
#  'о',
#  'о.',
#  'об',
#  'обо',
#  'оглы',
#  'ого',
#  'ого-го',
#  'о-го-го',
#  'один',
#  'однажды',
#  'однако',
#  'одно',
#  'ой',
#  'ой-ой-ой',
#  'ок',
#  "о'кей",
#  'около',
#  'окрест',
#  'окромя',
#  "о'кэй",
#  'он',
#  'она',
#  'они',
#  'оно',
#  'оный',
#  'о-о',
#  'о-о-о',
#  'оп',
#  'опять',
#  'особенно',
#  'остальное',
#  'остальной',
#  'остальные',
#  'от',
#  'откуда',
#  'откуда-нибудь',
#  'откуда-то',
#  'относительно',
#  'ото',
#  'отовсюду',
#  'отсюда',
#  'отсюдова',
#  'оттого',
#  'оттого-то',
#  'оттуда',
#  'оттудова',
#  'отчего',
#  'отчего-то',
#  'офф',
#  'ох',
#  'ох-хо-хо',
#  'очень',
#  'п.',
#  'п/я',
#  'пам',
#  'пардон',
#  'пер',
#  '.',
#  'перед',
#  'передо',
#  'пи',
#  'пиф-паф',
#  'пли',
#  'плюс',
#  'по',
#  'по-вашему',
#  'поверх',
#  'повсюду',
#  'по-всякому',
#  'под',
#  'поди',
#  'подле',
#  'подо',
#  'подобно',
#  'по-другому',
#  'поелику',
#  'пожалуйста',
#  'по-за',
#  'позади',
#  'по-иному',
#  'пока',
#  'покамест',
#  'покуда',
#  'полноте',
#  'полундра',
#  'помимо',
#  'по-моему',
#  'по-над',
#  'по-нашему',
#  'понеже',
#  'поперек',
#  'пос',
#  '.',
#  'по-своему',
#  'посему',
#  'посередине',
#  'посередь',
#  'поскольку',
#  'после',
#  'посреди',
#  'посредине',
#  'посредством',
#  'постольку',
#  'по-твоему',
#  'потом',
#  'потому',
#  'потому-то',
#  'почем',
#  'почему',
#  'почему-либо',
#  'почему-то',
#  'почти',
#  'почто',
#  'пошто',
#  'поэтому',
#  'поэтому-то',
#  'пп',
#  '.',
#  'пр',
#  '.',
#  'правда',
#  'превыше',
#  'пред',
#  'предо',
#  'прежде',
#  'при',
#  'притом',
#  'причем',
#  'про',
#  'промеж',
#  'просп',
#  '.',
#  'просто',
#  'против',
#  'противу',
#  'прочая',
#  'прочее',
#  'прочий',
#  'пр-т',
#  'прям',
#  'прямо',
#  'пу',
#  'пускай',
#  'пусть',
#  'путем',
#  'пущай',
#  'пшел',
#  'р.',
#  'равно',
#  'равняйсь',
#  'ради',
#  'раз',
#  'разве',
#  'р-н',
#  'ровно',
#  'р-раз',
#  'руб',
#  '.',
#  'рядом',
#  'с',
#  'с.',
#  'сам',
#  'самый',
#  'самый-самый',
#  'сверх',
#  'свое',
#  'свой',
#  'свыше',
#  'се',
#  'себе',
#  'себя',
#  'сей',
#  'сейчас',
#  'сек',
#  '.',
#  'сем',
#  'середь',
#  'сзади',
#  'сие',
#  'сиречь',
#  'сичас',
#  'сквозь',
#  'сколь',
#  'сколько',
#  'сколько-нибудь',
#  'сколько-то',
#  'сколь-нибудь',
#  'слишком',
#  'словно',
#  'см',
#  'см',
#  '.',
#  'сначала',
#  'снова',
#  'со',
#  'собственно',
#  'совершенно',
#  'совсем',
#  'согласно',
#  'сообразно',
#  'соответственно',
#  'сорри',
#  'спасибо',
#  'спасибочки',
#  'СПб',
#  'СПб',
#  '.',
#  'спустя',
#  'сразу',
#  'среди',
#  'средь',
#  'сродни',
#  'столь',
#  'столько',
#  'столько-то',
#  'стоп',
#  'стр',
#  '.',
#  'стук',
#  'супер',
#  'супротив',
#  'сю',
#  'сюда',
#  'сюды',
#  'сяк',
#  'сякой',
#  'сям',
#  'т.',
#  'т/к',
#  'та',
#  'та-ак',
#  'так',
#  'также',
#  'таки',
#  'тако',
#  'таков',
#  'таковой',
#  'таковский',
#  'такой',
#  'такой-сякой',
#  'такой-то',
#  'так-так',
#  'так-таки',
#  'так-так-так',
#  'так-то',
#  'там',
#  'тама',
#  'там-то',
#  'та-та',
#  'та-та-та',
#  'твой',
#  'те',
#  'тел',
#  '.',
#  'тем',
#  'теперь',
#  'тик-так',
#  'типа',
#  'то',
#  'тов',
#  '.',
#  'тогда',
#  'тогда-то',
#  'тож',
#  'тоже',
#  'той',
#  'тока',
#  'токмо',
#  'токо',
#  'только',
#  'только-то',
#  'топ',
#  'то-се',
#  'тот',
#  'то-то',
#  'тот-то',
#  'точно',
#  'тра-та-та',
#  'трах',
#  'трис',
#  'тсс',
#  'тс-с',
#  'тт',
#  '.',
#  'ттт',
#  'туда',
#  'туда-сюда',
#  'туда-то',
#  'туды',
#  'тук',
#  'тук-тук',
#  'тук-тук-тук',
#  'тут',
#  'тута',
#  'тут-то',
#  'ту-ту',
#  'ты',
#  'тыс',
#  '.',
#  'тьфу',
#  'тьфу-тьфу',
#  'тьфу-тьфу-тьфу',
#  'тю',
#  'у',
#  'уа',
#  'увы',
#  'угодно',
#  'угу',
#  'уж',
#  'уже',
#  'ужели',
#  'ужель',
#  'уй',
#  'ул',
#  '.',
#  'ура',
#  'усе',
#  'у-у',
#  'ууу',
#  'у-у-у',
#  'уф',
#  'ух',
#  'ф.и.о',
#  '.',
#  'фи',
#  ...]

# %%
stop_list = nltk.word_tokenize(stop) + nltk.word_tokenize(pronouns) + nltk.word_tokenize(preps) + nltk.word_tokenize(mystop)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def isPunct(word):
  return len(word) == 1 and (word in string.punctuation or word in punct_list)

# %%
def isNumeric(word):
  try:
    float(word) if '.' in word else int(word)
    return True
  except ValueError:
    return False

# %%
def isInitial(word):
  return len(word) == 2 and word[1] == "."

# %%
class RakeKeywordExtractor:

  def __init__(self):
    self.stopwords = set(nltk.corpus.stopwords.words())
    self.top_fraction = 1 # consider top third candidate keywords by score

  def _generate_candidate_keywords(self, sentences):
    phrase_list = []
    for sentence in sentences:
      words = map(lambda x: "|" if x in self.stopwords or x in stop_list or isNumeric(x) or isInitial(x) else x,
        nltk.word_tokenize(sentence.lower()))
      phrase = []
      for word in words:
        if word == "|" or isPunct(word):
          if len(phrase) > 0:
            phrase_list.append(phrase)
            phrase = []
        else:
          phrase.append(word)
    return phrase_list
## СТОП!!
  def _calculate_word_scores(self, phrase_list):
    word_freq = nltk.FreqDist()
    word_degree = nltk.FreqDist()
    for phrase in phrase_list:
      #degree = len(filter(lambda x: not isNumeric(x), phrase)) - 1
      degree = len(list(filter(lambda x: not isNumeric(x), phrase))) - 1
      for word in phrase:
        word_freq[word] += 1 ## word_fd.inc(word.lower()) with word_fd[word.lower()] += 1
        word_degree[word] += degree # other words
    for word in word_freq.keys():
      word_degree[word] = word_degree[word] + word_freq[word] # itself
    # word score = deg(w) / freq(w)
    word_scores = {}
    for word in word_freq.keys():
      word_scores[word] = word_degree[word] / word_freq[word]
    return word_scores

  def _calculate_phrase_scores(self, phrase_list, word_scores):
    phrase_scores = {}
    for phrase in phrase_list:
      phrase_score = 0
      for word in phrase:
        phrase_score += word_scores[word]
      phrase_scores[" ".join(phrase)] = phrase_score
    return phrase_scores
    
  def extract(self, text, incl_scores=False):
    sentences = nltk.sent_tokenize(text)
    phrase_list = self._generate_candidate_keywords(sentences)
    word_scores = self._calculate_word_scores(phrase_list)
    phrase_scores = self._calculate_phrase_scores(
      phrase_list, word_scores)
    #sorted_phrase_scores = sorted(phrase_scores.iteritems(),
    sorted_phrase_scores = sorted(phrase_scores.items(),
      key=operator.itemgetter(1), reverse=True)
    n_phrases = len(sorted_phrase_scores)
    if incl_scores:
      return sorted_phrase_scores[0:int(n_phrases/self.top_fraction)]
    else:
      return map(lambda x: x[0],
        sorted_phrase_scores[0:int(n_phrases/self.top_fraction)])

# %%
rake = RakeKeywordExtractor()

# %%
with open('/content/art_m.txt', 'r', encoding='utf-8') as f:
    txt = f.read()

# %%
keywords = rake.extract(txt, incl_scores=True)

# %%
for eachkwrd in keywords:
    print(eachkwrd[0], eachkwrd[1])
# Out:
# доступные исследователям компьютерные инструменты автоматической обработки 25.107142857142858
# ранними результатами автоматического выделения 16.0
# 1.введение разработка новых подходов 15.0
# практических разработках последних лет 14.0
# разных значениях многозначные слова 12.714285714285714
# тематическое моделирование научных текстов 11.736842105263158
# автоматическом выделении ключевых слов 11.664285714285715
# круг практических задач 9.5
# важный класс задач 9.0
# близкими дистрибутивными свойствами 9.0
# анализу социальных сетей 9.0
# иным экспериментальным данным 9.0
# больших текстовых коллекций 9.0
# использование многоуровневой разметки 9.0
# ограничение контекстного окна 9.0
# качестве текстовых коллекций 9.0
# стандартной векторной моделью 9.0
# качественного семантического сжатия 9.0
# сопоставительным анализом набора 9.0
# открытом доступе инструментов 9.0
# уровне лингвистической обработки 8.857142857142858
# этих скрытых переменных 8.75
# адаптацией этих инструментов 8.75
# решение этих задач 8.75
# результаты автоматической обработки 8.607142857142858
# оценке семантической однородности/неоднородности 8.5
# особенности различных методов 8.5
# обработке текстовых данных 8.5
# скрытая тематическая марковская 8.5
# традиционных лингвистических методов 8.5
# свертка признакового пространства 8.166666666666666
# особое внимание исследователей 8.0
# вероятностный латентно-семантический анализ 8.0
# какое-либо ключевое слово 8.0
# моделях семантического пространства 8.0
# случайная выборка слов 7.95
# 3.типы тематических моделей 7.916666666666666
# спецификация тематических моделей 7.916666666666666
# смысловую компрессию текста 7.833333333333333
# обработке больших текстов 7.7368421052631575
# автоматическую обработку текстов 7.7368421052631575
# наборах ключевых слов 7.664285714285715
# пределах текстовой коллекции 7.647727272727273
# средней текстовой коллекции 7.647727272727273
# данной текстовой коллекции 7.647727272727273
# задача тематического моделирования 7.6
# основу тематического моделирования 7.6
# характеризующий отдельный документ 7.6
# средству тематического моделирования 7.6
# матрицей совместной встречаемости 7.583333333333334
# выявлению тематической структуры 7.5
# текстами больших объемов 7.5
# автоматическому моделированию тематики 7.5
# характеризующих указанные тексты 7.458333333333334
# характеризующих текстовую коллекцию 7.333333333333334
# задающими тематику текстов 7.2368421052631575
# лекарственных свойствах растений 7.166666666666667
# общий объем текстов 7.0701754385964914
# темах второго текста 6.833333333333333
# набор ключевых слов 6.664285714285715
# перечень ключевых слов 6.664285714285715
# порождаемых семейством распределений 6.5
# автоматической обработки 6.107142857142858
# тематическое моделирование 6.0
# результаты обработки 5.357142857142858
# признакового пространства 5.166666666666666
# выделении классов 5.0
# тематических моделях 5.0
# латентно-семантический анализ 5.0
# текстовую коллекцию 5.0
# разных частей 5.0
# параметры обработки 4.857142857142858
# выявление этих 4.75
# ключевых слов 4.664285714285715
# текстовой коллекции 4.647727272727273
# тематического моделирования 4.6
# совместной встречаемости 4.583333333333334
# лингвистическому моделированию 4.5
# арсенал методов 4.5
# семантической близости 4.5
# ряд методов 4.5
# новых документов 4.5
# корреляционная тематическая 4.5
# тематической структуры 4.5
# умеренных объемов 4.5
# пересекающуюся тематику 4.5
# лекарственных средств 4.5
# база данных 4.5
# ключевых слова 4.428571428571429
# предыдущих моделях 4.333333333333334
# объем списков 4.333333333333334
# объем каждого 4.333333333333334
# тестовой коллекции 4.272727272727273
# тематике коллекции 4.272727272727273
# частоту встречаемости 4.25
# алгебраических моделей 4.25
# публицистические тексты 4.125
# научные тексты 4.125
# научно-популярные тексты 4.125
# художественные тексты 4.125
# деловые тексты 4.125
# рассматриваемые тексты 4.125
# естественного языка 4.0
# данном ряду 4.0
# создающие предпосылки 4.0
# проведению экспериментов 4.0
# данными средствами 4.0
# отражающий переход 4.0
# скрытыми переменными 4.0
# пересекающиеся классы 4.0
# таком случае 4.0
# результат бикластеризации 4.0
# любое слово 4.0
# некоторой вероятностью 4.0
# нескольким темам 4.0
# тематическом моделировании 4.0
# порожденная неким 4.0
# каким набором 4.0
# лингвистическом смысле 4.0
# имеющих определенную 4.0
# вероятность появления 4.0
# стандартная векторная 4.0
# краткую характеристику 4.0
# подробные обзоры 4.0
# n-мерном пространстве 4.0
# неудобством использования 4.0
# синонимические отношения 4.0
# основные характеристики 4.0
# методом байеса 4.0
# риском переобучения 4.0
# сложностью добавления 4.0
# вероятностным распределением 4.0
# большого объема 4.0
# одну тему 4.0
# мере связанные 4.0
# совместная вероятностная 4.0
# привлечением аппарата 4.0
# дистрибутивной семантики 4.0
# языковых ресурсов 4.0
# случае доступности 4.0
# учет границ 4.0
# синтаксических групп 4.0
# назначение весов 4.0
# контекстных элементов 4.0
# нормализация значений 4.0
# повышению качества 4.0
# выборе инструмента 4.0
# программные пакеты 4.0
# программные реализации 4.0
# удобный интерфейс 4.0
# выдача результатов 4.0
# английском языке 4.0
# мировой политике 4.0
# нашем случае 4.0
# нескольких десятков 4.0
# нескольких сотен 4.0
# отдельные иллюстрации 4.0
# дающие представление 4.0
# результатах экспериментов 4.0
# компьютерной лингвистике 4.0
# подробная информация 4.0
# описание основных 4.0
# компьютерной лингвистики 4.0
# редким исключением 4.0
# низкой долей 4.0
# имена собственные 4.0
# некоторых других 4.0
# трех источниках 4.0
# авторитетным справочником 4.0
# предсказуемым образом 4.0
# лекарственными средствами 4.0
# ботанического характера 4.0
# внешнем виде 4.0
# условиях произрастания 4.0
# особенностях сбора 4.0
# меньшей степени 4.0
# заключение наблюдения 4.0
# сделанные нами 4.0
# ходе экспериментов 4.0
# перспективы исследования 4.0
# русскоязычными текстами 4.0
# совокупности слов 3.95
# порядок слов 3.95
# наборами слов 3.95
# значимых слов 3.95
# первого текста 3.833333333333333
# документах коллекции 3.772727272727273
# корпусах текстов 3.736842105263158
# входных текстов 3.736842105263158
# двух текстов 3.736842105263158
# описанию слова 3.7142857142857144
# одновременной кластеризации 3.666666666666667
# нечеткой кластеризации 3.666666666666667
# второй источник 3.666666666666667
# третий источник 3.666666666666667
# конкретный документ 3.6
# исследователям 3.5
# совокупности документов 3.5
# семейство вероятностных 3.5
# способ упорядочения 3.5
# набор документов 3.5
# соответствующих теме 3.5
# ожидаемое число 3.5
# большинство разработчиков 3.5
# устойчивостью работы 3.5
# доступные 3.5
# число итераций 3.5
# материалы конференции 3.5
# полученные данные 3.5
# следующее наполнение 3.5
# темой напрямую 3.5
# многозначность слов 3.45
# множестве слов 3.45
# порождение документа 3.333333333333333
# текст конвенции 3.333333333333333
# метку темы 3.2857142857142856
# полученные темы 3.2857142857142856
# наши эксперименты 3.25
# конце статьи 3.25
# тематические модели 3.2222222222222223
# каждая тема 3.2
# возможность заметить 3.0
# лет 2.5
# характеризующих 2.3333333333333335
# моделей 2.25
# тематической 2.0
# набор 2.0
# слово 2.0
# семейством 2.0
# исследователей 2.0
# темах 2.0
# текстами 2.0
# тематики 2.0
# перечень 2.0
# слов 1.95
# текста 1.8333333333333333
# текстов 1.736842105263158
# слова 1.7142857142857142
# кластеризации 1.6666666666666667
# растений 1.6666666666666667
# источник 1.6666666666666667
# документ 1.6
# документов 1.5
# способ 1.5
# распределений 1.5
# множестве 1.5
# документах 1.5
# вероятностных 1.5
# многозначность 1.5
# теме 1.5
# число 1.5
# работы 1.5
# конференции 1.5
# разработчиков 1.5
# заметить 1.5
# наполнение 1.5
# возможность 1.5
# данные 1.5
# темой 1.5
# документа 1.3333333333333333
# текст 1.3333333333333333
# темы 1.2857142857142858
# эксперименты 1.25
# статьи 1.25
# модели 1.2222222222222223
# тема 1.2
# позволяет 1.0
# по-новому 1.0
# взглянуть 1.0
# производимую 1.0
# словосочетаний 1.0
# классификации 1.0
# лексики 1.0
# п 1.0
# ср 1.0
# описанные 1.0
# статьях 1.0
# митрофанова 1.0
# мухин 1.0
# паничева 1.0
# mitrofanova 1.0
# mukhin 1.0
# panicheva 1.0
# грачкова 1.0
# шиморина 1.0
# особняком 1.0
# стоит 1.0
# корпусов 1.0
# последние 1.0
# несколько 1.0
# существенно 1.0
# расширился 1.0
# появились 1.0
# gate 1.0
# lingpipe 1.0
# nltk 1.0
# stanford 1.0
# toolkit 1.0
# т 1.0
# д 1.0
# параллельно 1.0
# расширяется 1.0
# которые 1.0
# решаются 1.0
# обращено 1.0
# сообществ 1.0
# bodrunova 1.0
# al. 1.0
# koltsova 1.0
# связи 1.0
# этим 1.0
# представляется 1.0
# важным 1.0
# оценить 1.0
# применимость 1.0
# 2.тематическое 1.0
# моделирование—что 1.0
# такое 1.0
# построения 1.0
# набору 1.0
# факторами 1.0
# выявления 1.0
# применять 1.0
# нечеткую 1.0
# кластеризацию 1.0
# разбиение 1.0
# точки 1.0
# зрения 1.0
# относится 1.0
# сказать 1.0
# ставится 1.0
# соответствие 1.0
# составляет 1.0
# используется 1.0
# подход 1.0
# называемый 1.0
# мешок 1.0
# имеет 1.0
# значения 1.0
# учитывается 1.0
# предложении 1.0
# взаимное 1.0
# расположение 1.0
# тексте 1.0
# описывается 1.0
# время 1.0
# корпусе 1.0
# множеством 1.0
# исходя 1.0
# установить 1.0
# распределение 1.0
# выяснить 1.0
# порождается 1.0
# могут 1.0
# присутствовать 1.0
# искусство 1.0
# дети 1.0
# образование 1.0
# жизнь 1.0
# ген 1.0
# мозг 1.0
# ассоциируемые 1.0
# рис. 1.0
# ng 1.0
# jordan 1.0
# lafferty 1.0
# широко 1.0
# опираются 1.0
# процедуры 1.0
# распространены 1.0
# модель 1.0
# vsm 1.0
# vector 1.0
# space 1.0
# model 1.0
# lsa 1.0
# latent 1.0
# semantic 1.0
# analysis 1.0
# генеративных 1.0
# применяются 1.0
# plsa 1.0
# probalilistic 1.0
# латентное 1.0
# размещение 1.0
# дирихле 1.0
# lda 1.0
# dirichlet 1.0
# allocation 1.0
# дадим 1.0
# anaya 1.0
# lee 1.0
# song 1.0
# topic 1.0
# modelling 1.0
# bibliography 1.0
# термы-термы 1.0
# термы-документы 1.0
# словам 1.0
# текстам 1.0
# ставятся 1.0
# вектора 1.0
# сравнение 1.0
# векторов 1.0
# правило 1.0
# определение 1.0
# косинуса 1.0
# угла 1.0
# векторами 1.0
# насколько 1.0
# характерно 1.0
# связаны 1.0
# собой 1.0
# документе 1.0
# близки 1.0
# документы 1.0
# недостатки 1.0
# работе 1.0
# невозможностью 1.0
# учесть 1.0
# словами 1.0
# наследует 1.0
# сокращения 1.0
# размерности 1.0
# текстах 1.0
# сингулярное 1.0
# разложение 1.0
# матрицы 1.0
# singular 1.0
# value 1.0
# decomposition 1.0
# svd 1.0
# отличие 1.0
# пригодна 1.0
# описания 1.0
# частично 1.0
# контекстную 1.0
# синонимию 1.0
# справляется 1.0
# многозначностью 1.0
# сложно 1.0
# заранее 1.0
# задать 1.0
# приписать 1.0
# используя 1.0
# являет 1.0
# вероятностную 1.0
# модификацию 1.0
# производится 1.0
# соответствии 1.0
# отчасти 1.0
# учитывает 1.0
# представлять 1.0
# разные 1.0
# основ 1.0
# ные 1.0
# сглаживает 1.0
# шероховатости 1.0
# имеющиеся 1.0
# опирающейся 1.0
# характеризуется 1.0
# описываются 1.0
# описывать 1.0
# корпуса 1.0
# попадать 1.0
# речи 1.0
# данная 1.0
# предусматривает 1.0
# установление 1.0
# связей 1.0
# темами 1.0
# известны 1.0
# упомянутыми 1.0
# частности 1.0
# jpm 1.0
# joint 1.0
# probabilistic 1.0
# ahmm 1.0
# aspect 1.0
# hidden 1.0
# markov 1.0
# автортематическая 1.0
# atm 1.0
# author-topic 1.0
# автор-получатель 1.0
# artm 1.0
# author-recipient 1.0
# ctm 1.0
# correlated 1.0
# связана 1.0
# различиями 1.0
# baroni 1.0
# bernardi 1.0
# zamparelli 1.0
# mitchell 1.0
# lapata 1.0
# склоняются 1.0
# необходимости 1.0
# интеграции 1.0
# статистических 1.0
# анализа 1.0
# реализовано 1.0
# wsm 1.0
# word 1.0
# hyperspace 1.0
# analogue 1.0
# language 1.0
# coals 1.0
# occurrence 1.0
# lexical 1.0
# semantics 1.0
# rohde 1.0
# gonnerman 1.0
# plaut 1.0
# sahlgren 1.0
# лемматизация 1.0
# морфосинтаксическая 1.0
# семантическая 1.0
# аннотация 1.0
# существующих 1.0
# коэффициентов 1.0
# методы 1.0
# способствуют 1.0
# 4.наши 1.0
# руководствовались 1.0
# доступностью 1.0
# гибкостью 1.0
# остановились 1.0
# пакете 1.0
# tmt 1.0
# реализующем 1.0
# http 1.0
# //code.google.com/p/topic-modeling-tool/ 1.0
# разработчики 1.0
# ньюмэн 1.0
# коллеги 1.0
# калифорнийский 1.0
# университет 1.0
# приведены 1.0
# раздел 1.0
# программа 1.0
# рис 1.0
# пользователь 1.0
# загружает 1.0
# выбирает 1.0
# автоматически 1.0
# генерируются 1.0
# программы 1.0
# содержит 1.0
# списки 1.0
# проводились 1.0
# латинице 1.0
# использовались 1.0
# журнала 1.0
# time 1.0
# экклезиологической 1.0
# cicling-2002 1.0
# гомеопатии 1.0
# растениеводству 1.0
# рассказы 1.0
# повести 1.0
# старк 1.0
# дж. 1.0
# даррелла 1.0
# правам 1.0
# человека 1.0
# .lda 1.0
# обоснованно 1.0
# метод 1.0
# утверждению 1.0
# специалистов 1.0
# пригоден 1.0
# варьироваться 1.0
# достаточно 1.0
# выполнялись 1.0
# пошагово 1.0
# приведем 1.0
# прокомментируем 1.0
# пример 1.0
# проведено 1.0
# материалов 1.0
# //www.cicling.org/2002/ 1.0
# //repository.dlsi.ua.es/357/ 1.0
# примерно 1.0
# тыс. 1.0
# с/у 1.0
# имеется 1.0
# числе 1.0
# linguistic 1.0
# syntax 1.0
# morphology 1.0
# parsing 1.0
# ambiguity 1.0
# wsd 1.0
# anaphora 1.0
# pos 1.0
# spelling 1.0
# lexicon 1.0
# lexics 1.0
# corpus 1.0
# text 1.0
# generation 1.0
# processing 1.0
# information 1.0
# retrieval 1.0
# summarization 1.0
# classifi 1.0
# cation 1.0
# texts 1.0
# //www.cs.buap.mx/~dpinto/research/cicling07_1/pinto06c/node4.html 1.0
# основе 1.0
# табл 1.0
# адекватно 1.0
# отражают 1.0
# содержательное 1.0
# разнообразие 1.0
# охватывающей 1.0
# направления 1.0
# отличаются 1.0
# компактностью 1.0
# шума 1.0
# pronouns 1.0
# pronoun 1.0
# resolution 1.0
# number 1.0
# antecedent 1.0
# mars 1.0
# rate 1.0
# performance 1.0
# имели 1.0
# сравнить 1.0
# полученных 1.0
# ассоциированных 1.0
# intersentential 1.0
# coreference 1.0
# intrasentential 1.0
# extensively 1.0
# lancaster 1.0
# outweighed 1.0
# santorini 1.0
# duplication 1.0
# ... 1.0
# armando 1.0
# maximiliano 1.0
# trabajando 1.0
# заметно 1.0
# значимыми 1.0
# перечне 1.0
# являются 1.0
# первые 1.0
# семантике 1.0
# всё 1.0
# свидетельствует 1.0
# пользу 1.0
# проанализированы 1.0
# истории 1.0
# косово 1.0
# метохии 1.0
# имеют 1.0
# православие 1.0
# политическая 1.0
# история 1.0
# нашло 1.0
# отражение 1.0
# имен 1.0
# собственных 1.0
# общих 1.0
# kosovo 1.0
# metohia 1.0
# содержат 1.0
# monastery 1.0
# church 1.0
# orthodox 1.0
# monksи 1.0
# приводятся 1.0
# cultural 1.0
# economic 1.0
# albanian 1.0
# turks 1.0
# проиллюстрированы 1.0
# провели 1.0
# рассматривались 1.0
# arnica 1.0
# bryonia 1.0
# gelsemium 1.0
# opium 1.0
# ruta 1.0
# книга 1.0
# materia 1.0
# medica 1.0
# кента 1.0
# которая 1.0
# считается 1.0
# энциклопедия 1.0
# современных 1.0
# грив 1.0
# сформированных 1.0
# вошедших 1.0
# дает 1.0
# первый 1.0
# сведения 1.0
# симптомах 1.0
# связанных 1.0
# head 1.0
# symptoms 1.0
# headache 1.0
# room 1.0
# eyes 1.0
# headaches 1.0
# violent 1.0
# congestion 1.0
# state 1.0
# pressure 1.0
# ожиданиям 1.0
# скорее 1.0
# медицинского 1.0
# bryony 1.0
# effective 1.0
# infl 1.0
# ammation 1.0
# ammatory 1.0
# results 1.0
# medications 1.0
# root 1.0
# tenderness 1.0
# soreness 1.0
# plant 1.0
# plants 1.0
# seeds 1.0
# condition 1.0
# part 1.0
# grow 1.0
# early 1.0
# alleviating 1.0
# serous 1.0
# toxic 1.0
# следовало 1.0
# информацию 1.0
# хранения 1.0
# winter 1.0
# late 1.0
# frame 1.0
# soil 1.0
# prefers 1.0
# greenhouse 1.0
# seedlings 1.0
# dioecious 1.0
# hedgerows 1.0
# remedy 1.0
# toxicity 1.0
# позволяют 1.0
# одобрительно 1.0
# относиться 1.0
# алгоритму 1.0
# пригодному 1.0
# оценки 1.0
# содержания 1.0
# соответствия 1.0
# имеющихся 1.0
# которых 1.0
# реализована 1.0
# способствовать 1.0

# %%
keywords
# Out:
# [('доступные исследователям компьютерные инструменты автоматической обработки',
#   25.107142857142858),
#  ('ранними результатами автоматического выделения', 16.0),
#  ('1.введение разработка новых подходов', 15.0),
#  ('практических разработках последних лет', 14.0),
#  ('разных значениях многозначные слова', 12.714285714285714),
#  ('тематическое моделирование научных текстов', 11.736842105263158),
#  ('автоматическом выделении ключевых слов', 11.664285714285715),
#  ('круг практических задач', 9.5),
#  ('важный класс задач', 9.0),
#  ('близкими дистрибутивными свойствами', 9.0),
#  ('анализу социальных сетей', 9.0),
#  ('иным экспериментальным данным', 9.0),
#  ('больших текстовых коллекций', 9.0),
#  ('использование многоуровневой разметки', 9.0),
#  ('ограничение контекстного окна', 9.0),
#  ('качестве текстовых коллекций', 9.0),
#  ('стандартной векторной моделью', 9.0),
#  ('качественного семантического сжатия', 9.0),
#  ('сопоставительным анализом набора', 9.0),
#  ('открытом доступе инструментов', 9.0),
#  ('уровне лингвистической обработки', 8.857142857142858),
#  ('этих скрытых переменных', 8.75),
#  ('адаптацией этих инструментов', 8.75),
#  ('решение этих задач', 8.75),
#  ('результаты автоматической обработки', 8.607142857142858),
#  ('оценке семантической однородности/неоднородности', 8.5),
#  ('особенности различных методов', 8.5),
#  ('обработке текстовых данных', 8.5),
#  ('скрытая тематическая марковская', 8.5),
#  ('традиционных лингвистических методов', 8.5),
#  ('свертка признакового пространства', 8.166666666666666),
#  ('особое внимание исследователей', 8.0),
#  ('вероятностный латентно-семантический анализ', 8.0),
#  ('какое-либо ключевое слово', 8.0),
#  ('моделях семантического пространства', 8.0),
#  ('случайная выборка слов', 7.95),
#  ('3.типы тематических моделей', 7.916666666666666),
#  ('спецификация тематических моделей', 7.916666666666666),
#  ('смысловую компрессию текста', 7.833333333333333),
#  ('обработке больших текстов', 7.7368421052631575),
#  ('автоматическую обработку текстов', 7.7368421052631575),
#  ('наборах ключевых слов', 7.664285714285715),
#  ('пределах текстовой коллекции', 7.647727272727273),
#  ('средней текстовой коллекции', 7.647727272727273),
#  ('данной текстовой коллекции', 7.647727272727273),
#  ('задача тематического моделирования', 7.6),
#  ('основу тематического моделирования', 7.6),
#  ('характеризующий отдельный документ', 7.6),
#  ('средству тематического моделирования', 7.6),
#  ('матрицей совместной встречаемости', 7.583333333333334),
#  ('выявлению тематической структуры', 7.5),
#  ('текстами больших объемов', 7.5),
#  ('автоматическому моделированию тематики', 7.5),
#  ('характеризующих указанные тексты', 7.458333333333334),
#  ('характеризующих текстовую коллекцию', 7.333333333333334),
#  ('задающими тематику текстов', 7.2368421052631575),
#  ('лекарственных свойствах растений', 7.166666666666667),
#  ('общий объем текстов', 7.0701754385964914),
#  ('темах второго текста', 6.833333333333333),
#  ('набор ключевых слов', 6.664285714285715),
#  ('перечень ключевых слов', 6.664285714285715),
#  ('порождаемых семейством распределений', 6.5),
#  ('автоматической обработки', 6.107142857142858),
#  ('тематическое моделирование', 6.0),
#  ('результаты обработки', 5.357142857142858),
#  ('признакового пространства', 5.166666666666666),
#  ('выделении классов', 5.0),
#  ('тематических моделях', 5.0),
#  ('латентно-семантический анализ', 5.0),
#  ('текстовую коллекцию', 5.0),
#  ('разных частей', 5.0),
#  ('параметры обработки', 4.857142857142858),
#  ('выявление этих', 4.75),
#  ('ключевых слов', 4.664285714285715),
#  ('текстовой коллекции', 4.647727272727273),
#  ('тематического моделирования', 4.6),
#  ('совместной встречаемости', 4.583333333333334),
#  ('лингвистическому моделированию', 4.5),
#  ('арсенал методов', 4.5),
#  ('семантической близости', 4.5),
#  ('ряд методов', 4.5),
#  ('новых документов', 4.5),
#  ('корреляционная тематическая', 4.5),
#  ('тематической структуры', 4.5),
#  ('умеренных объемов', 4.5),
#  ('пересекающуюся тематику', 4.5),
#  ('лекарственных средств', 4.5),
#  ('база данных', 4.5),
#  ('ключевых слова', 4.428571428571429),
#  ('предыдущих моделях', 4.333333333333334),
#  ('объем списков', 4.333333333333334),
#  ('объем каждого', 4.333333333333334),
#  ('тестовой коллекции', 4.272727272727273),
#  ('тематике коллекции', 4.272727272727273),
#  ('частоту встречаемости', 4.25),
#  ('алгебраических моделей', 4.25),
#  ('публицистические тексты', 4.125),
#  ('научные тексты', 4.125),
#  ('научно-популярные тексты', 4.125),
#  ('художественные тексты', 4.125),
#  ('деловые тексты', 4.125),
#  ('рассматриваемые тексты', 4.125),
#  ('естественного языка', 4.0),
#  ('данном ряду', 4.0),
#  ('создающие предпосылки', 4.0),
#  ('проведению экспериментов', 4.0),
#  ('данными средствами', 4.0),
#  ('отражающий переход', 4.0),
#  ('скрытыми переменными', 4.0),
#  ('пересекающиеся классы', 4.0),
#  ('таком случае', 4.0),
#  ('результат бикластеризации', 4.0),
#  ('любое слово', 4.0),
#  ('некоторой вероятностью', 4.0),
#  ('нескольким темам', 4.0),
#  ('тематическом моделировании', 4.0),
#  ('порожденная неким', 4.0),
#  ('каким набором', 4.0),
#  ('лингвистическом смысле', 4.0),
#  ('имеющих определенную', 4.0),
#  ('вероятность появления', 4.0),
#  ('стандартная векторная', 4.0),
#  ('краткую характеристику', 4.0),
#  ('подробные обзоры', 4.0),
#  ('n-мерном пространстве', 4.0),
#  ('неудобством использования', 4.0),
#  ('синонимические отношения', 4.0),
#  ('основные характеристики', 4.0),
#  ('методом байеса', 4.0),
#  ('риском переобучения', 4.0),
#  ('сложностью добавления', 4.0),
#  ('вероятностным распределением', 4.0),
#  ('большого объема', 4.0),
#  ('одну тему', 4.0),
#  ('мере связанные', 4.0),
#  ('совместная вероятностная', 4.0),
#  ('привлечением аппарата', 4.0),
#  ('дистрибутивной семантики', 4.0),
#  ('языковых ресурсов', 4.0),
#  ('случае доступности', 4.0),
#  ('учет границ', 4.0),
#  ('синтаксических групп', 4.0),
#  ('назначение весов', 4.0),
#  ('контекстных элементов', 4.0),
#  ('нормализация значений', 4.0),
#  ('повышению качества', 4.0),
#  ('выборе инструмента', 4.0),
#  ('программные пакеты', 4.0),
#  ('программные реализации', 4.0),
#  ('удобный интерфейс', 4.0),
#  ('выдача результатов', 4.0),
#  ('английском языке', 4.0),
#  ('мировой политике', 4.0),
#  ('нашем случае', 4.0),
#  ('нескольких десятков', 4.0),
#  ('нескольких сотен', 4.0),
#  ('отдельные иллюстрации', 4.0),
#  ('дающие представление', 4.0),
#  ('результатах экспериментов', 4.0),
#  ('компьютерной лингвистике', 4.0),
#  ('подробная информация', 4.0),
#  ('описание основных', 4.0),
#  ('компьютерной лингвистики', 4.0),
#  ('редким исключением', 4.0),
#  ('низкой долей', 4.0),
#  ('имена собственные', 4.0),
#  ('некоторых других', 4.0),
#  ('трех источниках', 4.0),
#  ('авторитетным справочником', 4.0),
#  ('предсказуемым образом', 4.0),
#  ('лекарственными средствами', 4.0),
#  ('ботанического характера', 4.0),
#  ('внешнем виде', 4.0),
#  ('условиях произрастания', 4.0),
#  ('особенностях сбора', 4.0),
#  ('меньшей степени', 4.0),
#  ('заключение наблюдения', 4.0),
#  ('сделанные нами', 4.0),
#  ('ходе экспериментов', 4.0),
#  ('перспективы исследования', 4.0),
#  ('русскоязычными текстами', 4.0),
#  ('совокупности слов', 3.95),
#  ('порядок слов', 3.95),
#  ('наборами слов', 3.95),
#  ('значимых слов', 3.95),
#  ('первого текста', 3.833333333333333),
#  ('документах коллекции', 3.772727272727273),
#  ('корпусах текстов', 3.736842105263158),
#  ('входных текстов', 3.736842105263158),
#  ('двух текстов', 3.736842105263158),
#  ('описанию слова', 3.7142857142857144),
#  ('одновременной кластеризации', 3.666666666666667),
#  ('нечеткой кластеризации', 3.666666666666667),
#  ('второй источник', 3.666666666666667),
#  ('третий источник', 3.666666666666667),
#  ('конкретный документ', 3.6),
#  ('исследователям', 3.5),
#  ('совокупности документов', 3.5),
#  ('семейство вероятностных', 3.5),
#  ('способ упорядочения', 3.5),
#  ('набор документов', 3.5),
#  ('соответствующих теме', 3.5),
#  ('ожидаемое число', 3.5),
#  ('большинство разработчиков', 3.5),
#  ('устойчивостью работы', 3.5),
#  ('доступные', 3.5),
#  ('число итераций', 3.5),
#  ('материалы конференции', 3.5),
#  ('полученные данные', 3.5),
#  ('следующее наполнение', 3.5),
#  ('темой напрямую', 3.5),
#  ('многозначность слов', 3.45),
#  ('множестве слов', 3.45),
#  ('порождение документа', 3.333333333333333),
#  ('текст конвенции', 3.333333333333333),
#  ('метку темы', 3.2857142857142856),
#  ('полученные темы', 3.2857142857142856),
#  ('наши эксперименты', 3.25),
#  ('конце статьи', 3.25),
#  ('тематические модели', 3.2222222222222223),
#  ('каждая тема', 3.2),
#  ('возможность заметить', 3.0),
#  ('лет', 2.5),
#  ('характеризующих', 2.3333333333333335),
#  ('моделей', 2.25),
#  ('тематической', 2.0),
#  ('набор', 2.0),
#  ('слово', 2.0),
#  ('семейством', 2.0),
#  ('исследователей', 2.0),
#  ('темах', 2.0),
#  ('текстами', 2.0),
#  ('тематики', 2.0),
#  ('перечень', 2.0),
#  ('слов', 1.95),
#  ('текста', 1.8333333333333333),
#  ('текстов', 1.736842105263158),
#  ('слова', 1.7142857142857142),
#  ('кластеризации', 1.6666666666666667),
#  ('растений', 1.6666666666666667),
#  ('источник', 1.6666666666666667),
#  ('документ', 1.6),
#  ('документов', 1.5),
#  ('способ', 1.5),
#  ('распределений', 1.5),
#  ('множестве', 1.5),
#  ('документах', 1.5),
#  ('вероятностных', 1.5),
#  ('многозначность', 1.5),
#  ('теме', 1.5),
#  ('число', 1.5),
#  ('работы', 1.5),
#  ('конференции', 1.5),
#  ('разработчиков', 1.5),
#  ('заметить', 1.5),
#  ('наполнение', 1.5),
#  ('возможность', 1.5),
#  ('данные', 1.5),
#  ('темой', 1.5),
#  ('документа', 1.3333333333333333),
#  ('текст', 1.3333333333333333),
#  ('темы', 1.2857142857142858),
#  ('эксперименты', 1.25),
#  ('статьи', 1.25),
#  ('модели', 1.2222222222222223),
#  ('тема', 1.2),
#  ('позволяет', 1.0),
#  ('по-новому', 1.0),
#  ('взглянуть', 1.0),
#  ('производимую', 1.0),
#  ('словосочетаний', 1.0),
#  ('классификации', 1.0),
#  ('лексики', 1.0),
#  ('п', 1.0),
#  ('ср', 1.0),
#  ('описанные', 1.0),
#  ('статьях', 1.0),
#  ('митрофанова', 1.0),
#  ('мухин', 1.0),
#  ('паничева', 1.0),
#  ('mitrofanova', 1.0),
#  ('mukhin', 1.0),
#  ('panicheva', 1.0),
#  ('грачкова', 1.0),
#  ('шиморина', 1.0),
#  ('особняком', 1.0),
#  ('стоит', 1.0),
#  ('корпусов', 1.0),
#  ('последние', 1.0),
#  ('несколько', 1.0),
#  ('существенно', 1.0),
#  ('расширился', 1.0),
#  ('появились', 1.0),
#  ('gate', 1.0),
#  ('lingpipe', 1.0),
#  ('nltk', 1.0),
#  ('stanford', 1.0),
#  ('toolkit', 1.0),
#  ('т', 1.0),
#  ('д', 1.0),
#  ('параллельно', 1.0),
#  ('расширяется', 1.0),
#  ('которые', 1.0),
#  ('решаются', 1.0),
#  ('обращено', 1.0),
#  ('сообществ', 1.0),
#  ('bodrunova', 1.0),
#  ('al.', 1.0),
#  ('koltsova', 1.0),
#  ('связи', 1.0),
#  ('этим', 1.0),
#  ('представляется', 1.0),
#  ('важным', 1.0),
#  ('оценить', 1.0),
#  ('применимость', 1.0),
#  ('2.тематическое', 1.0),
#  ('моделирование—что', 1.0),
#  ('такое', 1.0),
#  ('построения', 1.0),
#  ('набору', 1.0),
#  ('факторами', 1.0),
#  ('выявления', 1.0),
#  ('применять', 1.0),
#  ('нечеткую', 1.0),
#  ('кластеризацию', 1.0),
#  ('разбиение', 1.0),
#  ('точки', 1.0),
#  ('зрения', 1.0),
#  ('относится', 1.0),
#  ('сказать', 1.0),
#  ('ставится', 1.0),
#  ('соответствие', 1.0),
#  ('составляет', 1.0),
#  ('используется', 1.0),
#  ('подход', 1.0),
#  ('называемый', 1.0),
#  ('мешок', 1.0),
#  ('имеет', 1.0),
#  ('значения', 1.0),
#  ('учитывается', 1.0),
#  ('предложении', 1.0),
#  ('взаимное', 1.0),
#  ('расположение', 1.0),
#  ('тексте', 1.0),
#  ('описывается', 1.0),
#  ('время', 1.0),
#  ('корпусе', 1.0),
#  ('множеством', 1.0),
#  ('исходя', 1.0),
#  ('установить', 1.0),
#  ('распределение', 1.0),
#  ('выяснить', 1.0),
#  ('порождается', 1.0),
#  ('могут', 1.0),
#  ('присутствовать', 1.0),
#  ('искусство', 1.0),
#  ('дети', 1.0),
#  ('образование', 1.0),
#  ('жизнь', 1.0),
#  ('ген', 1.0),
#  ('мозг', 1.0),
#  ('ассоциируемые', 1.0),
#  ('рис.', 1.0),
#  ('ng', 1.0),
#  ('jordan', 1.0),
#  ('lafferty', 1.0),
#  ('широко', 1.0),
#  ('опираются', 1.0),
#  ('процедуры', 1.0),
#  ('распространены', 1.0),
#  ('модель', 1.0),
#  ('vsm', 1.0),
#  ('vector', 1.0),
#  ('space', 1.0),
#  ('model', 1.0),
#  ('lsa', 1.0),
#  ('latent', 1.0),
#  ('semantic', 1.0),
#  ('analysis', 1.0),
#  ('генеративных', 1.0),
#  ('применяются', 1.0),
#  ('plsa', 1.0),
#  ('probalilistic', 1.0),
#  ('латентное', 1.0),
#  ('размещение', 1.0),
#  ('дирихле', 1.0),
#  ('lda', 1.0),
#  ('dirichlet', 1.0),
#  ('allocation', 1.0),
#  ('дадим', 1.0),
#  ('anaya', 1.0),
#  ('lee', 1.0),
#  ('song', 1.0),
#  ('topic', 1.0),
#  ('modelling', 1.0),
#  ('bibliography', 1.0),
#  ('термы-термы', 1.0),
#  ('термы-документы', 1.0),
#  ('словам', 1.0),
#  ('текстам', 1.0),
#  ('ставятся', 1.0),
#  ('вектора', 1.0),
#  ('сравнение', 1.0),
#  ('векторов', 1.0),
#  ('правило', 1.0),
#  ('определение', 1.0),
#  ('косинуса', 1.0),
#  ('угла', 1.0),
#  ('векторами', 1.0),
#  ('насколько', 1.0),
#  ('характерно', 1.0),
#  ('связаны', 1.0),
#  ('собой', 1.0),
#  ('документе', 1.0),
#  ('близки', 1.0),
#  ('документы', 1.0),
#  ('недостатки', 1.0),
#  ('работе', 1.0),
#  ('невозможностью', 1.0),
#  ('учесть', 1.0),
#  ('словами', 1.0),
#  ('наследует', 1.0),
#  ('сокращения', 1.0),
#  ('размерности', 1.0),
#  ('текстах', 1.0),
#  ('сингулярное', 1.0),
#  ('разложение', 1.0),
#  ('матрицы', 1.0),
#  ('singular', 1.0),
#  ('value', 1.0),
#  ('decomposition', 1.0),
#  ('svd', 1.0),
#  ('отличие', 1.0),
#  ('пригодна', 1.0),
#  ('описания', 1.0),
#  ('частично', 1.0),
#  ('контекстную', 1.0),
#  ('синонимию', 1.0),
#  ('справляется', 1.0),
#  ('многозначностью', 1.0),
#  ('сложно', 1.0),
#  ('заранее', 1.0),
#  ('задать', 1.0),
#  ('приписать', 1.0),
#  ('используя', 1.0),
#  ('являет', 1.0),
#  ('вероятностную', 1.0),
#  ('модификацию', 1.0),
#  ('производится', 1.0),
#  ('соответствии', 1.0),
#  ('отчасти', 1.0),
#  ('учитывает', 1.0),
#  ('представлять', 1.0),
#  ('разные', 1.0),
#  ('основ', 1.0),
#  ('ные', 1.0),
#  ('сглаживает', 1.0),
#  ('шероховатости', 1.0),
#  ('имеющиеся', 1.0),
#  ('опирающейся', 1.0),
#  ('характеризуется', 1.0),
#  ('описываются', 1.0),
#  ('описывать', 1.0),
#  ('корпуса', 1.0),
#  ('попадать', 1.0),
#  ('речи', 1.0),
#  ('данная', 1.0),
#  ('предусматривает', 1.0),
#  ('установление', 1.0),
#  ('связей', 1.0),
#  ('темами', 1.0),
#  ('известны', 1.0),
#  ('упомянутыми', 1.0),
#  ('частности', 1.0),
#  ('jpm', 1.0),
#  ('joint', 1.0),
#  ('probabilistic', 1.0),
#  ('ahmm', 1.0),
#  ('aspect', 1.0),
#  ('hidden', 1.0),
#  ('markov', 1.0),
#  ('автортематическая', 1.0),
#  ('atm', 1.0),
#  ('author-topic', 1.0),
#  ('автор-получатель', 1.0),
#  ('artm', 1.0),
#  ('author-recipient', 1.0),
#  ('ctm', 1.0),
#  ('correlated', 1.0),
#  ('связана', 1.0),
#  ('различиями', 1.0),
#  ('baroni', 1.0),
#  ('bernardi', 1.0),
#  ('zamparelli', 1.0),
#  ('mitchell', 1.0),
#  ('lapata', 1.0),
#  ('склоняются', 1.0),
#  ('необходимости', 1.0),
#  ('интеграции', 1.0),
#  ('статистических', 1.0),
#  ('анализа', 1.0),
#  ('реализовано', 1.0),
#  ('wsm', 1.0),
#  ('word', 1.0),
#  ('hyperspace', 1.0),
#  ('analogue', 1.0),
#  ('language', 1.0),
#  ('coals', 1.0),
#  ('occurrence', 1.0),
#  ('lexical', 1.0),
#  ('semantics', 1.0),
#  ('rohde', 1.0),
#  ('gonnerman', 1.0),
#  ('plaut', 1.0),
#  ('sahlgren', 1.0),
#  ('лемматизация', 1.0),
#  ('морфосинтаксическая', 1.0),
#  ('семантическая', 1.0),
#  ('аннотация', 1.0),
#  ('существующих', 1.0),
#  ('коэффициентов', 1.0),
#  ('методы', 1.0),
#  ('способствуют', 1.0),
#  ('4.наши', 1.0),
#  ('руководствовались', 1.0),
#  ('доступностью', 1.0),
#  ('гибкостью', 1.0),
#  ('остановились', 1.0),
#  ('пакете', 1.0),
#  ('tmt', 1.0),
#  ('реализующем', 1.0),
#  ('http', 1.0),
#  ('//code.google.com/p/topic-modeling-tool/', 1.0),
#  ('разработчики', 1.0),
#  ('ньюмэн', 1.0),
#  ('коллеги', 1.0),
#  ('калифорнийский', 1.0),
#  ('университет', 1.0),
#  ('приведены', 1.0),
#  ('раздел', 1.0),
#  ('программа', 1.0),
#  ('рис', 1.0),
#  ('пользователь', 1.0),
#  ('загружает', 1.0),
#  ('выбирает', 1.0),
#  ('автоматически', 1.0),
#  ('генерируются', 1.0),
#  ('программы', 1.0),
#  ('содержит', 1.0),
#  ('списки', 1.0),
#  ('проводились', 1.0),
#  ('латинице', 1.0),
#  ('использовались', 1.0),
#  ('журнала', 1.0),
#  ('time', 1.0),
#  ('экклезиологической', 1.0),
#  ('cicling-2002', 1.0),
#  ('гомеопатии', 1.0),
#  ('растениеводству', 1.0),
#  ('рассказы', 1.0),
#  ('повести', 1.0),
#  ('старк', 1.0),
#  ('дж.', 1.0),
#  ('даррелла', 1.0),
#  ('правам', 1.0),
#  ('человека', 1.0),
#  ('.lda', 1.0),
#  ('обоснованно', 1.0),
#  ('метод', 1.0),
#  ('утверждению', 1.0),
#  ('специалистов', 1.0),
#  ('пригоден', 1.0),
#  ('варьироваться', 1.0),
#  ('достаточно', 1.0),
#  ('выполнялись', 1.0),
#  ('пошагово', 1.0),
#  ('приведем', 1.0),
#  ('прокомментируем', 1.0),
#  ('пример', 1.0),
#  ('проведено', 1.0),
#  ('материалов', 1.0),
#  ('//www.cicling.org/2002/', 1.0),
#  ('//repository.dlsi.ua.es/357/', 1.0),
#  ('примерно', 1.0),
#  ('тыс.', 1.0),
#  ('с/у', 1.0),
#  ('имеется', 1.0),
#  ('числе', 1.0),
#  ('linguistic', 1.0),
#  ('syntax', 1.0),
#  ('morphology', 1.0),
#  ('parsing', 1.0),
#  ('ambiguity', 1.0),
#  ('wsd', 1.0),
#  ('anaphora', 1.0),
#  ('pos', 1.0),
#  ('spelling', 1.0),
#  ('lexicon', 1.0),
#  ('lexics', 1.0),
#  ('corpus', 1.0),
#  ('text', 1.0),
#  ('generation', 1.0),
#  ('processing', 1.0),
#  ('information', 1.0),
#  ('retrieval', 1.0),
#  ('summarization', 1.0),
#  ('classifi', 1.0),
#  ('cation', 1.0),
#  ('texts', 1.0),
#  ('//www.cs.buap.mx/~dpinto/research/cicling07_1/pinto06c/node4.html', 1.0),
#  ('основе', 1.0),
#  ('табл', 1.0),
#  ('адекватно', 1.0),
#  ('отражают', 1.0),
#  ('содержательное', 1.0),
#  ('разнообразие', 1.0),
#  ('охватывающей', 1.0),
#  ('направления', 1.0),
#  ('отличаются', 1.0),
#  ('компактностью', 1.0),
#  ('шума', 1.0),
#  ('pronouns', 1.0),
#  ('pronoun', 1.0),
#  ('resolution', 1.0),
#  ('number', 1.0),
#  ('antecedent', 1.0),
#  ('mars', 1.0),
#  ('rate', 1.0),
#  ('performance', 1.0),
#  ('имели', 1.0),
#  ('сравнить', 1.0),
#  ('полученных', 1.0),
#  ('ассоциированных', 1.0),
#  ('intersentential', 1.0),
#  ('coreference', 1.0),
#  ('intrasentential', 1.0),
#  ('extensively', 1.0),
#  ('lancaster', 1.0),
#  ('outweighed', 1.0),
#  ('santorini', 1.0),
#  ('duplication', 1.0),
#  ('...', 1.0),
#  ('armando', 1.0),
#  ('maximiliano', 1.0),
#  ('trabajando', 1.0),
#  ('заметно', 1.0),
#  ('значимыми', 1.0),
#  ('перечне', 1.0),
#  ('являются', 1.0),
#  ('первые', 1.0),
#  ('семантике', 1.0),
#  ('всё', 1.0),
#  ('свидетельствует', 1.0),
#  ('пользу', 1.0),
#  ('проанализированы', 1.0),
#  ('истории', 1.0),
#  ('косово', 1.0),
#  ('метохии', 1.0),
#  ('имеют', 1.0),
#  ('православие', 1.0),
#  ('политическая', 1.0),
#  ('история', 1.0),
#  ('нашло', 1.0),
#  ('отражение', 1.0),
#  ('имен', 1.0),
#  ('собственных', 1.0),
#  ('общих', 1.0),
#  ('kosovo', 1.0),
#  ('metohia', 1.0),
#  ('содержат', 1.0),
#  ('monastery', 1.0),
#  ('church', 1.0),
#  ('orthodox', 1.0),
#  ('monksи', 1.0),
#  ('приводятся', 1.0),
#  ('cultural', 1.0),
#  ('economic', 1.0),
#  ('albanian', 1.0),
#  ('turks', 1.0),
#  ('проиллюстрированы', 1.0),
#  ('провели', 1.0),
#  ('рассматривались', 1.0),
#  ('arnica', 1.0),
#  ('bryonia', 1.0),
#  ('gelsemium', 1.0),
#  ('opium', 1.0),
#  ('ruta', 1.0),
#  ('книга', 1.0),
#  ('materia', 1.0),
#  ('medica', 1.0),
#  ('кента', 1.0),
#  ('которая', 1.0),
#  ('считается', 1.0),
#  ('энциклопедия', 1.0),
#  ('современных', 1.0),
#  ('грив', 1.0),
#  ('сформированных', 1.0),
#  ('вошедших', 1.0),
#  ('дает', 1.0),
#  ('первый', 1.0),
#  ('сведения', 1.0),
#  ('симптомах', 1.0),
#  ('связанных', 1.0),
#  ('head', 1.0),
#  ('symptoms', 1.0),
#  ('headache', 1.0),
#  ('room', 1.0),
#  ('eyes', 1.0),
#  ('headaches', 1.0),
#  ('violent', 1.0),
#  ('congestion', 1.0),
#  ('state', 1.0),
#  ('pressure', 1.0),
#  ('ожиданиям', 1.0),
#  ('скорее', 1.0),
#  ('медицинского', 1.0),
#  ('bryony', 1.0),
#  ('effective', 1.0),
#  ('infl', 1.0),
#  ('ammation', 1.0),
#  ('ammatory', 1.0),
#  ('results', 1.0),
#  ('medications', 1.0),
#  ('root', 1.0),
#  ('tenderness', 1.0),
#  ('soreness', 1.0),
#  ('plant', 1.0),
#  ('plants', 1.0),
#  ('seeds', 1.0),
#  ('condition', 1.0),
#  ('part', 1.0),
#  ('grow', 1.0),
#  ('early', 1.0),
#  ('alleviating', 1.0),
#  ('serous', 1.0),
#  ('toxic', 1.0),
#  ('следовало', 1.0),
#  ('информацию', 1.0),
#  ('хранения', 1.0),
#  ('winter', 1.0),
#  ('late', 1.0),
#  ('frame', 1.0),
#  ('soil', 1.0),
#  ('prefers', 1.0),
#  ('greenhouse', 1.0),
#  ('seedlings', 1.0),
#  ('dioecious', 1.0),
#  ('hedgerows', 1.0),
#  ('remedy', 1.0),
#  ('toxicity', 1.0),
#  ('позволяют', 1.0),
#  ('одобрительно', 1.0),
#  ('относиться', 1.0),
#  ('алгоритму', 1.0),
#  ('пригодному', 1.0),
#  ('оценки', 1.0),
#  ('содержания', 1.0),
#  ('соответствия', 1.0),
#  ('имеющихся', 1.0),
#  ('которых', 1.0),
#  ('реализована', 1.0),
#  ('способствовать', 1.0)]

# %%
with open('rake_keywords.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
# !pip install keybert

# %%
#KeyBERT
import keybert

# %%
from keybert import KeyBERT

# %%
with open('/content/art_m.txt', 'r', encoding='utf-8') as f:
    doc = f.read()

# %%
kw_model = KeyBERT()

# %%
keywords = kw_model.extract_keywords(doc)

# %%
keywords
# Out:
# [('источниках', 0.3613),
#  ('алгебраических', 0.3591),
#  ('автоматической', 0.3551),
#  ('автоматически', 0.3536),
#  ('русскоязычных', 0.3536)]

# %%
keywords = kw_model.extract_keywords(doc, top_n=20)
keywords
# Out:
# [('источниках', 0.3613),
#  ('алгебраических', 0.3591),
#  ('автоматической', 0.3551),
#  ('автоматически', 0.3536),
#  ('русскоязычных', 0.3536),
#  ('необходимости', 0.3434),
#  ('исследователей', 0.342),
#  ('автоматическую', 0.339),
#  ('имеющихся', 0.3355),
#  ('использования', 0.3353),
#  ('ассоциированных', 0.3346),
#  ('русскоязычными', 0.3345),
#  ('различиями', 0.3333),
#  ('автоматическом', 0.3328),
#  ('различных', 0.3325),
#  ('одновременной', 0.3323),
#  ('лингвистических', 0.3312),
#  ('словосочетаний', 0.3306),
#  ('автоматического', 0.3305),
#  ('тематических', 0.3301)]

# %%
with open('KeyBERT_top_20.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
keywords = kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 2), top_n=20)
keywords
# Out:
# [('использование многоуровневой', 0.4145),
#  ('лингвистических методов', 0.4067),
#  ('их семантической', 0.4063),
#  ('моделирования тематических', 0.4063),
#  ('исследователей сейчас', 0.4012),
#  ('особенности различных', 0.401),
#  ('нескольких десятков', 0.4006),
#  ('подходов лингвистическому', 0.3987),
#  ('автоматического выделения', 0.3968),
#  ('алгебраических моделей', 0.3872),
#  ('уровне лингвистической', 0.387),
#  ('многоуровневой разметки', 0.3856),
#  ('среди алгебраических', 0.3853),
#  ('риском переобучения', 0.3835),
#  ('тематического моделирования', 0.3811),
#  ('различных методов', 0.381),
#  ('провели автоматическую', 0.3796),
#  ('одновременной кластеризации', 0.3794),
#  ('моделирования их', 0.3789),
#  ('источник предсказуемым', 0.3786)]

# %%
with open('KeyBERT_top_20_bigram.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
keywords = kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 3), top_n=20)
keywords
# Out:
# [('особенности различных методов', 0.4447),
#  ('тематического моделирования тематических', 0.4397),
#  ('использование многоуровневой разметки', 0.4388),
#  ('тематического моделирования их', 0.436),
#  ('автоматического выделения ключевых', 0.4333),
#  ('моделирования среди алгебраических', 0.4321),
#  ('analysis среди вероятностных', 0.4275),
#  ('имеющиеся трех источниках', 0.4265),
#  ('зрения их семантической', 0.4264),
#  ('новых подходов лингвистическому', 0.4256),
#  ('однородности неоднородности текстов', 0.4233),
#  ('текстовых коллекций позволяет', 0.4217),
#  ('ресурсов склоняются необходимости', 0.4216),
#  ('информация от разработчиков', 0.4216),
#  ('ключевых слов ассоциированных', 0.4209),
#  ('введение разработка новых', 0.4206),
#  ('от нескольких десятков', 0.4196),
#  ('необходимости интеграции статистических', 0.4188),
#  ('словами их многозначность', 0.4184),
#  ('разнообразие текстовой коллекции', 0.418)]

# %%
with open('KeyBERT_top_20_trigram.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
#RuTermExtract

# %%
# !pip install rutermextract

# %%
from rutermextract import TermExtractor

# %%
term_extractor = TermExtractor()

# %%
with open('/content/art_m.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
for term in term_extractor(text):
    print(term.normalized, term.count)
# Out:
# модель 20
# тексты 16
# тематический моделирование 11
# тема 11
# lda 11
# слова 9
# текстовая коллекция 7
# vsm 7
# model 7
# ключевые слова 6
# текст 6
# п 6
# документы 6
# lsa 6
# слово 5
# and 5
# автоматическая обработка 4
# число 4
# соответствие 4
# описание 4
# документ 4
# выявление 4
# plsa 4
# blei 4
# anaphora 4
# тематические модели 3
# совместная встречаемость 3
# эксперименты 3
# темы 3
# таблы 3
# статья 3
# растениеводство 3
# распределения 3
# распределение 3
# работа 3
# пример 3
# перечень 3
# набор 3
# митрофанов 3
# корпус 3
# гомеопатия 3
# topic 3
# to 3
# latent 3
# cicling-2002 3
# большие текстовые коллекции 2
# тематическая структура 2
# публицистические тексты 2
# проведение экспериментов 2
# научные тексты 2
# лекарственные средства 2
# компьютерная лингвистика 2
# частность 2
# сравнение 2
# семейство 2
# связи 2
# сведение 2
# растения 2
# разработчики 2
# программа 2
# оценка 2
# основа 2
# обработка 2
# недостатки 2
# модели 2
# множество 2
# многозначность 2
# матрица 2
# кластеризация 2
# история 2
# исследователи 2
# имена 2
# дирихло 2
# возможность 2
# векторы 2
# анализ 2
# tmt 2
# texts 2
# text 2
# symptoms 2
# space 2
# semantics 2
# semantic 2
# p 2
# ng 2
# mitrofanova 2
# jordan 2
# infl 2
# et 2
# early 2
# correlated 2
# bryonia 2
# analysis 2
# analogue 2
# al 2
# первые три ключевых слова 1
# характеризующий отдельный документ 1
# характеризующие указанные тексты 1
# характеризующие текстовая коллекция 1
# традиционные лингвистические методы 1
# стандартная векторная модель 1
# средняя текстовая коллекция 1
# сопоставительный анализ набора 1
# смысловая компрессия текста 1
# случайная выборка слов 1
# порождаемые семейство распределений 1
# открытый доступ инструментов 1
# особое внимание исследователей 1
# общий объём текстов 1
# о<лекарственные свойства растений 1
# качественное семантический сжатие 1
# какое-либо ключевое слово 1
# иные экспериментальный данные 1
# задающие тематика текстов 1
# другие тематические модель 1
# данная текстовая коллекция 1
# вероятностный латентно-семантический анализ 1
# важный класс задач 1
# близкие дистрибутивные свойства 1
# автоматический моделирование тематики 1
# автоматическая обработка текстов 1
# языковые ресурсы 1
# число итераций 1
# частота встречаемости 1
# художественные тексты 1
# ход экспериментов 1
# учёт границ 1
# устойчивость работы 1
# условия произрастания 1
# умеренные объёмы 1
# удобный интерфейс 1
# три источниках 1
# третий источник 1
# тестовая коллекция 1
# тематическое моделирование<—<способ 1
# тематическое моделирование 1
# тематические модель 1
# тематика коллекции 1
# текстовые коллекции 1
# текстовые данные 1
# текст конвенции 1
# такой случай 1
# способ упорядочения 1
# социальные сети 1
# соответствующие тема 1
# создающие предпосылки 1
# совокупность слов 1
# совокупность документов 1
# сложность добавления 1
# следующее наполнение 1
# синтаксические группы 1
# синонимические отношения 1
# семантический пространство 1
# семантическая однородности/неоднородность 1
# семантическая близость 1
# ряд методов 1
# русскоязычные тексты 1
# риск переобучения 1
# результаты экспериментов 1
# результаты обработки 1
# результат бикластеризации 1
# редкое исключение 1
# рассматриваемые тексты 1
# ранние результаты 1
# разные части 1
# разные значения 1
# различные методы 1
# программные реализация 1
# программные пакеты 1
# признаковый пространство 1
# признаковый пространства<—<эти 1
# привлечение аппарата 1
# предыдущие модели 1
# предсказуемый образ 1
# практические разработки 1
# практические задачи 1
# последние годы 1
# порядок слов 1
# порождение документа 1
# полученные тема 1
# подробные обзоры 1
# подробная информация 1
# повышение качества 1
# перспективы исследования 1
# пересекающиеся классы 1
# пересекающаяся тематика 1
# первое текст 1
# параметры обработки 1
# отражающий переход 1
# отдельные иллюстрации 1
# особенности сбора 1
# основные характеристики 1
# описание слова 1
# ожидаемое число 1
# одновременная кластеризация 1
# одна тема 1
# объём списков 1
# нормализация значений 1
# новые подходы 1
# новые документы 1
# низкая доля 1
# нечёткая кластеризация 1
# неудобство использования 1
# несколько темам 1
# несколько сотен 1
# несколько десятков 1
# некоторая вероятность 1
# некое документ 1
# наши эксперименты 1
# наш случай 1
# научно-популярные тексты 1
# назначение весов 1
# наборы слов 1
# набор документов 1
# множество слов 1
# многоуровневая разметка 1
# многозначные слово 1
# многозначность слов 1
# мировая политика 1
# метод байеса 1
# метка темы 1
# материалы конференции 1
# малейшая степень 1
# любое слово 1
# любая документ 1
# лингвистический смысл 1
# лингвистический моделирование 1
# лингвистическая обработка 1
# латентно-семантический анализ 1
# краткая характеристика 1
# корпусы текстов 1
# контекстный окно 1
# контекстные элементы 1
# конкретный документ 1
# конец статьи 1
# компьютерные инструменты 1
# какой набор 1
# каждая тема 1
# иная мера 1
# и<ие применимость 1
# значимые слова 1
# заключение наблюдения 1
# естественное язык 1
# другие модель 1
# другие методы 1
# доступные исследователи 1
# документы коллекции 1
# дистрибутивная семантика 1
# деловые тексты 1
# два текстов 1
# дающие представление 1
# данный ряд 1
# выделение классов 1
# выдача результатов 1
# выбор инструмента 1
# входные тексты 1
# второе текст 1
# вторая источник 1
# внешний вид 1
# вероятность появления 1
# вероятностный распределение 1
# ботанический характер 1
# большое объём 1
# большинство разработчиков 1
# большие тексты 1
# большие объёмы 1
# арсенал методов 1
# английский язык 1
# алгебраические модели 1
# авторитетный справочник 1
# автоматическое выделение 1
# автоматический выделение 1
# n-мерный пространство 1
# 3)<база данных 1
# шум 1
# шиморин 1
# шероховатость 1
# хранение 1
# факторы 1
# ф 1
# утверждение 1
# установление 1
# уровень 1
# университет 1
# угол 1
# точка 1
# термы-термы 1
# термы-документ 1
# тематика 1
# статьи 1
# старк 1
# средство 1
# средства 1
# списки 1
# спецификация 1
# специалисты 1
# сообщества 1
# сокращение 1
# содержание 1
# случай 1
# словосочетания 1
# синонимия 1
# симптомы 1
# семантика 1
# свёртка 1
# связь 1
# рис 1
# решение 1
# речь 1
# результаты 1
# рассказы 1
# расположение 1
# разработка 1
# разнообразие 1
# размещение 1
# размерность 1
# разложение 1
# различия 1
# раздел 1
# разбиение 1
# процедура 1
# предложение 1
# пределы 1
# православие 1
# правило 1
# права 1
# построение 1
# пользователь 1
# польза 1
# подход 1
# повести 1
# паничева 1
# пакет 1
# отражение 1
# отличие 1
# особенности 1
# основы 1
# определение 1
# ожидания 1
# ограничение 1
# объём 1
# образование 1
# необходимость 1
# невозможность 1
# направление 1
# наполнение 1
# наборы 1
# мухин 1
# мозг 1
# модификация 1
# мешок 1
# метохия 1
# метод 1
# материалы 1
# м.<гривы 1
# лемматизация 1
# лексика 1
# латиница 1
# круг 1
# коэффициенты 1
# косово 1
# косинус 1
# корпусы 1
# конференция 1
# компактность 1
# коллеги 1
# классификация 1
# качество 1
# источник 1
# использование 1
# искусство 1
# информация 1
# интеграция 1
# инструменты 1
# именно<—<на 1
# и<т.<д 1
# зрение 1
# значение 1
# задачи 1
# задача 1
# журнал 1
# жизнь 1
# доступность 1
# дж.<кент 1
# дети 1
# даррелла 1
# данные 1
# д.<ньюмэн 1
# грачкова 1
# годы 1
# гибкость 1
# ген 1
# время 1
# вектор 1
# в<работа 1
# аннотация 1
# алгоритм 1
# адаптация 1
# автор-получатель 1
# а<такж 1
# zamparelli 1
# wsm 1
# wsd 1
# word 1
# winter 1
# violent 1
# vector 1
# value 1
# turks 1
# trabajando 1
# toxicity 1
# toxic 1
# toolkit 1
# time 1
# tenderness 1
# syntax 1
# svd 1
# summarization 1
# state 1
# stanford 1
# spelling 1
# soreness 1
# song 1
# soil 1
# singular 1
# serous 1
# seeds 1
# seedlings 1
# santorini 1
# sahlgren 1
# ruta 1
# root 1
# room 1
# rohde 1
# retrieval 1
# results 1
# resolution 1
# remedy 1
# rate 1
# pronouns 1
# pronoun 1
# processing 1
# probalilistic 1
# probabilistic 1
# pressure 1
# prefers 1
# pos 1
# plaut 1
# plants 1
# plant 1
# performance 1
# part 1
# parsing 1
# panicheva 1
# outweighed 1
# orthodox 1
# opium 1
# of 1
# occurrence 1
# number 1
# nltk 1
# mukhin 1
# morphology 1
# monksь 1
# monastery 1
# modelling 1
# mitchell 1
# metohia 1
# medications 1
# medica 1
# maximiliano 1
# materia 1
# mars 1
# markov 1
# linguistic 1
# lingpipe 1
# lexics 1
# lexicon 1
# lexical 1
# lee 1
# late 1
# lapata 1
# language 1
# lancaster 1
# lafferty 1
# kosovo 1
# koltsova 1
# kim 1
# jpm 1
# joint 1
# intrasentential 1
# intersentential 1
# information 1
# hyperspace 1
# http://www.cs.buap.mx/~dpinto/research/cicling07_1/pinto06c/node4.html 1
# http://www.cicling.org/2002 1
# http://repository.dlsi.ua.es/357 1
# http://code.google.com/p/topic-modeling-tool 1
# hidden 1
# hedgerows 1
# headaches 1
# headache 1
# head 1
# hat 1
# hal 1
# grow 1
# greenhouse 1
# gonnerman 1
# generation 1
# gelsemium 1
# gate 1
# frame 1
# eyes 1
# extensively 1
# effective 1
# economic 1
# duplication 1
# dirichlet 1
# dioecious 1
# decomposition 1
# cultural 1
# ctm 1
# corpus 1
# coreference 1
# congestion 1
# condition 1
# coals 1
# classifi 1
# church 1
# cation 1
# bryony 1
# bodrunova 1
# bibliography 1
# bernardi 1
# baroni 1
# author-topic 1
# author-recipient 1
# atm 1
# aspect 1
# artm 1
# arnica 1
# armando 1
# appear 1
# antecedent 1
# anaya 1
# ammatory 1
# ammation 1
# ambiguity 1
# allocation 1
# alleviating 1
# albanian 1
# ahmm 1
# 5<тыс.<с/ 1
# 4.наша 1
# 3.типы 1
# 20<тыс.<с/ 1
# 2)<энциклопедия 1
# 2)<с 1
# 150<тыс.<с/ 1
# 1.введение 1
# 1)<с 1
# 1)<книга 1

# %%
with open('RuTermExtract_keywords.csv', 'w', encoding='utf-8') as f2:
    for term in term_extractor(text):
        f2.write(str(term.normalized)+";"+str(term.count)+"\n")

# %%
#SpaCy

# %%
# !pip install spacy

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.1.0/ru_core_news_sm-3.1.0.tar.gz

# %%
import spacy
from collections import Counter
from nltk.corpus import stopwords

# %%
# Для SpaCy (дополнительно взяли стоп-слова из nltk, с ними результаты улучшились)
spacy_model = spacy.load('ru_core_news_sm')

# %%
spacy_model.max_length = 2400000

# %%
nltk_stopwords = stopwords.words('russian')

# %%
spacy_stopwords = spacy_model.Defaults.stop_words

# %%
def extract_keywords_with_spacy(text):
    keywords = []
    doc = spacy_model(text.read())
    for token in doc:
        # Тексты уже очищены от знаков препинания и лемматизированы, тем не менее, остались некоторые символы,
        # которые нужно удалить
        if token.text not in spacy_stopwords and token.text not in nltk_stopwords and \
                token.text not in "`'«»...—-":
            if token.pos_ in ('ADJ', 'NOUN', 'VERB'):
                keywords.append(token.text)

    freq_word = Counter(keywords)
    max_freq = Counter(keywords).most_common(1)[0][1]
    for w in freq_word:
        freq_word[w] = round(freq_word[w] / max_freq, 3)
    
    freq_20 = freq_word.most_common(20)
    
    with open('spacy_keywords.csv', 'w', encoding='utf-8') as f2:
        for term in freq_20:
            f2.write(str(term[0])+";"+str(term[1])+"\n")
    
    print(freq_20)

# %%
with open('/content/art_m.txt', 'r', encoding='utf-8') as file:
    extract_keywords_with_spacy(file)
# Out:
# [('слов', 1.0), ('текстов', 0.95), ('коллекции', 0.55), ('т', 0.5), ('тематического', 0.5), ('моделирования', 0.5), ('модель', 0.5), ('д', 0.45), ('модели', 0.45), ('текстовой', 0.4), ('тексты', 0.4), ('обработки', 0.35), ('ключевых', 0.35), ('слова', 0.35), ('темы', 0.35), ('текста', 0.3), ('документов', 0.3), ('документ', 0.25), ('связаны', 0.25), ('позволяет', 0.2)]

# %%
#Pullenti

# %%
# !pip install pullenti_wrapper

# %%
from pullenti_wrapper.processor import Processor, GEO, ORGANIZATION, PERSON, PHONE, ADDRESS
from collections import Counter

# %%
pullenti_processor = Processor([PERSON, ORGANIZATION, GEO, PHONE, ADDRESS])

# %%
def extract_keywords_with_pullenti(text):
    keywords = []
    for text in text.read().splitlines():
        try:
            result = pullenti_processor(text)
            for match in result.walk():
                for key, value in match.referent.slots:
                    if key not in ('ISRELATIVE', 'SEX', 'NUMBER', 'HIGHER', 'PROFILE',
                                   'ALPHA2', 'POINTER', 'FROM', 'REF', 'ATTRIBUTE'):
                        if 'LASTNAME' in str(match.referent.slots) and 'FIRSTNAME' in str(match.referent.slots):
                            try:
                                keywords.append(f'{match.referent.firstname} {match.referent.lastname}'.lower())
                            except AttributeError:
                                continue
                        keywords.append(str(value).lower())
        except ValueError:
            continue

    freq_word = Counter(keywords)
    
    freq_20 = freq_word.most_common(20)
    
    with open('pullenti_keywords.csv', 'w', encoding='utf-8') as f2:
        for term in freq_20:
            f2.write(str(term[0])+";"+str(term[1])+"\n")
    
    print(freq_20)

# %%
with open('/content/art_m.txt', 'r', encoding='utf-8') as file:
    extract_keywords_with_pullenti(file)
# Out:
# [('государство', 5), ('иорданское хашимитское королевство', 2), ('иордания', 2), ('косово', 2), ('республика косово', 2), ('santorini', 1), ('город', 1), ('республика албания', 1), ('албания', 1)]
